# %%
#%%
# path to working directory
path = '/Users/davidnordfors/galvanize/galvanize-capstone/final'

# IMPORT LIBRARIES
## OS
import os
os.chdir(path)

# MANAGE
import pandas as pd
import numpy as np
#from collections import Counter
from boolma import BM

## FIT
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

#from sklearn.metrics import r2_score

## DECOMPOSITION
from sklearn.decomposition import NMF
from scipy.linalg import svd

## GRAPHICS
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})

def dist_boxplot(x, **kwargs):
    ax = sns.distplot(x, hist_kws=dict(alpha=0.2))
    ax2 = ax.twinx()
    sns.boxplot(x=x, ax=ax2)
    ax2.set(ylim=(-5, 5))


#%% DATA
## I/O
import zipfile
import requests
import pickle

# Normalization function
def norm(vec):
    return (vec-vec.mean())/vec.std()

# READ O*NET DATABASE. Search order: Dictionary, Pickle, Excel; Create dictionary/pickle if non-existent.
onet = {}
def from_onet(qualities):
        if qualities in onet:
                return onet[qualities]
        pickle_exists = os.path.isfile('./data/pickle/'+qualities+'.pkl')
        if pickle_exists:
                onet[qualities] = pd.read_pickle('./data/pickle/'+qualities+'.pkl')
                return onet[qualities]
        else: 
                onet[qualities]= pd.read_excel(
                        zipfile.ZipFile('./data/db_23_2_excel.zip').extract(
                        'db_23_2_excel/'+qualities+'.xlsx'))
                onet[qualities].to_pickle('./data/pickle/'+qualities+'.pkl')
                return onet[qualities]


# format and Strip O*NET SOC occupation codes to match the ones used by Census PUMS
def soc(socc):
    code = str(socc).replace('-','')
    return code[:5]

# CENSUS DATA: 
#%% PUMS Data dictionary
#Source: https://www.census.gov/programs-surveys/acs/data/pums.html )
datadic = pd.read_csv("./data/PUMS_Data_Dictionary_2017.csv").drop_duplicates()

# rows including the string 'word'
def var_about(word):
    return pd.concat((BM(datadic).select('Record Type', 'contains',word).df,
                      BM(datadic).select('Unnamed: 6', 'contains',word).df))

# Name of occupation for SOCP number
def socp_name(socc):
    return datadic[datadic['Record Type']== str(socc)]['Unnamed: 6'].values[0]


# The 6 coefficient/dimension correspond to the 6 occupation/feature clusters
# Functions for looking at the clusters:

tits = from_onet('Alternate Titles')
all_SOCP = set(tits['O*NET-SOC Code'])
aaa = tits[['O*NET-SOC Code','Title']]
aaa['O*NET-SOC Code'] = aaa['O*NET-SOC Code'].apply(soc)
looktit = dict(aaa.values)
def lookup_title(socpnr):
    return looktit[socpnr]


#%% select workers in ages 40 - 65 and discard the occupations with large standard deviations.
all_workers = pd.read_pickle('data/pickle/pums_California.pkl')
workers = BM(all_workers).select(
            'AGEP','gt',40).select(
            'AGEP','lt',65).df
workers['log FTE'] = workers['FTE wage'].apply(np.log)
workers['SOCP_shave'] = workers['SOCP'].apply(soc)
foo = workers.groupby('SOCP_shave') 

all_occupations = foo.mean()[['AGEP', 'FTE wage','log FTE']]
all_occupations['count'] = foo.count()['AGEP']
all_occupations['std log FTE'] = foo.std()['log FTE']
all_occupations['Occupation'] = all_occupations.index
occupations = all_occupations[all_occupations['std log FTE']<0.50]

#%%  CREATE X:features from O*NET; and y: mean wages from census/pums

def matrix(features):
    # Build X: occupation/feature matrix from O*NET
    foo = pd.get_dummies(features['Element Name']) 
    occ_features = features[['O*NET-SOC Code']].join(foo.multiply(features['Data Value'],axis = "index")).groupby('O*NET-SOC Code').sum()
    occ_features['SOCP'] = occ_features.index
    occ_features['SOCP_shave']=occ_features['SOCP'].apply(soc)
    # Group by census/PUMS SOC codes (SOCP_shave)
    occ_features_compounded= occ_features.groupby('SOCP_shave').mean()
    occ_features_compounded['SOCP_shave'] = occ_features_compounded.index   
    foo = occ_features_compounded.drop(columns='SOCP_shave')
    return foo

def xy(features,occupations):
    #Normalizes occupation matrix
    #foo = matrix(features)
    foo = features
    occ_features_norm = (foo - foo.mean())/foo.std()
    

    # Normalize y:  Census/PUMS log FTE wages   
    foo = occupations[['SOCP_shave','Occupation','FTE wage','log FTE']].copy()
#    foo['log FTE'] =norm(occupations['log FTE'])

    # Merge and align X & y for occupations
    fit_data = foo.merge(occ_features_norm,left_on='SOCP_shave',right_index=True)
    
    # Return X & y
    y = fit_data['log FTE']
    X = fit_data.drop(columns = ['SOCP_shave', 'Occupation', 'FTE wage', 'log FTE'])
    return (X,y)


    # Normalize y:  Census/PUMS log FTE wages   
    foo = occupations[['SOCP_shave','Occupation','FTE wage','log FTE']].copy()
#    foo['log FTE'] =norm(occupations['log FTE'])

    # Merge and align X & y for occupations
    fit_data = foo.merge(occ_features_norm,left_on='SOCP_shave',right_index=True)
    
    # Return X & y
    y = fit_data['log FTE']
    X = fit_data.drop(columns = ['SOCP_shave', 'Occupation', 'FTE wage', 'log FTE'])
    return (X,y)


# SELECT FEATURE SETS FROM O*NET, FIT FOR O*NET FTE WAGES 

# Prepare feature sets.
def prepare(df):
    # For Abilities, Knowledge, Skills
    if 'LV' in set(df['Scale ID']):
        sid = 'LV'
    # For Interests
    elif 'OI' in set(df['Scale ID']):
        sid = 'OI'
    df = df[df['Scale ID'] == sid]

    return df[['O*NET-SOC Code','Element Name','Data Value']]
    

dab = prepare(from_onet('Abilities'))
dkn = prepare(from_onet('Knowledge'))
dsk = prepare(from_onet('Skills'))
din = prepare(from_onet('Interests'))

featurenames = ['Abilities','Knowledge','Skills','Interests']

# Put them all together in one big feature matrix
dall = pd.concat([matrix(dab),matrix(dsk),matrix(dkn)],axis = 1)

#%% MODEL & FIT


# CLUSTER FEATURES INTO OCCUPATION CATEGORIES
# Use non-zero matrix factorization for clustering
# Use singular value decomposition first state for determining overall similarity

dwa = prepare(from_onet('Work Activities'))
dwv = from_onet('Work Values')
dwv = dwv[dwv['Scale Name'] == 'Extent'][['O*NET-SOC Code','Element Name','Data Value']]

class OnetCluster:
    def __init__(self,X,n):
        self.X = X
        self.model = NMF(n_components=n, init='random', random_state=0, max_iter = 1000, tol = 0.0000001)
        self.w = self.model.fit_transform(X)
        self.o = pd.DataFrame(self.w,index=X.index)
        self.on = nrmcol(self.o.T).T
        self.ont = self.on.reset_index()['SOCP_shave'].apply(lookup_title)
        self.h = self.model.components_
        self.f = pd.DataFrame(self.h,columns=X.columns)
        self.fn = nrmcol(self.f.T).T
        
    


class Svd:
    def __init__(self,X):
        self.u,self.s,self.vt = svd(np.array(X))
        self.f = pd.DataFrame(self.vt,columns=X.columns)
        self.o = pd.DataFrame(self.u,columns=X.index)
        
def nrmcol(df):
    return df / np.sqrt(np.diagonal(df.T @ df))

#Select PUMS data for occupations in an OnetCluster. 
#Default threshold set to 0.7: only occupations with at least 0.49 of their weight in the cluster are included. 

def clocc(n_order,m_cluster,thresh = 0.7):
    soccs = clcat[n_order][m_cluster][clcat[n_order][m_cluster] > thresh]
    cloccs = soccs.merge(occupations,left_index=True, right_index=True).dropna()
    return cloccs


# Create the matrix of all features




reg_ridge = linear_model.Ridge(alpha=.5)
rf = RandomForestRegressor(n_estimators=40,
                           max_features='auto',
                           random_state=0)

featuresets = [OnetCluster(dall,i).o for i in [6]]

# Xt={}
# yt = {}
# test_fit={}
# coefs = {}
# for ft in range(len(featuresets)):
#     test_fit[ft] = {}
#     coefs[ft] = {}
#     (X, y) = xy(featuresets[ft],occupations)
#     for sed in range(2000):      
#         X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
#         Xt[ft],yt[ft]=X_test,y_test
#         res = cross_validate(reg_ridge,X_train, y_train, cv=3, return_estimator=True)
#         #res = cross_validate(rf,X_train, y_train, cv=n, return_estimator=True)
#         #res = cross_validate(lasse,X_train, y_train, cv=n, return_estimator=True)
#         test_fit[ft][sed]= [res['estimator'][j].score(X_test,y_test) for j in range(3)]
#         coefs[ft][sed]= np.array([res['estimator'][j].coef_ for j in range(3)])
#     coefs[ft]['pd'] = pd.DataFrame(np.concatenate(np.array(list(coefs[ft].values()))))

# # The coefficients for the n'th featureset fitted above
# def coefficients(n):
#     return pd.DataFrame([coefs[n]['pd'].mean(),coefs[n]['pd'].std()],index=['mean','std']).T.sort_values('mean',ascending=False)

# # In the example above we have only one featureset: OnetCluster(dall,6)
# # The entire featurespace has been reduced to 6 dimensions, by NMF clustering
# resfeat = coefficients(0).merge(OnetCluster(dall,6).fn,left_index=True,right_index=True)
# result_features = {}
# for i in range(len(resfeat)):
#     result_features[i] = resfeat.iloc[i].sort_values(ascending=False)[:10]

# aaa = OnetCluster(dall,6)
# bbb = aaa.on.copy()
# bbb['SOCP_shave'] = bbb.index
# bbb['Title'] = bbb['SOCP_shave'].apply(lookup_title)
# aaa.ont = bbb
# ccc = aaa.ont.set_index(aaa.ont['Title'])
# resocc = coefficients(0).merge(ccc.T,left_index=True,right_index=True)

# result_occupations = {}
# for i in range(len(result_occupations)):
#     result_occupations[i] = resocc.iloc[i].sort_values(ascending=False)[:10]

def plo(dd,n):
    df = OnetCluster(matrix(dd),n).on.apply(np.square)
    df['Title'] = df.index
    df['Title'] = df['Title'].apply(lookup_title)
    df = df.merge(occupations[['FTE wage','count']].astype(int),left_index = True, right_on='SOCP_shave')
    return df
    

# # Check plo
# dd = dab
# n=2
# df = OnetCluster(matrix(dd),n).on.apply(np.square)
# df['Title'] = df.index
# df['Title'] = df['Title'].apply(lookup_title)
# df = df.merge(occupations[['FTE wage','count']].astype(int),left_index = True, right_on='SOCP_shave')

def plf(dd,n):
    sns.clustermap(OnetCluster(matrix(dd),n).fn.apply(lambda x: x**2).sort_values(
    1,axis=1,ascending = False).T,figsize=(2*n, 16),method = 'single')
# check plf
#plf(din,2)

# # check
# aaa = plo(dab,2).sort_values(0,ascending=False)
# aaa.merge(occupations[['FTE wage','count']].astype(int),left_index = True, right_index=True)
 

# Least Squares Approximation

def lsa(X,y):
    xtx = X.T @ X
    xty = X.T @ y
    xtx_inv = pd.DataFrame(np.linalg.pinv(xtx.values), xtx.columns, xtx.index)
    k = xtx_inv @ xty
    return k

# Prepare X = Onet features and y = Census FTE 
# Since X is specific for occupations, reduce the size and group workers by occupation / SOCP shave 
# Merge X and y to put them in the right order and exclude mis-matches

Xy_workers = pd.merge(workers[['SOCP_shave','DEAR','DEYE','log FTE']],dall,right_index = True, left_on='SOCP_shave')
Xy_occupations = Xy_workers.groupby('SOCP_shave').mean().drop(['DEAR','DEYE'],axis = 1)
Xy_occupations['std log FTE'] = Xy_workers.groupby('SOCP_shave').std()['log FTE']
Xy_occupations['count'] = Xy_workers.groupby('SOCP_shave').count()['log FTE']

X = Xy_occupations.drop(['log FTE', 'std log FTE', 'count'], axis = 1)
y = Xy_occupations['log FTE']


# use LSA

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

coefs = lsa(X_train,y_train)
coefs['test'] = lsa(X_test,y_test)

# Use sklearn - ridge / random forest

rid = linear_model.Ridge(alpha=.5)
rf = RandomForestRegressor(n_estimators=40,
                           max_features='auto',
                           random_state=0)
boo = GradientBoostingRegressor(loss='ls', learning_rate=0.1, n_estimators=100, subsample=1.0, criterion='friedman_mse', min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_depth=3, min_impurity_decrease=0.0, min_impurity_split=None, init=None, random_state=None, max_features=None, alpha=0.9, verbose=0, max_leaf_nodes=None, warm_start=False, presort='auto', validation_fraction=0.1, n_iter_no_change=None, tol=0.0001)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
res_rid = cross_validate(rid,X_train, y_train, cv=3, return_estimator=True)
res_rf = cross_validate(rf,X_train, y_train, cv=3, return_estimator=True)
res_boo = cross_validate(boo,X_train, y_train, cv=3, return_estimator=True)

# %%
res_rf['estimator']
# Out:
# (RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#             max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=40, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False),
#  RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#             max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=40, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False),
#  RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#             max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=40, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False))

# %%
plt.scatter(res_rf['estimator'][0].predict(X_test),y_test)
# Out:
# array([10.36846254, 10.5294305 , 10.84649171, 11.54790562, 10.68411216,
#        11.43352149, 11.65347806, 10.9079107 , 11.52597143, 10.98352286,
#        11.29963317, 11.49874841, 11.53484375, 10.58933758, 11.0529221 ,
#        10.81482165, 10.75274993, 10.89256262, 11.44817386, 11.1290265 ,
#        10.61060596, 11.04033011, 10.63338702, 11.00996279, 10.56021604,
#        11.38517412, 10.80930129, 11.44342053, 10.8342434 , 10.65843541,
#        11.20677621, 11.55918034, 11.02004119, 10.55202421, 10.65552834,
#        10.7805918 , 11.60948947, 11.07535819, 10.64244997, 10.6186951 ,
#        10.44876685, 11.13261086, 10.6684442 , 10.78650103, 11.02042624,
#        10.75770058, 10.56478641, 11.00344424, 11.33352083, 10.71986384,
#        11.34909955, 10.60172934, 10.54623177, 11.07475518, 11.09156665,
#        11.14332107, 10.7734122 , 10.62352998, 11.11872949, 10.94340064,
#        11.18268494, 10.96385945, 11.37620228, 10.75601426, 11.08432369,
#        10.59855413, 10.93776434, 11.46713202, 10.74007316, 10.71082642,
#        10.5660137 ])

# %%
plt.scatter(res_rf['estimator'][0].predict(X_test),y_test)
plt.scatter(res_rf['estimator'][1].predict(X_test),y_test)
plt.scatter(res_rf['estimator'][2].predict(X_test),y_test)

# %%
plt.scatter(res_rid['estimator'][0].predict(X_test),y_test)
plt.scatter(res_rid['estimator'][1].predict(X_test),y_test)
plt.scatter(res_rid['estimator'][2].predict(X_test),y_test)

# %%
plt.scatter(res_boo['estimator'][0].predict(X_test),y_test)
plt.scatter(res_boo['estimator'][1].predict(X_test),y_test)
plt.scatter(res_boo['estimator'][2].predict(X_test),y_test)

# %%
Xy_occupations
# Out:
#               log FTE  Arm-Hand Steadiness  Auditory Attention  \
# SOCP_shave
# 11102       11.308071             1.500000            2.000000
# 11201       11.403811             0.500000            1.250000
# 11202       11.483069             0.310000            1.750000
# 11203       11.351421             0.000000            1.500000
# 11301       11.155413             2.000000            2.250000
# 11302       11.586107             2.000000            1.750000
# 11303       11.478888             0.125000            1.560000
# 11305       11.232219             2.500000            2.875000
# 11306       11.255881             0.000000            1.880000
# 11307       10.984863             1.250000            2.040000
# 11311       11.430534             0.500000            1.000000
# 11312       11.300383             0.500000            1.620000
# 11313       11.314990             0.880000            2.000000
# 11901       10.911886             2.790000            2.420000
# 11902       11.277991             0.620000            3.000000
# 11903       11.210956             1.124000            1.952000
# 11904       11.873683             2.125000            2.375000
# 11905       10.774592             2.880000            2.620000
# 11907       11.119959             0.620000            2.750000
# 11908       10.878110             2.250000            2.000000
# 11911       11.342950             0.880000            2.000000
# 11912       11.673567             0.000000            1.916667
# 11914       11.038867             0.000000            1.380000
# 11915       11.146772             1.250000            2.000000
# 11916       11.282468             1.750000            2.250000
# 13101       11.518562             1.000000            1.750000
# 13102       10.929276             1.460000            1.583333
# 13103       11.015432             1.503333            1.713333
# 13104       11.232585             1.583333            2.538333
# 13105       11.167965             0.120000            1.380000
# ...               ...                  ...                 ...
# 51903       10.379736             3.250000            2.565000
# 51904       10.486176             3.250000            3.250000
# 51905       10.444339             3.000000            2.750000
# 51906       10.763994             2.750000            2.620000
# 51907       10.573115             4.916667            2.250000
# 51908       10.691931             3.746667            2.543333
# 51911       10.378290             3.120000            3.000000
# 51912       10.629334             3.333333            2.206667
# 51915       10.951767             2.880000            2.500000
# 51919       10.600827             3.405833            2.656667
# 53201       11.741220             3.435000            3.565000
# 53202       11.515300             2.315000            3.500000
# 53203       10.872716             2.880000            3.500000
# 53301       10.353993             3.000000            2.750000
# 53302       10.588856             2.630000            2.875000
# 53303       10.610734             2.460000            2.250000
# 53304       10.465969             3.000000            2.880000
# 53401       11.050928             3.003333            3.623333
# 53403       11.066654             2.880000            3.880000
# 53502       11.238317             3.125000            3.280000
# 53602       10.413428             2.120000            2.250000
# 53603       10.559829             3.000000            2.750000
# 53605       11.028663             2.833333            2.790000
# 53606       10.578659             2.120000            2.380000
# 53702       11.199852             3.120000            2.880000
# 53703       10.873764             3.163333            3.416667
# 53705       10.458187             2.880000            3.000000
# 11911                         3.350000             1.920000
# 11912                         2.906667             2.273333
# 11914                         4.230000             3.770000
# 11915                         3.550000             2.950000
# 11916                         5.280000             3.280000
# 13101                         1.340000             4.990000
# 13102                         2.520000             3.953333
# 13103                         1.666667             1.413333
# 13104                         3.288333             1.413333
# 13105                         2.140000             3.140000
# ...                                ...                  ...
# 51903                         1.610000             1.495000
# 51904                         2.430000             1.120000
# 51905                         2.690000             1.440000
# 51906                         1.700000             0.830000
# 51907                         1.740000             3.140000
# 51908                         2.180000             1.963333
# 51911                         3.060000             1.940000
# 51912                         1.513333             1.456667
# 51915                         1.120000             2.460000
# 51919                         2.384167             1.743333
# 53201                         3.605000             1.930000
# 53202                         4.540000             0.960000
# 53203                         3.610000             2.530000
# 53301                         2.980000             1.030000
# 53302                         3.405000             0.955000
# 53303                         2.636667             1.846667
# 53304                         2.910000             1.730000
# 53401                         3.730000             0.586667
# 53403                         4.010000             1.280000
# 53502                         3.917500             1.577500
# 53602                         2.580000             1.970000
# 53603                         3.030000             3.490000
# 53605                         3.453333             1.616667
# 53606                         2.670000             1.440000
# 53702                         3.000000             0.970000
# 53703                         2.790000             1.143333
# 53705                         3.070000             1.700000
# 53706                         2.242500             1.375000
# 53707                         3.696667             0.970000
# 53708                         3.210000             2.540000
#
#             Sociology and Anthropology  Telecommunications  \
# SOCP_shave
# 11102                         1.300000            2.330000
# 11201                         2.770000            1.910000
# 11202                         2.060000            2.260000
# 11203                         3.250000            1.110000
# 11301                         1.450000            2.190000
# 11302                         1.690000            2.810000
# 11303                         1.870000            1.260000
# 11305                         1.551667            1.775000
# 11306                         1.190000            2.140000
# 11307                         2.150000            2.340000
# 11311                         2.760000            0.430000
# 11312                         3.780000            1.040000
# 11313                         3.890000            1.480000
# 11901                         1.476667            1.226667
# 11902                         1.080000            1.960000
# 11903                         2.992000            1.772000
# 11904                         1.080000            2.155000
# 11905                         1.510000            1.260000
# 11907                         2.100000            1.910000
# 11908                         2.630000            2.520000
# 11911                         1.920000            1.120000
# 11912                         1.840000            1.383333
# 11914                         2.150000            1.650000
# 11915                         4.160000            1.500000
# 11916                         3.320000            3.480000
# 13101                         1.770000            1.630000
# 13102                         1.526667            1.963333
# 13103                         0.773333            1.303333
# 13104                         2.541667            1.508333
# 13105                         1.000000            1.770000
# ...                                ...                 ...
# 51903                         0.605000            0.670000
# 51904                         0.960000            1.240000
# 51905                         1.070000            1.550000
# 51906                         0.390000            0.420000
# 51907                         0.673333            1.190000
# 51908                         0.866667            1.146667
# 51911                         0.910000            1.170000
# 51912                         0.536667            0.236667
# 51915                         0.620000            0.610000
# 51919                         0.712500            0.849167
# 53201                         1.415000            2.775000
# 53202                         1.215000            2.905000
# 53203                         2.880000            0.770000
# 53301                         1.180000            1.470000
# 53302                         1.305000            1.480000
# 53303                         0.606667            1.133333
# 53304                         1.850000            1.920000
# 53401                         0.503333            1.966667
# 53403                         1.260000            2.100000
# 53502                         1.407500            2.727500
# 53602                         0.840000            1.410000
# 53603                         1.120000            1.620000
# 53706                     0.677500        1.992500     0.455428   3808
# 53707                     1.056667        2.236667     0.677149     31
# 53708                     0.980000        4.190000     0.534789    143
#
# [353 rows x 123 columns]

# %%
res = {}
for i in range(20):
    res[i] = pd.concat([lsa(Xy.sample(10000)) for i in range(100)],axis = 1)

fin = pd.concat(list(res.values()),axis = 1)
final = pd.concat([fin.T.mean(),fin.T.std()],axis = 1)
final.columns = ['mean','std']
final.sort_values('mean',ascending = False)

y_hat = dall @ final[['mean']]
y_test = Xy.groupby('SOCP').mean()[['log FTE']]

y_final = y_test.merge(y_hat,left_index = True, right_index = True)
y_final.columns = ['Actual log FTE wage','Predicted log FTE wage']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-e8af0b167340> in <module>()
#       1 res = {}
#       2 for i in range(20):
# ----> 3     res[i] = pd.concat([lsa(Xy.sample(10000)) for i in range(100)],axis = 1)
#       4
#       5 fin = pd.concat(list(res.values()),axis = 1)
#
# <ipython-input-16-e8af0b167340> in <listcomp>(.0)
#       1 res = {}
#       2 for i in range(20):
# ----> 3     res[i] = pd.concat([lsa(Xy.sample(10000)) for i in range(100)],axis = 1)
#       4
#       5 fin = pd.concat(list(res.values()),axis = 1)
#
# <ipython-input-14-01ada4c7b454> in lsa(Xy)
#       9     X = (Xy.drop(['SOCP','DEAR','DEYE','log FTE'],axis = 1))
#      10     y = (Xy[['log FTE']])
# ---> 11     xtx = X.T @ X
#      12     xty = X.T @ y
#      13     xtx_inv = pd.DataFrame(np.linalg.pinv(xtx.values), xtx.columns, xtx.index)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __matmul__(self, other)
#     894     def __matmul__(self, other):
#     895         """ Matrix multiplication using binary `@` operator in Python>=3.5 """
# --> 896         return self.dot(other)
#     897
#     898     def __rmatmul__(self, other):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in dot(self, other)
#     879
#     880         if isinstance(other, DataFrame):
# --> 881             return self._constructor(np.dot(lvals, rvals), index=left.index,
#     882                                      columns=other.columns)
#     883         elif isinstance(other, Series):
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
sns.set(color_codes=True)
sns.set(font_scale=2.3) 
f, axes = plt.subplots(1,1, sharey=True, figsize=(12, 6))
sns.regplot(x='Predicted log FTE wage',y='Actual log FTE wage',data = y_final)
plt.title('Predicting wages from Abilities + Skills + Knowledge ')
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5,1,'Predicting wages from Abilities + Skills + Knowledge ')

# %%
r2scores = pd.DataFrame(index = ['R^2','MSQE'])

# %%
from scipy import stats
from sklearn.metrics import r2_score
r2_score(y_final['Actual log FTE wage'] , y_final['Predicted log FTE wage'])
# Out:
# -1.6184798568452945

# %%
sum((y_final['Actual log FTE wage'] - y_final['Predicted log FTE wage']).apply(np.square))/len(y_final)
# Out:
# 0.20841053687990468

# %%
r2scores['Normal'] = [-1.6184798568452945,0.20841053687990468]

# %%
for n_order in [2,6,12,25,50,100]:
    clall = OnetCluster(dall,n_order).on

    Xy = pd.merge(workers[['SOCP','DEAR','DEYE','log FTE']],clall,right_index = True, left_on='SOCP')
    X = (Xy.drop(['SOCP','DEAR','DEYE','log FTE'],axis = 1))
    y = (Xy[['log FTE']]).apply(norm)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

    def lsa(Xy):
        X = (Xy.drop(['SOCP','DEAR','DEYE','log FTE'],axis = 1))
        y = (Xy[['log FTE']])
        xtx = X.T @ X
        xty = X.T @ y
        xtx_inv = pd.DataFrame(np.linalg.pinv(xtx.values), xtx.columns, xtx.index)
        k = xtx_inv @ xty
        return k

    res = {}
    for i in range(20):
        res[i] = pd.concat([lsa(Xy.sample(10000)) for i in range(100)],axis = 1)

    fin = pd.concat(list(res.values()),axis = 1)
    final = pd.concat([fin.T.mean(),fin.T.std()],axis = 1)
    final.columns = ['mean','std']
    final.sort_values('mean',ascending = False)

    y_hat = clall @ final[['mean']]
    y_test = Xy.groupby('SOCP').mean()[['log FTE']]

    y_final = y_test.merge(y_hat,left_index = True, right_index = True)
    y_final.columns = ['Actual log FTE wage','Predicted log FTE wage']


    r2scores[n_order] = [r2_score(y_final['Actual log FTE wage'],y_final['Predicted log FTE wage']),sum((y_final['Actual log FTE wage'] - y_final['Predicted log FTE wage']).apply(np.square))/len(y_final)]

# %%
r2scores
# Out:
#         Normal         2         6        12        25        50       100
# R^2  -1.618480 -9.161632 -9.583016 -7.797659 -3.019607 -2.130126 -1.229150
# MSQE  0.208411  1.514589  1.577397  1.311290  0.599122  0.466545  0.332254

# %%
pmsqe
# Out:
#                2         6         10        20        40
# p-value  0.000048  0.141279  0.183390  0.090695  0.407027
# msqe     1.514529  1.577188  1.363123  0.820290  0.332062

# %%
y_final['Actual log FTE wage'].mean()
# Out:
# 10.921912539113595

# %%
y_final['mean'] = 10.921912539113595

# %%
list(stats.ttest_ind(y_final['Actual log FTE wage'],y_final['Predicted log FTE wage']))[1]
# Out:
# 4.8546503033150886e-05

# %%
sum((y_final['Actual log FTE wage'] - y_final['Predicted log FTE wage']).apply(np.square))/len(y_final)
# Out:
# 1.5773052665747178

# %%
list(stats.ttest_ind(y_final['Actual log FTE wage'],y_final['mean']))[1]
# Out:
# 0.9999999999996769

# %%
sum((y_final['Actual log FTE wage'] - y_final['mean']).apply(np.square))/len(y_final)
# Out:
# 0.14904981353620955

# %%
pmsqe[120] = [0.72,0.21]
pmsqe['mean'] = [1.0 , 0.15 ]
pmsqe
# Out:
#                 2         6        10        20        40        80   120  \
# p-value  0.000048  0.141279  0.183390  0.090695  0.407027  0.998504  0.72
# msqe     1.514529  1.577188  1.363123  0.820290  0.332062  0.390284  0.21
#
#          mean
# p-value  1.00
# msqe     0.15

# %%
r2scores[[2,6,12,25,50,100,'Normal']]
# Out:
#              2         6        12        25        50       100    Normal
# R^2  -9.161632 -9.583016 -7.797659 -3.019607 -2.130126 -1.229150 -1.618480
# MSQE  1.514589  1.577397  1.311290  0.599122  0.466545  0.332254  0.208411

# %%
aaa = r2scores[[2,6,12,25,50,100,'Normal']].T
aaa['N'] = aaa.index

# %%
aaa['type'] = ['Archetype','Archetype','Archetype','Archetype','Archetype','Archetype','Normal']

# %%
sns.set(font_scale=1.5) 
sns.barplot(y='MSQE',x='N',hue='type',data = aaa)

# %%
sns.set(color_codes=True)
sns.set(font_scale=2.3) 
f, axes = plt.subplots(1,1, sharey=True, figsize=(12, 6))
sns.regplot(x='Predicted log FTE wage',y='Actual log FTE wage',data = y_final)
plt.title('Predicting wages from Archetypes - N=2 ')
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5,1,'Predicting wages from Archetypes - N=2 ')

# %%
pval = []

# %%
order = [2]

# %%
msq = []

# %%
len(X_test.columns)
# Out:
# 120

# %%
lres
# Out:
# {0:                                 log FTE   log FTE   log FTE   log FTE  \
#  Arm-Hand Steadiness           -0
#  ...                                 ...       ...       ...       ...
#  Chemistry                     -0.083274 -0.135221 -0.045198 -0.145797
#  Clerical                      -0.032611 -0.082822 -0.069764 -0.014681
#  Communications and Media      -0.224429 -0.151806 -0.204299 -0.114165
#  Computers and Electronics      0.070742  0.053884  0.056523  0.011392
#  Customer and Personal Service  0.018601  0.013531  0.019268  0.044783
#  Design                         0.049932  0.005218  0.034681 -0.047981
#  Economics and Accounting       0.054864  0.045342  0.049838 -0.053959
#  Education and Training         0.049778 -0.039746  0.034527  0.012549
#  Engineering and Technology     0.112629  0.086260  0.090527  0.106236
#  English Language               0.176544  0.244639  0.201516  0.160800
#  Fine Arts                     -0.063292 -0.029855  0.021807 -0.012167
#  Food Production                0.089896  0.085546  0.096357  0.078729
#  Foreign Language              -0.380673 -0.341838 -0.361919 -0.347276
#  Geography                     -0.034681 -0.044050 -0.044190 -0.049150
#  History and Archeology         0.029854 -0.045415 -0.012605  0.035934
#  Law and Government            -0.124675 -0.131429 -0.149765 -0.121839
#  Mathematics                   -0.064899 -0.012561 -0.029995  0.056077
#  Mechanical                    -0.125607 -0.091594 -0.110557 -0.073741
#  Medicine and Dentistry         0.005612  0.046049  0.009791 -0.041910
#  Personnel and Human Resources -0.052454  0.026141 -0.059462 -0.032728
#  Philosophy and Theology       -0.014077  0.038768 -0.019593 -0.007744
#  Physics                        0.143877  0.177358  0.127742  0.144663
#  Production and Processing      0.027759  0.045475  0.024930  0.045294
#  Psychology                    -0.048688 -0.061211 -0.083659 -0.037537
#  Public Safety and Security     0.119354  0.135954  0.151261  0.179172
#  Sales and Marketing            0.114145  0.068164  0.039674  0.078434
#  Sociology and Anthropology     0.203483  0.174568  0.240751  0.150100
#  Telecommunications             0.049084  0.027641  0.043946  0.038611
#  Therapy and Counseling        -0.167290 -0.163348 -0.144017 -0.129424
#  Transportation                -0.020314  0.017157  0.036776 -0.009587
#
#                                  log FTE   log FTE    ...      log FTE  \
#  Arm-Hand Steadiness           -0.188065 -0.194754    ...    -0.089832
#  Auditory Attention            -0.228310 -0.348164    ...    -0.319151
#  Category Flexibility           0.594150  0.606557    ...     0.747634
#  Control Precision              0.115646  0.101006    ...    -0.064062
#  Deductive Reasoning            0.140530  0.203956    ...     0.144476
#  Depth Perception               0.108650  0.040934    ...     0.082232
#  Dynamic Flexibility            0.091177  0.150577    ...     0.120194
#  Dynamic Strength               0.161251  0.234390    ...     0.213960
#  Explosive Strength            -0.086655 -0.066812    ...    -0.022242
#  Extent Flexibility            -0.091024 -0.067980    ...    -0.058670
#  Far Vision                     0.156058  0.170989    ...     0.212652
#  Finger Dexterity               0.023551  0.024943    ...     0.023200
#  Flexibility of Closure        -0.112445  0.013828    ...    -0.116142
#  Fluency of Ideas              -0.249215 -0.190404    ...    -0.336470
#  Glare Sensitivity             -0.060796 -0.107075    ...     0.035976
#  Gross Body Coordination        0.054269  0.297225    ...     0.075224
#  Gross Body Equilibrium        -0.167665 -0.223583    ...    -0.148412
#  Hearing Sensitivity            0.207124  0.235820    ...     0.221013
#  Inductive Reasoning            0.075341  0.015759    ...     0.008154
#  Information Ordering           0.199295  0.254702    ...     0.360190
#  Manual Dexterity               0.073141  0.077718    ...     0.061069
#  Mathematical Reasoning        -0.284285 -0.271694    ...    -0.146302
#  Memorization                   0.278312  0.249092    ...     0.063281
#  Multilimb Coordination         0.075394  0.033582    ...     0.103148
#  Near Vision                    0.591165  0.500068    ...     0.561603
#  Night Vision                  -0.261790 -0.064965    ...    -0.426283
#  Number Facility               -0.121024 -0.006973    ...    -0.083271
#  Oral Comprehension             0.482572  0.753437    ...     0.409068
#  Oral Expression                0.073855 -0.175824    ...    -0.081346
#  Originality                   -0.005592  0.038495    ...     0.208007
#  ...                                 ...       ...    ...          ...
#  Chemistry                     -0.090286 -0.056168    ...    -0.104104
#  Clerical                      -0.024611 -0.012174    ...    -0.023112
#  Communications and Media      -0.179866 -0.110146    ...    -0.262678
#  Computers and Electronics      0.045427  0.072588    ...     0.067242
#  Customer and Personal Service  0.021002  0.016811    ...     0.035406
#  Design                         0.026284  0.003055    ...     0.016918
#  Economics and Accounting       0.027319 -0.009059    ...     0.012402
#  Education and Training         0.039449  0.008099    ...     0.022278
#  Engineering and Technology     0.073809  0.057818    ...     0.117144
#  English Language               0.169074  0.175902    ...     0.214701
#  Fine Arts                      0.050920 -0.042532    ...    -0.010070
#  Food Production                0.046725  0.046645    ...     0.107244
#  Foreign Language              -0.258115 -0.328056    ...    -0.369366
#  Geography                     -0.094783 -0.042321    ...    -0.037218
#  History and Archeology        -0.017156  0.028697    ...     0.040289
#  Law and Government            -0.149432 -0.106686    ...    -0.147454
#  Mathematics                    0.034096 -0.039434    ...    -0.040560
#  Mechanical                    -0.085974 -0.076191    ...    -0.145796
#  Medicine and Dentistry         0.027978 -0.005446    ...     0.009892
#  Personnel and Human Resources  0.003717 -0.060107    ...    -0.027810
#  Philosophy and Theology        0.009385 -0.015680    ...     0.033882
#  Physics                        0.149308  0.118751    ...     0.184507
#  Production and Processing      0.015593  0.066489    ...     0.062234
#  Psychology                    -0.039605 -0.074884    ...    -0.046196
#  Public Safety and Security     0.144258  0.109927    ...     0.151522
#  Sales and Marketing            0.111080  0.138362    ...     0.106110
#  Sociology and Anthropology     0.180215  0.203287    ...     0.195882
#  Telecommunications             0.051450  0.003350    ...     0.058807
#  Therapy and Counseling        -0.203405 -0.146207    ...    -0.189817
#  Transportation                 0.022132  0.021775    ...    -0.025896
#
#                                  log FTE   log FTE   log FTE   log FTE  \
#  Arm-Hand Steadiness           -0.190760 -0.060674 -0.180362 -0.154934
#  Auditory Attention            -0.328999 -0.351172 -0.293084 -0.395085
#  Category Flexibility           0.754737  0.689114  0.843792  0.680783
#  Control Precision              0.055515  0.058729  0.002772 -0.083294
#  Deductive Reasoning            0.147823  0.171179  0.111469  0.210836
#  Depth Perception               0.153068  0.044915  0.089498  0.077174
#  Dynamic Flexibility            0.006354  0.172115  0.061127  0.152536
#  Dynamic Strength               0.279272  0.313889  0.248561  0.200091
#  Explosive Strength            -0.080779 -0.087755 -0.069456 -0.055387
#  Extent Flexibility            -0.000586 -0.003122 -0.004157 -0.040001
#  Far Vision                     0.221960  0.200558  0.121908  0.260914
#  Finger Dexterity               0.052274  0.063265  0.086575  0.049337
#  Flexibility of Closure        -0.210973 -0.124938 -0.114153 -0.050793
#  Fluency of Ideas              -0.377317 -0.303894 -0.224892 -0.308179
#  Glare Sensitivity              0.082020 -0.062490  0.092666  0.089409
#  Production and Processing      0.067360  0.049907  0.009853  0.058817
#  Psychology                    -0.046725 -0.038935 -0.044178 -0.078137
#  Public Safety and Security     0.160355  0.097534  0.157644  0.184028
#  Sales and Marketing            0.099310  0.095404  0.095309  0.122176
#  Sociology and Anthropology     0.229185  0.210908  0.210978  0.175105
#  Telecommunications             0.021830  0.028899  0.051132  0.026321
#  Therapy and Counseling        -0.179753 -0.158594 -0.163539 -0.177958
#  Transportation                 0.026891  0.030402 -0.004039  0.035967
#
#                                  log FTE
#  Arm-Hand Steadiness           -0.098446
#  Auditory Attention            -0.300461
#  Category Flexibility           0.670027
#  Control Precision             -0.008653
#  Deductive Reasoning            0.051458
#  Depth Perception               0.122514
#  Dynamic Flexibility           -0.013868
#  Dynamic Strength               0.251186
#  Explosive Strength            -0.077875
#  Extent Flexibility            -0.068367
#  Far Vision                     0.169184
#  Finger Dexterity               0.105569
#  Flexibility of Closure        -0.048551
#  Fluency of Ideas              -0.247957
#  Glare Sensitivity             -0.077510
#  Gross Body Coordination        0.174967
#  Gross Body Equilibrium        -0.227113
#  Hearing Sensitivity            0.177608
#  Inductive Reasoning           -0.080114
#  Information Ordering           0.243551
#  Manual Dexterity               0.058013
#  Mathematical Reasoning        -0.234930
#  Memorization                   0.065242
#  Multilimb Coordination         0.006476
#  Near Vision                    0.581599
#  Night Vision                  -0.179875
#  Number Facility               -0.052199
#  Oral Comprehension             0.561519
#  Oral Expression                0.081054
#  Originality                    0.221907
#  ...                                 ...
#  Chemistry                     -0.076874
#  Clerical                      -0.040942
#  Communications and Media      -0.198531
#  Computers and Electronics      0.025417
#  Customer and Personal Service  0.042230
#  Design                        -0.001215
#  Economics and Accounting       0.029157
#  Education and Training        -0.002835
#  Engineering and Technology     0.072590
#  English Language               0.250939
#  Fine Arts                     -0.010132
#  Food Production                0.072502
#  Foreign Language              -0.346189
#  Geography                     -0.052452
#  History and Archeology         0.022076
#  Law and Government            -0.123810
#  Mathematics                   -0.001870
#  Mechanical                    -0.065260
#  Medicine and Dentistry         0.049393
#  Personnel and Human Resources -0.013227
#  Philosophy and Theology        0.009215
#  Physics                        0.191342
#  Production and Processing      0.025093
#  Psychology                    -0.085839
#  Public Safety and Security     0.099388
#  Sales and Marketing            0.083524
#  Sociology and Anthropology     0.228875
#  Telecommunications             0.039569
#  Therapy and Counseling        -0.191866
#  Transportation                 0.021229
#
#  [120 rows x 100 columns],
#  1:                                 log FTE   log FTE   log FTE   log FTE  \
#  Arm-Hand Steadiness           -0.178169 -0.217449 -0.157360 -0.168010
#  Auditory Attention            -0.348969 -0.317864 -0.297256 -0.321785
#  Category Flexibility           0.667296  0.636621  0.788789  0.679184
#  Control Precision             -0.003185  0.013513  0.026362 -0.047666
#  Deductive Reasoning            0.302269  0.271781  0.240505  0.335229
#  Depth Perception               0.026755  0.050960  0.033781  0.048734
#  Dynamic Flexibility            0.116934  0.072647  0.053389  0.186833
#  Dynamic Strength               0.210538  0.105589  0.215487  0.277409
#  Explosive Strength            -0.085641 -0.027552 -0.101627 -0.086906
#  Mathematics                    0.001718  0.003677  0.040248 -0.049944
#  Mechanical                    -0.123835 -0.127197 -0.075755 -0.108969
#  Medicine and Dentistry        -0.000344 -0.026979  0.015236  0.013864
#  Personnel and Human Resources -0.029897 -0.034334  0.009814 -0.044051
#  Philosophy and Theology        0.025508  0.077452 -0.019403 -0.010140
#  Physics                        0.206605  0.183985  0.131443  0.166338
#  Production and Processing      0.043871  0.013889  0.024852  0.034193
#  Psychology                    -0.059031 -0.081872 -0.024756 -0.065868
#  Public Safety and Security     0.126414  0.132668  0.122527  0.170368
#  Sales and Marketing            0.120583  0.113790  0.091077  0.083407
#  Sociology and Anthropology     0.207566  0.197913  0.163885  0.257371
#  Telecommunications             0.053428  0.064748  0.013498  0.037086
#  Therapy and Counseling        -0.203966 -0.167731 -0.192216 -0.175421
#  Transportation                 0.028797  0.009156  0.002752  0.003607
#
#                                  log FTE   log FTE    ...      log FTE  \
#  Arm-Hand Steadiness           -0.218025 -0.110271    ...    -0.150224
#  Auditory Attention            -0.357278 -0.358200    ...    -0.329360
#  Category Flexibility           0.613886  0.712693    ...     0.632556
#  Control Precision             -0.028508 -0.017958    ...    -0.031582
#  Deductive Reasoning            0.077893  0.189860    ...     0.210420
#  Depth Perception               0.102866  0.067434    ...     0.060249
#  Dynamic Flexibility            0.133949  0.010711    ...     0.263837
#  Dynamic Strength               0.164766  0.151136    ...     0.175752
#  Explosive Strength            -0.112672 -0.100867    ...    -0.094017
#  Extent Flexibility            -0.086796 -0.021058    ...    -0.082266
#  Far Vision                     0.157391  0.178204    ...     0.195954
#  Finger Dexterity               0.065876  0.031629    ...     0.024559
#  Flexibility of Closure        -0.030791 -0.109676    ...     0.012678
#  Fluency of Ideas              -0.249418 -0.232999    ...    -0.403945
#  Glare Sensitivity             -0.022376 -0.072559    ...     0.015229
#  Gross Body Coordination        0.289194  0.122998    ...     0.282058
#  Gross Body Equilibrium        -0.166400 -0.181753    ...    -0.224975
#  Hearing Sensitivity            0.209228  0.238518    ...     0.301628
#  Inductive Reasoning           -0.053240 -0.064987    ...    -0.161986
#  Information Ordering           0.342686  0.247951    ...     0.242680
#  Manual Dexterity               0.243907  0.119926    ...     0.204345
#  Mathematical Reasoning        -0.152594 -0.161627    ...    -0.262757
#  Memorization                   0.066224  0.084578    ...     0.221793
#  Multilimb Coordination         0.077420  0.049175    ...    -0.000420
#  Near Vision                    0.528905  0.586200    ...     0.594343
#  Night Vision                  -0.341501 -0.233321    ...    -0.220738
#  Number Facility               -0.064392 -0.057478    ...     0.015351
#  Oral Comprehension             0.691594  0.755070    ...     0.641711
#  Oral Expression               -0.069069 -0.212025    ...    -0.056301
#  Originality                    0.112110  0.130287    ...     0.283676
#  ...                                 ...       ...    ...          ...
#  Chemistry                     -0.046472 -0.062323    ...    -0.096001
#  Clerical                      -0.035392 -0.043067    ...     0.004590
#  Communications and Media      -0.194016 -0.214354    ...    -0.196217
#  Computers and Electronics      0.105465  0.097751    ...     0.022461
#  Customer and Personal Service  0.036504  0.042810    ...     0.064334
#  Design                        -0.023069 -0.039446    ...    -0.040758
#  Economics and Accounting       0.016464 -0.007469    ...    -0.011496
#  Education and Training         0.035373  0.016012    ...     0.003390
#  Engineering and Technology     0.025838  0.055597    ...     0.119023
#  English Language               0.213488  0.219678    ...     0.160585
#  Fine Arts                     -0.052962  0.003873    ...     0.001118
#  Food Production                0.077529  0.069087    ...     0.053753
#  Foreign Language              -0.333467 -0.362175    ...    -0.406328
#  Geography                     -0.082975 -0.091188    ...    -0.124516
#  History and Archeology         0.092046  0.082693    ...     0.131618
#  Law and Government            -0.116976 -0.152115    ...    -0.153807
#  Mathematics                   -0.017896 -0.029670    ...    -0.006608
#  Mechanical                    -0.103963 -0.141220    ...    -0.095971
#  Medicine and Dentistry        -0.036371 -0.068078    ...    -0.006032
#  Personnel and Human Resources -0.050388  0.006398    ...    -0.020813
#  Philosophy and Theology        0.032708 -0.003229    ...    -0.027117
#  Physics                        0.192115  0.188028    ...     0.136080
#  Production and Processing      0.076040  0.045174    ...     0.037530
#  Psychology                    -0.070034 -0.027654    ...    -0.039379
#  Public Safety and Security     0.109330  0.140869    ...     0.136976
#  Sales and Marketing            0.089039  0.108522    ...     0.087919
#  Sociology and Anthropology     0.174107  0.175251    ...     0.256256
#  Telecommunications             0.048737  0.031634    ...     0.046392
#  Therapy and Counseling        -0.121303 -0.175056    ...    -0.184633
#  Transportation                 0.035862  0.016437    ...     0.036885
#
#                                  log FTE   log FTE   log FTE   log FTE  \
#  Arm-Hand Steadiness           -0.131582 -0.157529 -0.093290 -0.139092
#  Auditory Attention            -0.279436 -0.329303 -0.367498 -0.334185
#  Category Flexibility           0.747234  0.684364  0.782616  0.706548
#  Control Precision             -0.105275 -0.031168 -0.059769  0.008884
#  Deductive Reasoning            0.036754  0.156285  0.157001  0.294387
#  Depth Perception               0.136080  0.085602  0.093214  0.033603
#  Dynamic Flexibility           -0.048778  0.099640  0.108745  0.208713
#  Dynamic Strength               0.281217  0.190758  0.264107  0.186900
#  Explosive Strength            -0.048730 -0.012004 -0.054710 -0.124537
#  Extent Flexibility            -0.053803 -0.039558 -0.018530  0.027637
#  Far Vision                     0.187206  0.313081  0.169171  0.179012
#  Finger Dexterity              -0.030882  0.091222  0.082650  0.078460
#  Flexibility of Closure        -0.110173 -0.068757 -0.105698 -0.069618
#  Fluency of Ideas              -0.204111 -0.163614 -0.257574 -0.146868
#  Glare Sensitivity              0.008142  0.041089 -0.066320  0.000471
#  Gross Body Coordination        0.181988  0.053232  0.193967  0.180012
#  Gross Body Equilibrium        -0.264562 -0.167746 -0.221799 -0.166461
#  Hearing Sensitivity            0.228665  0.154673  0.222848  0.306177
#  Inductive Reasoning           -0.223962 -0.124138 -0.185800 -0.292408
#  Information Ordering           0.343047  0.273111  0.264646  0.365549
#  Manual Dexterity               0.204384  0.132755  0.124146  0.086749
#  Mathematical Reasoning        -0.257731 -0.218971 -0.276625 -0.173934
#  Memorization                   0.046520  0.083416  0.147042  0.090159
#  Multilimb Coordination         0.075245  0.039660 -0.022018  0.097273
#  Near Vision                    0.654148  0.541041  0.556446  0.498528
#  Night Vision                  -0.237370 -0.225848 -0.257915 -0.233603
#  Number Facility                0.064035  0.045741  0.053301 -0.025623
#  Oral Comprehension             0.636867  0.637255  0.544246  0.513113
#  Oral Expression               -0.169204 -0.142479 -0.016128 -0.124805
#  Originality                    0.145729  0.066705  0.197072  0.128627
#  ...                                 ...       ...       ...       ...
#  Chemistry                     -0
#  Gross Body Equilibrium        -0.149135 -0.153420    ...    -0.240486
#  Hearing Sensitivity            0.254751  0.265384    ...     0.231321
#  Inductive Reasoning           -0.252700 -0.140289    ...    -0.121350
#  Information Ordering           0.322286  0.303962    ...     0.222624
#  Manual Dexterity               0.163681  0.106964    ...     0.100126
#  Mathematical Reasoning        -0.195367 -0.305038    ...    -0.281134
#  Memorization                   0.108055  0.109346    ...     0.141791
#  Multilimb Coordination         0.079549 -0.023068    ...     0.143239
#  Near Vision                    0.604328  0.629276    ...     0.591420
#  Night Vision                  -0.361440 -0.175928    ...    -0.282365
#  Number Facility                0.015085  0.022013    ...     0.004279
#  Oral Comprehension             0.627538  0.444863    ...     0.810019
#  Oral Expression               -0.071440 -0.018660    ...    -0.255651
#  Originality                    0.231470  0.231648    ...     0.007743
#  ...                                 ...       ...    ...          ...
#  Chemistry                     -0.125790 -0.061536    ...    -0.074416
#  Clerical                       0.023202  0.007603    ...    -0.012255
#  Communications and Media      -0.159333 -0.167253    ...    -0.165004
#  Computers and Electronics      0.070858  0.050182    ...     0.057827
#  Customer and Personal Service  0.017730  0.027299    ...     0.072086
#  Design                         0.021016  0.016928    ...     0.071667
#  Economics and Accounting       0.002439  0.017929    ...    -0.023077
#  Education and Training         0.031039  0.047908    ...     0.015712
#  Engineering and Technology     0.152748  0.112559    ...     0.063566
#  English Language               0.134189  0.106189    ...     0.216869
#  Fine Arts                     -0.113209  0.006553    ...    -0.023808
#  Food Production                0.126809  0.074793    ...     0.076775
#  Foreign Language              -0.397713 -0.329623    ...    -0.383717
#  Geography                     -0.037591 -0.122132    ...    -0.051354
#  History and Archeology         0.171007  0.149793    ...     0.038814
#  Law and Government            -0.166515 -0.196603    ...    -0.098946
#  Mathematics                   -0.056713 -0.038999    ...    -0.009384
#  Mechanical                    -0.133304 -0.115484    ...    -0.096313
#  Medicine and Dentistry         0.043517 -0.018506    ...    -0.013572
#  Personnel and Human Resources -0.031162 -0.018695    ...    -0.064395
#  Philosophy and Theology       -0.076912 -0.096774    ...    -0.001247
#  Physics                        0.158854  0.161673    ...     0.146801
#  Production and Processing      0.008901  0.022079    ...     0.062606
#  Psychology                    -0.051037  0.022803    ...    -0.049795
#  Public Safety and Security     0.165602  0.166024    ...     0.106141
#  Sales and Marketing            0.122779  0.080224    ...     0.070841
#  Sociology and Anthropology     0.203301  0.179393    ...     0.196953
#  Telecommunications            -0.006445  0.036307    ...     0.039029
#  Therapy and Counseling        -0.123910 -0.210346    ...    -0.183730
#  Transportation                -0.010194 -0.015192    ...    -0.013280
#
#                                  log FTE   log FTE   log FTE   log FTE  \
#  Arm-Hand Steadiness           -0.122493 -0.162034 -0.100181 -0.135363
#  Auditory Attention            -0.342045 -0.439739 -0.286320 -0.309005
#  Category Flexibility           0.693887  0.691280  0.724017  0.795454
#  Control Precision              0.051529 -0.000881  0.094708 -0.107739
#  Deductive Reasoning            0.219558  0.149339  0.007303  0.200000
#  Depth Perception               0.025404  0.019564  0.107611  0.061511
#  Dynamic Flexibility           -0.004273  0.094651  0.045089  0.152246
#  Food Production                0.067500  0.082618  0.042720  0.059894
#  Foreign Language              -0.347015 -0.347435 -0.352625 -0.370342
#  Geography                     -0.061448 -0.054039 -0.058540 -0.064679
#  History and Archeology         0.018289  0.024983  0.011890  0.013169
#  Law and Government            -0.189804 -0.112111 -0.107457 -0.151460
#  Mathematics                   -0.039988 -0.013904  0.004805 -0.080188
#  Mechanical                    -0.086341 -0.137800 -0.083224 -0.074818
#  Medicine and Dentistry        -0.026828  0.031597 -0.025534  0.006741
#  Personnel and Human Resources -0.019798 -0.038538 -0.001137  0.004560
#  Philosophy and Theology       -0.012343  0.022502  0.050194  0.022654
#  Physics                        0.123920  0.142355  0.199990  0.150086
#  Production and Processing      0.048945  0.078822  0.041687  0.025792
#  Psychology                     0.006128 -0.052551 -0.073032 -0.065609
#  Public Safety and Security     0.151800  0.111407  0.119394  0.159003
#  Sales and Marketing            0.055531  0.089465  0.121648  0.082384
#  Sociology and Anthropology     0.199322  0.224243  0.176273  0.212307
#  Telecommunications             0.063496  0.004667  0.067676  0.033993
#  Therapy and Counseling        -0.262371 -0.198126 -0.139163 -0.204123
#  Transportation                -0.009884  0.003799  0.006911  0.043544
#
#                                  log FTE
#  Arm-Hand Steadiness           -0.174832
#  Auditory Attention            -0.343149
#  Category Flexibility           0.771945
#  Control Precision             -0.038698
#  Deductive Reasoning            0.183805
#  Depth Perception               0.079961
#  Dynamic Flexibility           -0.056764
#  Dynamic Strength               0.259833
#  Explosive Strength            -0.050526
#  Extent Flexibility            -0.075737
#  Far Vision                     0.182573
#  Finger Dexterity               0.047493
#  Flexibility of Closure        -0.139046
#  Fluency of Ideas              -0.380908
#  Glare Sensitivity              0.024279
#  Gross Body Coordination       -0.034232
#  Gross Body Equilibrium        -0.111232
#  Hearing Sensitivity            0.227942
#  Inductive Reasoning           -0.147938
#  Information Ordering           0.265790
#  Manual Dexterity               0.074605
#  Mathematical Reasoning        -0.328822
#  Memorization                   0.087753
#  Multilimb Coordination         0.072287
#  Near Vision                    0.543976
#  Night Vision                  -0.302573
#  Number Facility                0.104859
#  Oral Comprehension             0.563371
#  Oral Expression               -0.020262
#  Originality                    0.340439
#  ...                                 ...
#  Chemistry                     -0.095962
#  Clerical                      -0.021579
#  Communications and Media      -0.273504
#  Computers and Electronics      0.092059
#  Customer and Personal Service  0.053909
#  Design                         0.030126
#  Economics and Accounting      -0.008050
#  Education and Training         0.078941
#  Engineering and Technology     0.073362
#  English Language               0.211864
#  Fine Arts                      0.008223
#  Food Production                0.101623
#  Foreign Language              -0.427408
#  Geography                     -0.052762
#  History and Archeology         0.044864
#  Law and Government            -0.143320
#  Mathematics                   -0.098174
#  Mechanical                    -0.081978
#  Medicine and Dentistry         0.041217
#  Personnel and Human Resources -0.028871
#  Philosophy and Theology       -0.040661
#  Physics                        0.182263
#  Production and Processing      0.060032
#  Psychology                    -0.060897
#  Public Safety and Security     0.143226
#  Sales and Marketing            0.098818
#  Sociology and Anthropology     0.239162
#  Telecommunications             0.056899
#  Therapy and Counseling        -0.199995
#  Transportation                 0.020781
#
#  [120 rows x 100 columns]}

# %%
def fnn(n):
    return fin[:n].std().max()

# %%
fin.mean().sort_values(ascending=False)
# Out:
# log FTE    0.025868
# log FTE    0.025845
# log FTE    0.025757
# log FTE    0.025752
# log FTE    0.025675
# log FTE    0.025591
# log FTE    0.025575
# log FTE    0.025559
# log FTE    0.025519
# log FTE    0.025448
# log FTE    0.025434
# log FTE    0.025408
# log FTE    0.025376
# log FTE    0.025328
# log FTE    0.025319
# log FTE    0.025316
# log FTE    0.025315
# log FTE    0.025314
# log FTE    0.025307
# log FTE    0.025285
# log FTE    0.025271
# log FTE    0.025250
# log FTE    0.025247
# log FTE    0.025209
# log FTE    0.025207
# log FTE    0.025189
# log FTE    0.025182
# log FTE    0.025153
# log FTE    0.025152
# log FTE    0.025151
#              ...
# log FTE    0.021672
# log FTE    0.021663
# log FTE    0.021653
# log FTE    0.021645
# log FTE    0.021636
# log FTE    0.021629
# log FTE    0.021623
# log FTE    0.021610
# log FTE    0.021594
# log FTE    0.021583
# log FTE    0.021579
# log FTE    0.021576
# log FTE    0.021543
# log FTE    0.021539
# log FTE    0.021523
# log FTE    0.021513
# log FTE    0.021501
# log FTE    0.021486
# log FTE    0.021473
# log FTE    0.021460
# log FTE    0.021412
# log FTE    0.021377
# log FTE    0.021360
# log FTE    0.021270
# log FTE    0.021262
# log FTE    0.021259
# log FTE    0.021217
# log FTE    0.021160
# log FTE    0.021073
# log FTE    0.020319
# Length: 2000, dtype: float64

# %%
plt.scatter(x=range(len(fin)),y=[fnn(n) for n in range(len(fin))])

# %%
dall
# Out:
#             Arm-Hand Steadiness  Auditory Attention  Category Flexibility  \
# SOCP_shave
# 111011                 0.000000            1.870000              3.870000
# 111021                 1.500000            2.000000              3.000000
# 112011                 0.500000            1.250000              3.880000
# 112021                 0.120000            1.620000              3.620000
# 112022                 0.500000            1.880000              3.620000
# 112031                 0.000000            1.500000              3.380000
# 113011                 2.000000            2.250000              3.120000
# 113021                 2.000000            1.750000              3.120000
# 113031                 0.125000            1.560000              3.560000
# 113051                 2.500000            2.875000              3.458333
# 113061                 0.000000            1.880000              3.750000
# 113071                 1.250000            2.040000              3.460000
# 113111                 0.500000            1.000000              3.000000
# 113121                 0.500000            1.620000              3.750000
# 113131                 0.880000            2.000000              3.620000
# 119013                 2.790000            2.420000              3.456667
# 119021                 0.620000            3.000000              3.500000
# 119031                 1.880000            2.000000              3.120000
# 119032                 0.500000            2.120000              4.000000
# 119033                 0.120000            1.380000              3.750000
# 119039                 1.560000            2.130000              3.380000
# 119041                 2.125000            2.375000              3.815000
# 119051                 2.880000            2.620000              3.120000
# 119061                 2.120000            1.750000              3.000000
# 119071                 0.620000            2.750000              3.250000
# 119081                 2.250000            2.000000              3.000000
# 119111                 0.880000            2.000000              3.250000
# 119121                 0.000000            1.916667              3.623333
# 119131                 0.380000            2.120000              3.000000
# 119141                 0.000000            1.380000              3.120000
# ...                         ...                 ...                   ...
# 534021                 2.630000            3.500000              2.630000
# 534031                 2.880000            3.880000              3.120000
# 534041                 2.750000            3.500000              2.630000
# 535011                 3.120000            3.880000              3.000000
# 535021                 3.123333            3.246667              3.126667
# 535022                 3.130000            3.380000              2.630000
# 535031                 3.250000            3.380000              3.250000
# 536011                 2.500000            2.750000              2.630000
# 536021                 2.120000            2.250000              2.620000
# 536031                 3.000000            2.750000              2.380000
# 536041                 2.500000            2.380000              3.250000
# 536051                 2.833333            2.790000              3.170000
# 536061                 2.120000            2.380000              2.880000
# 537011                 3.120000            3.000000              3.000000
# 537021                 3.120000            2.880000              2.500000
# 537031                 3.120000            3.380000              2.250000
# 537032                 3.120000            4.120000              2.880000
# 537033                 3.250000            2.750000              3.120000
# 537041                 2.630000            2.880000              2.630000
# 537051                 2.880000            3.000000              2.380000
# 537061                 2.500000            1.000000              2.120000
# 537062                 3.000000            2.250000              2.620000
# 537063                 3.250000            2.750000              2.880000
# 537064                 2.250000            1.500000              2.380000
# 537071                 3.120000            3.000000              3.000000
# 537072                 3.000000            3.500000              3.130000
# 537073                 2.500000            2.750000              3.130000
# 537081                 2.380000            2.120000              2.750000
# 537111                 2.000000            2.250000              1.500000
# 537121                 2.630000            3.380000              2.750000
#
#             Control Precision  Deductive Reasoning  Depth Perception  \
# SOCP_shave
# 111011               1.185000             4.750000          1.690000
# 111021               1.380000             3.750000          1.880000
# 112011               0.120000             4.500000          1.000000
# 112021               0.000000             4.380000          0.750000
# 112022               0.880000             4.380000          1.000000
# 112031               0.000000             4.120000          0.880000
# 113011               1.750000             3.880000          1.620000
# 113021               2.000000             4.000000          1.120000
# 113031               0.190000             4.440000          0.310000
# 113051               2.500000             3.981667          2.250000
# 113061               0.000000             4.000000          1.000000
# 113071               1.336667             3.956667          1.460000
# 113111               0.380000             3.380000          0.000000
# 113121               0.250000             4.120000          0.750000
# 113131               0.750000             4.250000          0.620000
# 119013               3.083333             3.833333          2.376667
# 119021               1.880000             4.000000          2.750000
# 119031               0.500000             4.120000          0.880000
# 119032               0.000000             4.500000          0.880000
# 119033               0.000000             4.000000          0.120000
# 119039               0.935000             4.190000          1.370000
# 119041               2.375000             4.380000          2.060000
# 119051               2.250000             3.500000          1.620000
# 119061               2.000000             3.120000          2.000000
# 119071               0.000000             4.000000          1.750000
# 119081               2.000000             3.880000          1.880000
# 119111               0.750000             4.000000          1.380000
# 119121               0.666667             4.293333          1.380000
# 119131               0.500000             3.250000          1.750000
# 119141               1.000000             3.880000          1.500000
# ...                       ...                  ...               ...
# 534021               3.630000             2.750000          2.880000
# 534031               3.120000             3.750000          3.000000
# 534041               3.750000             3.250000          3.000000
# 535011               3.750000             3.000000          3.880000
# 535021               3.916667             3.710000          3.583333
# 535022               4.130000             3.000000          3.380000
# 535031               3.880000             3.750000          2.250000
# 536011               3.380000             2.750000          3.000000
# 536021               2.880000             2.500000          2.750000
# 536031               3.000000             2.500000          2.250000
# 536041               2.620000             3.880000          2.000000
# 537062                 1.000000          2.750000            0.880000
# 537063                 0.380000          2.120000            1.120000
# 537064                 0.500000          2.250000            0.500000
# 537071                 0.000000          1.880000            1.120000
# 537072                 0.250000          2.250000            0.000000
# 537073                 0.750000          2.500000            0.380000
# 537081                 0.250000          2.250000            0.500000
# 537111                 0.630000          1.500000            0.750000
# 537121                 0.380000          2.750000            0.130000
#
#             Extent Flexibility       ...        Philosophy and Theology  \
# SOCP_shave                           ...
# 111011                0.000000       ...                       2.120000
# 111021                0.500000       ...                       0.870000
# 112011                0.000000       ...                       2.110000
# 112021                0.000000       ...                       1.120000
# 112022                0.000000       ...                       1.220000
# 112031                0.000000       ...                       2.130000
# 113011                0.750000       ...                       1.310000
# 113021                0.000000       ...                       0.690000
# 113031                0.000000       ...                       0.715000
# 113051                1.166667       ...                       1.208333
# 113061                0.000000       ...                       0.900000
# 113071                0.626667       ...                       1.596667
# 113111                0.000000       ...                       0.950000
# 113121                0.000000       ...                       2.670000
# 113131                0.000000       ...                       2.040000
# 119013                2.166667       ...                       1.313333
# 119021                0.380000       ...                       0.640000
# 119031                1.120000       ...                       2.880000
# 119032                0.620000       ...                       3.670000
# 119033                0.000000       ...                       3.080000
# 119039                1.440000       ...                       1.735000
# 119041                0.560000       ...                       0.695000
# 119051                2.120000       ...                       1.540000
# 119061                0.880000       ...                       4.130000
# 119071                0.380000       ...                       1.360000
# 119081                1.380000       ...                       2.550000
# 119111                0.000000       ...                       1.150000
# 119121                0.000000       ...                       0.833333
# 119131                0.500000       ...                       1.310000
# 119141                0.000000       ...                       1.650000
# ...                        ...       ...                            ...
# 534021                3.630000       ...                       0.400000
# 534031                2.750000       ...                       1.130000
# 534041                1.380000       ...                       0.980000
# 535011                3.380000       ...                       0.590000
# 535021                2.540000       ...                       0.983333
# 535022                3.380000       ...                       1.150000
# 535031                3.500000       ...                       0.470000
# 536011                1.880000       ...                       0.790000
# 536021                2.620000       ...                       0.660000
# 536031                3.380000       ...                       0.690000
# 536041                1.120000       ...                       0.500000
# 536051                2.453333       ...                       0.550000
# 536061                2.120000       ...                       1.170000
# 537011                3.000000       ...                       0.030000
# 537021                2.620000       ...                       0.350000
# 537031                1.880000       ...                       0.260000
# 537032                2.880000       ...                       0.580000
# 537033                3.380000       ...                       1.140000
# 537041                3.500000       ...                       0.120000
# 537051                3.000000       ...                       0.400000
# 537061                3.120000       ...                       0.770000
# 537062                3.620000       ...                       0.460000
# 537063                2.750000       ...                       0.820000
# 537064                2.880000       ...                       1.090000
# 537071                2.250000       ...                       0.320000
# 537072                3.250000       ...                       2.030000
# 537073                3.250000       ...                       0.580000
# 537081                2.750000       ...                       0.290000
# 537111                3.130000       ...                       0.600000
# 537121                3.630000       ...                       0.080000
#
#              Physics  Production and Processing  Psychology  \
# SOCP_shave
# 111011      1.685000                   2.635000    3.590000
# 111021      1.410000                   4.340000    2.780000
# 112011      0.490000                   2.680000    2.740000
# 112021      0.370000                   2.920000    2.860000
# 112022      0.910000                   3.090000    2.950000
# 537061                        0.890000            1.150000
# 537062                        0.520000            0.410000
# 537063                        0.860000            1.070000
# 537064                        0.900000            0.950000
# 537071                        0.200000            1.030000
# 537072                        1.590000            1.460000
# 537073                        0.640000            1.400000
# 537081                        0.590000            1.330000
# 537111                        0.200000            0.300000
# 537121                        0.170000            0.280000
#
#             Therapy and Counseling  Transportation
# SOCP_shave
# 111011                    1.520000        2.195000
# 111021                    1.480000        2.310000
# 112011                    1.420000        1.590000
# 112021                    1.100000        1.530000
# 112022                    1.040000        2.130000
# 112031                    1.540000        1.010000
# 113011                    1.390000        1.410000
# 113021                    0.780000        0.410000
# 113031                    0.980000        1.070000
# 113051                    1.688333        2.365000
# 113061                    0.760000        2.810000
# 113071                    2.206667        4.686667
# 113111                    1.810000        0.380000
# 113121                    3.710000        0.880000
# 113131                    2.070000        1.070000
# 119013                    1.233333        3.310000
# 119021                    0.840000        2.440000
# 119031                    2.830000        2.060000
# 119032                    3.680000        1.950000
# 119033                    3.460000        1.620000
# 119039                    2.010000        1.075000
# 119041                    0.985000        2.390000
# 119051                    2.270000        1.690000
# 119061                    2.880000        2.180000
# 119071                    1.790000        1.150000
# 119081                    2.030000        2.000000
# 119111                    1.760000        0.460000
# 119121                    1.096667        1.843333
# 119131                    2.020000        3.650000
# 119141                    1.230000        1.380000
# ...                            ...             ...
# 534021                    0.800000        4.260000
# 534031                    1.800000        4.130000
# 534041                    0.890000        4.450000
# 535011                    0.560000        2.930000
# 535021                    1.316667        4.770000
# 535022                    1.280000        3.480000
# 535031                    0.580000        3.950000
# 536011                    1.140000        2.430000
# 536021                    0.710000        2.440000
# 536031                    0.460000        1.410000
# 536041                    0.600000        4.230000
# 536051                    0.626667        3.820000
# 536061                    1.210000        3.750000
# 537011                    0.080000        2.200000
# 537021                    1.030000        3.420000
# 537031                    0.330000        1.830000
# 537032                    0.620000        2.130000
# 537033                    1.250000        2.730000
# 537041                    0.460000        2.570000
# 537051                    0.380000        2.690000
# 537061                    0.810000        2.780000
# 537062                    0.540000        2.460000
# 537063                    0.700000        1.910000
# 537064                    0.660000        0.820000
# 537071                    0.750000        1.640000
# 537072                    1.730000        2.570000
# 537073                    0.690000        2.500000
# 537081                    0.980000        4.190000
# 537111                    0.370000        2.490000
# 537121                    0.190000        3.980000
#
# [773 rows x 120 columns]

# %% [markdown]
# ## WITH TRAIN TEST SPLIT

# %%
Xy = pd.merge(workers[['SOCP','DEAR','DEYE','log FTE']],dall,right_index = True, left_on='SOCP')
X = (Xy.drop(['SOCP','DEAR','DEYE','log FTE'],axis = 1))
y = (Xy[['log FTE']])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

def sampler(X_train,y_train,n=10000):
    aaa = y_train.sample(10).index
    return (X_train.loc[aaa],y_train.loc[aaa])   

def lsa(X,y):
    xtx = X.T @ X
    xty = X.T @ y
    xtx_inv = pd.DataFrame(np.linalg.pinv(xtx.values), xtx.columns, xtx.index)
    k = xtx_inv @ xty
    return k

# %% [markdown]
# # CHECK CATEGORIES

# %%
datadic

# %%
1+1
# Out:
# 2
