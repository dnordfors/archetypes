# %%
#%%
# path to working directory
path = '/Users/davidnordfors/galvanize/galvanize-capstone/final'

# IMPORT LIBRARIES
## OS
import os
os.chdir(path)

# MANAGE
import pandas as pd
import numpy as np
#from collections import Counter
from boolma import BM

## FIT
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

## DECOMPOSITION
from sklearn.decomposition import NMF
from scipy.linalg import svd

## GRAPHICS
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})

def dist_boxplot(x, **kwargs):
    ax = sns.distplot(x, hist_kws=dict(alpha=0.2))
    ax2 = ax.twinx()
    sns.boxplot(x=x, ax=ax2)
    ax2.set(ylim=(-5, 5))


#%% DATA
## I/O
import zipfile
import requests
import pickle

# Normalization function
def norm(vec):
    return (vec-vec.mean())/vec.std()

# READ O*NET DATABASE. Search order: Dictionary, Pickle, Excel; Create dictionary/pickle if non-existent.
onet = {}
def from_onet(qualities):
        if qualities in onet:
                return onet[qualities]
        pickle_exists = os.path.isfile('./data/pickle/'+qualities+'.pkl')
        if pickle_exists:
                onet[qualities] = pd.read_pickle('./data/pickle/'+qualities+'.pkl')
                return onet[qualities]
        else: 
                onet[qualities]= pd.read_excel(
                        zipfile.ZipFile('./data/db_23_2_excel.zip').extract(
                        'db_23_2_excel/'+qualities+'.xlsx'))
                onet[qualities].to_pickle('./data/pickle/'+qualities+'.pkl')
                return onet[qualities]


# format and Strip O*NET SOC occupation codes to match the ones used by Census PUMS
def soc(socc):
    code = str(socc).replace('-','')
    return code[:5]

# CENSUS DATA: 
#%% PUMS Data dictionary
#Source: https://www.census.gov/programs-surveys/acs/data/pums.html )
datadic = pd.read_csv("./data/PUMS_Data_Dictionary_2017.csv").drop_duplicates()

# rows including the string 'word'
def var_about(word):
    return pd.concat((BM(datadic).select('Record Type', 'contains',word).df,
                      BM(datadic).select('Unnamed: 6', 'contains',word).df))

# Name of occupation for SOCP number
def socp_name(socc):
    return datadic[datadic['Record Type']== str(socc)]['Unnamed: 6'].values[0]

tits = from_onet('Alternate Titles')
all_SOCP = set(tits['O*NET-SOC Code'])


def lookup_title(socc):
    soccn = socc[:2]+'-'+socc[2:]+'.00'
    if soccn in all_SOCP:
        return tits[tits['O*NET-SOC Code']== soccn].iloc[0].get('Title')
    else:
        return 'NaN'
        
#%% select workers in ages 40 - 65 and discard the occupations with large standard deviations.
all_workers = pd.read_pickle('data/pickle/pums_California.pkl')
workers = BM(all_workers).select(
            'AGEP','gt',40).select(
            'AGEP','lt',65).df
workers['log FTE'] = workers['FTE wage'].apply(np.log)
foo = workers.groupby('SOCP') 
all_occupations = foo.mean()[['AGEP', 'FTE wage','log FTE']]
all_occupations['count'] = foo.count()['AGEP']
all_occupations['std log FTE'] = foo.std()['log FTE']
all_occupations['SOCP'] = all_occupations.index
all_occupations['SOCP_shave'] = all_occupations['SOCP'].apply(soc)
all_occupations['Occupation'] = all_occupations['SOCP']
occupations = all_occupations[all_occupations['std log FTE']<0.50]

#%%  CREATE X:features from O*NET; and y: mean wages from census/pums

def matrix(features):
    # Build X: occupation/feature matrix from O*NET
    foo = pd.get_dummies(features['Element Name']) 
    occ_features = features[['O*NET-SOC Code']].join(foo.multiply(features['Data Value'],axis = "index")).groupby('O*NET-SOC Code').sum()
    occ_features['SOCP'] = occ_features.index
    occ_features['SOCP_shave']=occ_features['SOCP'].apply(soc)
    # Group by census/PUMS SOC codes (SOCP_shave)
    occ_features_compounded= occ_features.groupby('SOCP_shave').mean()
    occ_features_compounded['SOCP_shave'] = occ_features_compounded.index   
    foo = occ_features_compounded.drop(columns='SOCP_shave')
    return foo

def xy(features,occupations):
    #Normalizes occupation matrix
    #foo = matrix(features)
    foo = features
    occ_features_norm = (foo - foo.mean())/foo.std()
    

    # Normalize y:  Census/PUMS log FTE wages   
    foo = occupations[['SOCP_shave','Occupation','FTE wage','log FTE']].copy()
    foo['log FTE'] =norm(occupations['log FTE'])

    # Merge and align X & y for occupations
    fit_data = foo.merge(occ_features_norm,left_on='SOCP_shave',right_index=True)
    
    # Return X & y
    y = fit_data['log FTE']
    X = fit_data.drop(columns = ['SOCP_shave', 'Occupation', 'FTE wage', 'log FTE'])
    return (X,y)


    # Normalize y:  Census/PUMS log FTE wages   
    foo = occupations[['SOCP_shave','Occupation','FTE wage','log FTE']].copy()
    foo['log FTE'] =norm(occupations['log FTE'])

    # Merge and align X & y for occupations
    fit_data = foo.merge(occ_features_norm,left_on='SOCP_shave',right_index=True)
    
    # Return X & y
    y = fit_data['log FTE']
    X = fit_data.drop(columns = ['SOCP_shave', 'Occupation', 'FTE wage', 'log FTE'])
    return (X,y)


# SELECT FEATURE SETS FROM O*NET, FIT FOR O*NET FTE WAGES 

# Prepare feature sets.
def prepare(df):
    # For Abilities, Knowledge, Skills
    if 'LV' in set(df['Scale ID']):
        sid = 'LV'
    # For Interests
    elif 'OI' in set(df['Scale ID']):
        sid = 'OI'
    df = df[df['Scale ID'] == sid]

    return df[['O*NET-SOC Code','Element Name','Data Value']]
    

dab = prepare(from_onet('Abilities'))
dkn = prepare(from_onet('Knowledge'))
dsk = prepare(from_onet('Skills'))
din = prepare(from_onet('Interests'))

featurenames = ['Abilities','Knowledge','Skills','Interests']

# Put them all together in one big feature matrix
dall = pd.concat([matrix(dab),matrix(dsk),matrix(dkn)],axis = 1)

#%% MODEL & FIT


# CLUSTER FEATURES INTO OCCUPATION CATEGORIES
# Use non-zero matrix factorization for clustering
# Use singular value decomposition first state for determining overall similarity

# %%
class OnetCluster:
    def __init__(self,X,n):
        self.X = X
        self.model = NMF(n_components=n, init='random', random_state=0, max_iter = 1000, tol = 0.0000001)
        self.w = self.model.fit_transform(X)
        self.o = pd.DataFrame(self.w,index=X.index)
        self.on = nrmcol(self.o.T).T
        self.ont = self.on.reset_index()['SOCP_shave'].apply(lookup_title)
        self.h = self.model.components_
        self.f = pd.DataFrame(self.h,columns=X.columns)
        self.fn = nrmcol(self.f.T).T
        
    


class Svd:
    def __init__(self,X):
        self.u,self.s,self.vt = svd(np.array(X))
        self.f = pd.DataFrame(self.vt,columns=X.columns)
        self.o = pd.DataFrame(self.u,columns=X.index)
        
def nrmcol(df):
    return df / np.sqrt(np.diagonal(df.T @ df))

# %%
#Select PUMS data for occupations in an OnetCluster. 
#Default threshold set to 0.7: only occupations with at least 0.49 of their weight in the cluster are included. 

def clocc(n_order,m_cluster,thresh = 0.7):
    soccs = clcat[n_order][m_cluster][clcat[n_order][m_cluster] > thresh]
    cloccs = soccs.merge(occupations,left_index=True, right_index=True).dropna()
    return cloccs


# Create the matrix of all features




reg_ridge = linear_model.Ridge(alpha=.5)
rf = RandomForestRegressor(n_estimators=40,
                           max_features='auto',
                           random_state=0)

featuresets = [OnetCluster(dall,i).o for i in [6]]


Xt={}
yt = {}
test_fit={}
coefs = {}
for ft in range(len(featuresets)):
    test_fit[ft] = {}
    coefs[ft] = {}
    X, y = xy(featuresets[ft],occupations)
    for sed in range(2000):      
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
        Xt[ft],yt[ft]=X_test,y_test
        res = cross_validate(reg_ridge,X_train, y_train, cv=3, return_estimator=True)
        #res = cross_validate(rf,X_train, y_train, cv=n, return_estimator=True)
        #res = cross_validate(lasse,X_train, y_train, cv=n, return_estimator=True)
        test_fit[ft][sed]= [res['estimator'][j].score(X_test,y_test) for j in range(3)]
        coefs[ft][sed]= np.array([res['estimator'][j].coef_ for j in range(3)])
    coefs[ft]['pd'] = pd.DataFrame(np.concatenate(np.array(list(coefs[ft].values()))))

# The coefficients for the n'th featureset fitted above
def coefficients(n):
    return pd.DataFrame([coefs[n]['pd'].mean(),coefs[n]['pd'].std()],index=['mean','std']).T.sort_values('mean',ascending=False)

# In the example above we have only one featureset: OnetCluster(dall,6)
# The entire featurespace has been reduced to 6 dimensions, by NMF clustering
resfeat = coefficients(0).merge(OnetCluster(dall,6).fn,left_index=True,right_index=True)
result_features = {}
for i in range(len(resfeat)):
    result_features[i] = resfeat.iloc[i].sort_values(ascending=False)[:10]

aaa = OnetCluster(dall,6)
bbb = aaa.on.copy()
bbb['SOCP_shave'] = bbb.index
bbb['Title'] = bbb['SOCP_shave'].apply(lookup_title)
aaa.ont = bbb
ccc = aaa.ont.set_index(aaa.ont['Title'])
resocc = coefficients(0).merge(ccc.T,left_index=True,right_index=True)

result_occupations = {}
for i in range(len(result_occupations)):
    result_occupations[i] = resocc.iloc[i].sort_values(ascending=False)[:10]


# The 6 coefficient/dimension correspond to the 6 occupation/feature clusters
# Functions for looking at the clusters:

# %%
aaa = tits[['O*NET-SOC Code','Title']]
aaa['O*NET-SOC Code'] = aaa['O*NET-SOC Code'].apply(soc)
looktit = dict(aaa.values)
def lookup_title(socpnr):
    return looktit[socpnr]
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
occupations.head()
# Out:
#              AGEP      FTE wage    log FTE  count  std log FTE    SOCP  \
# SOCP
# 113061  53.045134  86722.475716  11.255881    709     0.473258  113061
# 113131  51.560811  91069.762397  11.314990    148     0.485071  113131
# 119030  52.216567  83654.857017  11.210956   2849     0.490627  119030
# 119161  50.921053  83786.048845  11.282468     38     0.359862  119161
# 131023  52.773543  65736.095265  10.974031    892     0.453184  131023
#
#        SOCP_shave Occupation
# SOCP
# 113061      11306     113061
# 113131      11313     113131
# 119030      11903     119030
# 119161      11916     119161
# 131023      13102     131023

# %%
df = OnetCluster(matrix(dab),2).on.apply(np.square)
df['Title'] = df.index
df['Title'] = df['Title'].apply(lookup_title)
df.merge(occupations.groupby('SOCP_shave').mean()[['FTE wage','count']].astype(int),left_index = True, right_index=True)
# Out:
#                    0             1  \
# SOCP_shave
# 11306       1.000000  0.000000e+00
# 11313       1.000000  0.000000e+00
# 11903       0.969690  3.031032e-02
# 11916       0.902699  9.730081e-02
# 13102       0.982221  1.777902e-02
# 13103       0.966419  3.358124e-02
# 13104       0.826962  1.730380e-01
# 13108       0.999823  1.767386e-04
# 13113       0.999845  1.550427e-04
# 13114       1.000000  0.000000e+00
# 13115       1.000000  0.000000e+00
# 13202       0.882691  1.173087e-01
# 13203       1.000000  0.000000e+00
# 13204       0.999931  6.906100e-05
# 13208       0.999999  5.053810e-07
# 15112       0.991407  8.593028e-03
# 15113       0.994968  5.032467e-03
# 15114       0.912452  8.754782e-02
# 15115       0.827922  1.720779e-01
# 15203       1.000000  0.000000e+00
# 17102       0.702348  2.976523e-01
# 17201       1.000000  0.000000e+00
# 17204       0.992242  7.758225e-03
# 17205       0.995589  4.410981e-03
# 17206       0.992413  7.587366e-03
# 17207       0.910466  8.953367e-02
# 17208       0.999027  9.727911e-04
# 17211       0.953771  4.622852e-02
# 17213       0.970226  2.977406e-02
# 17214       0.937019  6.298141e-02
# ...              ...           ...
# 51701       0.168165  8.318354e-01
# 51702       0.220977  7.790234e-01
# 51704       0.163559  8.364405e-01
# 51802       0.263307  7.366929e-01
# 51803       0.329169  6.708315e-01
# 51809       0.271270  7.287303e-01
# 51902       0.181017  8.189828e-01
# 51903       0.201162  7.988382e-01
# 51904       0.164383  8.356170e-01
# 51905       0.205432  7.945680e-01
# 51906       0.541624  4.583756e-01
# 51907       0.588864  4.111357e-01
# 51908       0.444287  5.557131e-01
# 51911       0.184553  8.154473e-01
# 51919       0.180206  8.197943e-01
# 53202       0.792708  2.072918e-01
# 53203       0.382279  6.177206e-01
# 53301       0.197541  8.024590e-01
# 53302       0.198966  8.010340e-01
# 53303       0.167579  8.324211e-01
# 53304       0.194145  8.058551e-01
# 53401       0.161665  8.383348e-01
# 53403       0.268383  7.316171e-01
# 53602       0.194582  8.054176e-01
# 53603       0.166038  8.339616e-01
# 53605       0.392520  6.074797e-01
# 53606       0.418032  5.819677e-01
# 53702       0.128487  8.715133e-01
# 53705       0.081859  9.181411e-01
# 53706       0.149276  8.507236e-01
#
#                                                         Title  FTE wage  count
# SOCP_shave
# 11306                                     Purchasing Managers     86722    709
# 11313                       Training and Development Managers     91069    148
# 11903                       Fitness and Wellness Coordinators     83654   2849
# 11916                          Emergency Management Directors     83786     38
# 13102       Purchasing Agents, Except Wholesale, Retail, a...     65736    892
# 13103                       Insurance Appraisers, Auto Damage     66070    805
# 13104                          Regulatory Affairs Specialists     85599    772
# 13108                                      Logistics Analysts     71432    243
# 13113                                             Fundraisers     86382    217
# 13114       Compensation, Benefits, and Job Analysis Speci...     74696    161
# 13115                    Training and Development Specialists     76150    307
# 13202                                 Appraisers, Real Estate     78551    202
# 13203                                         Budget Analysts     78859    176
# 13204                                         Credit Analysts     88143     55
# 13208                                           Tax Preparers     68023    213
# 15112                           Information Security Analysts     99396    853
# 15113                                          Web Developers    107178   2141
# 15114              Telecommunications Engineering Specialists     97026    443
# 15115                    Computer Network Support Specialists     78540   1415
# 15203                            Operations Research Analysts     79976    548
# 17102                                      Geodetic Surveyors     85611     81
# 17201                                     Aerospace Engineers    125841    859
# 17204                                      Chemical Engineers    122719    115
# 17205                                Transportation Engineers    110674   1091
# 17206                             Computer Hardware Engineers    127847    332
# 17207       Radio Frequency Identification Device Specialists    126548   1067
# 17208                              Water/Wastewater Engineers    104367    118
# 17211                 Human Factors Engineers and Ergonomists     95578    689
# 17213                                     Materials Engineers     93460    127
# 17214                                    Automotive Engineers     99225    539
# ...                                                       ...       ...    ...
# 51701                      Cabinetmakers and Bench Carpenters     45347     71
# 51702                                     Furniture Finishers     43352     17
# 51704       Woodworking Machine Setters, Operators, and Te...     36054     23
# 51802               Stationary Engineers and Boiler Operators     75125    299
# 51803       Water and Wastewater Treatment Plant and Syste...     71828    250
# 51809                         Hydroelectric Plant Technicians     70310    107
# 51902       Mixing and Blending Machine Setters, Operators...     45591    148
# 51903       Cutting and Slicing Machine Setters, Operators...     34697    116
# 51904       Extruding, Forming, Pressing, and Compacting M...     38640     31
# 51905       Furnace, Kiln, Oven, Drier, and Kettle Operato...     36086     15
# 51906       Inspectors, Testers, Sorters, Samplers, and We...     53868   2044
# 51907                                  Precious Metal Workers     42261     74
# 51908                       Ophthalmic Laboratory Technicians     48199    225
# 51911       Packaging and Filling Machine Operators and Te...     34811    430
# 51919                       Recycling and Reclamation Workers     43528     21
# 53202                         Airfield Operations Specialists    112085     82
# 53203                                       Flight Attendants     58182    289
# 53301       Ambulance Drivers and Attendants, Except Emerg...     33249     20
# 53302                   Bus Drivers, School or Special Client     42571   1251
# 53303                Light Truck or Delivery Services Drivers     44868   7594
# 53304                             Taxi Drivers and Chauffeurs     40712    632
# 53401       Rail Yard Engineers, Dinkey Operators, and Hos...     66843     97
# 53403                     Railroad Conductors and Yardmasters     68511     63
# 53602                                  Parking Lot Attendants     39201    138
# 53603            Automotive and Watercraft Service Attendants     43264     62
# 53605                            Freight and Cargo Inspectors     68008     99
# 53606       Transportation Attendants, Except Flight Atten...     43012     31
# 53702                               Crane and Tower Operators     81537     99
# 53705                  Industrial Truck and Tractor Operators     37942   1061
# 53706                             Packers and Packagers, Hand     37349    952
#
# [252 rows x 5 columns]

# %%
def plo(dd,n):
    df = OnetCluster(matrix(dd),n).on.apply(np.square)
    df['Title'] = df.index
    df['Title'] = df['Title'].apply(lookup_title)
    df = df.merge(occupations.groupby('SOCP_shave').mean()[['FTE wage','count']].astype(int),left_index = True, right_index=True)
    return df

# %%
plo(dab,2)
# Out:
#                    0             1  \
# SOCP_shave
# 11306       1.000000  0.000000e+00
# 11313       1.000000  0.000000e+00
# 11903       0.969690  3.031032e-02
# 11916       0.902699  9.730081e-02
# 13102       0.982221  1.777902e-02
# 13103       0.966419  3.358124e-02
# 13104       0.826962  1.730380e-01
# 13108       0.999823  1.767386e-04
# 13113       0.999845  1.550427e-04
# 13114       1.000000  0.000000e+00
# 13115       1.000000  0.000000e+00
# 13202       0.882691  1.173087e-01
# 13203       1.000000  0.000000e+00
# 13204       0.999931  6.906100e-05
# 13208       0.999999  5.053810e-07
# 15112       0.991407  8.593028e-03
# 15113       0.994968  5.032467e-03
# 15114       0.912452  8.754782e-02
# 15115       0.827922  1.720779e-01
# 15203       1.000000  0.000000e+00
# 17102       0.702348  2.976523e-01
# 17201       1.000000  0.000000e+00
# 17204       0.992242  7.758225e-03
# 17205       0.995589  4.410981e-03
# 17206       0.992413  7.587366e-03
# 17207       0.910466  8.953367e-02
# 17208       0.999027  9.727911e-04
# 17211       0.953771  4.622852e-02
# 17213       0.970226  2.977406e-02
# 17214       0.937019  6.298141e-02
# ...              ...           ...
# 51701       0.168165  8.318354e-01
# 51702       0.220977  7.790234e-01
# 51704       0.163559  8.364405e-01
# 51802       0.263307  7.366929e-01
# 51803       0.329169  6.708315e-01
# 51809       0.271270  7.287303e-01
# 51902       0.181017  8.189828e-01
# 51903       0.201162  7.988382e-01
# 51904       0.164383  8.356170e-01
# 51905       0.205432  7.945680e-01
# 51906       0.541624  4.583756e-01
# 51907       0.588864  4.111357e-01
# 51908       0.444287  5.557131e-01
# 51911       0.184553  8.154473e-01
# 51919       0.180206  8.197943e-01
# 53202       0.792708  2.072918e-01
# 53203       0.382279  6.177206e-01
# 53301       0.197541  8.024590e-01
# 53302       0.198966  8.010340e-01
# 53303       0.167579  8.324211e-01
# 53304       0.194145  8.058551e-01
# 53401       0.161665  8.383348e-01
# 53403       0.268383  7.316171e-01
# 53602       0.194582  8.054176e-01
# 53603       0.166038  8.339616e-01
# 53605       0.392520  6.074797e-01
# 53606       0.418032  5.819677e-01
# 53702       0.128487  8.715133e-01
# 53705       0.081859  9.181411e-01
# 53706       0.149276  8.507236e-01
#
#                                                         Title  FTE wage  count
# SOCP_shave
# 11306                                     Purchasing Managers     86722    709
# 11313                       Training and Development Managers     91069    148
# 11903                       Fitness and Wellness Coordinators     83654   2849
# 11916                          Emergency Management Directors     83786     38
# 13102       Purchasing Agents, Except Wholesale, Retail, a...     65736    892
# 13103                       Insurance Appraisers, Auto Damage     66070    805
# 13104                          Regulatory Affairs Specialists     85599    772
# 13108                                      Logistics Analysts     71432    243
# 13113                                             Fundraisers     86382    217
# 13114       Compensation, Benefits, and Job Analysis Speci...     74696    161
# 13115                    Training and Development Specialists     76150    307
# 13202                                 Appraisers, Real Estate     78551    202
# 13203                                         Budget Analysts     78859    176
# 13204                                         Credit Analysts     88143     55
# 13208                                           Tax Preparers     68023    213
# 15112                           Information Security Analysts     99396    853
# 15113                                          Web Developers    107178   2141
# 15114              Telecommunications Engineering Specialists     97026    443
# 15115                    Computer Network Support Specialists     78540   1415
# 15203                            Operations Research Analysts     79976    548
# 17102                                      Geodetic Surveyors     85611     81
# 17201                                     Aerospace Engineers    125841    859
# 17204                                      Chemical Engineers    122719    115
# 17205                                Transportation Engineers    110674   1091
# 17206                             Computer Hardware Engineers    127847    332
# 17207       Radio Frequency Identification Device Specialists    126548   1067
# 17208                              Water/Wastewater Engineers    104367    118
# 17211                 Human Factors Engineers and Ergonomists     95578    689
# 17213                                     Materials Engineers     93460    127
# 17214                                    Automotive Engineers     99225    539
# ...                                                       ...       ...    ...
# 51701                      Cabinetmakers and Bench Carpenters     45347     71
# 51702                                     Furniture Finishers     43352     17
# 51704       Woodworking Machine Setters, Operators, and Te...     36054     23
# 51802               Stationary Engineers and Boiler Operators     75125    299
# 51803       Water and Wastewater Treatment Plant and Syste...     71828    250
# 51809                         Hydroelectric Plant Technicians     70310    107
# 51902       Mixing and Blending Machine Setters, Operators...     45591    148
# 51903       Cutting and Slicing Machine Setters, Operators...     34697    116
# 51904       Extruding, Forming, Pressing, and Compacting M...     38640     31
# 51905       Furnace, Kiln, Oven, Drier, and Kettle Operato...     36086     15
# 51906       Inspectors, Testers, Sorters, Samplers, and We...     53868   2044
# 51907                                  Precious Metal Workers     42261     74
# 51908                       Ophthalmic Laboratory Technicians     48199    225
# 51911       Packaging and Filling Machine Operators and Te...     34811    430
# 51919                       Recycling and Reclamation Workers     43528     21
# 53202                         Airfield Operations Specialists    112085     82
# 53203                                       Flight Attendants     58182    289
# 53301       Ambulance Drivers and Attendants, Except Emerg...     33249     20
# 53302                   Bus Drivers, School or Special Client     42571   1251
# 53303                Light Truck or Delivery Services Drivers     44868   7594
# 53304                             Taxi Drivers and Chauffeurs     40712    632
# 53401       Rail Yard Engineers, Dinkey Operators, and Hos...     66843     97
# 53403                     Railroad Conductors and Yardmasters     68511     63
# 53602                                  Parking Lot Attendants     39201    138
# 53603            Automotive and Watercraft Service Attendants     43264     62
# 53605                            Freight and Cargo Inspectors     68008     99
# 53606       Transportation Attendants, Except Flight Atten...     43012     31
# 53702                               Crane and Tower Operators     81537     99
# 53705                  Industrial Truck and Tractor Operators     37942   1061
# 53706                             Packers and Packagers, Hand     37349    952
#
# [252 rows x 5 columns]

# %%
def plf(dd,n):
    sns.clustermap(OnetCluster(matrix(dd),n).fn.apply(lambda x: x**2).sort_values(
    1,axis=1,ascending = False).T,figsize=(2*n, 16),method = 'single')
plf(din,2)

# %%
aaa = plo(dab,2).sort_values(0,ascending=False)
aaa.merge(occupations[['FTE wage','count']].astype(int),left_index = True, right_index=True)
# Out:
#                0         1                                              Title  \
# 172011  1.000000  0.000000                                Aerospace Engineers
# 152031  1.000000  0.000000                       Operations Research Analysts
# 433061  1.000000  0.000000                                 Procurement Clerks
# 433051  1.000000  0.000000                     Payroll and Timekeeping Clerks
# 434161  1.000000  0.000000  Human Resources Assistants, Except Payroll and...
# 439111  1.000000  0.000000                         Bioinformatics Technicians
# 291031  1.000000  0.000000                       Dietitians and Nutritionists
# 132031  1.000000  0.000000                                    Budget Analysts
# 131151  1.000000  0.000000               Training and Development Specialists
# 131141  1.000000  0.000000  Compensation, Benefits, and Job Analysis Speci...
# 131023  1.000000  0.000000  Purchasing Agents, Except Wholesale, Retail, a...
# 113131  1.000000  0.000000                  Training and Development Managers
# 113061  1.000000  0.000000                                Purchasing Managers
# 434131  0.999946  0.000054                       Loan Interviewers and Clerks
# 212021  0.999895  0.000105      Directors, Religious Activities and Education
# 232011  0.999870  0.000130                    Paralegals and Legal Assistants
# 131131  0.999808  0.000192                                        Fundraisers
# 435011  0.999806  0.000194                                 Freight Forwarders
# 132041  0.999781  0.000219                                    Credit Analysts
# 132081  0.999764  0.000236   Tax Examiners and Collectors, and Revenue Agents
# 131081  0.999682  0.000318                                 Logistics Analysts
# 439081  0.999636  0.000364                      Proofreaders and Copy Markers
# 433021  0.999503  0.000497                     Billing, Cost, and Rate Clerks
# 273042  0.999500  0.000500                                  Technical Writers
# 433011  0.998893  0.001107                        Bill and Account Collectors
# 172081  0.998723  0.001277                         Water/Wastewater Engineers
# 193051  0.998321  0.001679                        Urban and Regional Planners
# 413041  0.998247  0.001753                                      Travel Agents
# 434031  0.998233  0.001767                                     License Clerks
# 434111  0.998121  0.001879          Interviewers, Except Eligibility and Loan
# ...          ...       ...                                                ...
# 472211  0.202445  0.797555                                Sheet Metal Workers
# 517011  0.198250  0.801750                 Cabinetmakers and Bench Carpenters
# 536031  0.197832  0.802168       Automotive and Watercraft Service Attendants
# 516063  0.195624  0.804376  Textile Knitting and Weaving Machine Setters, ...
# 519041  0.193854  0.806146  Extruding, Forming, Pressing, and Compacting M...
# 517042  0.193145  0.806855  Woodworking Machine Setters, Operators, and Te...
# 517041  0.192871  0.807129  Sawing Machine Setters, Operators, and Tenders...
# 499044  0.188414  0.811586                                        Millwrights
# 514023  0.168988  0.831012  Rolling Machine Setters, Operators, and Tender...
# 519191  0.166972  0.833028     Adhesive Bonding Machine Operators and Tenders
# 514021  0.164379  0.835621  Extruding and Drawing Machine Setters, Operato...
# 519198  0.161522  0.838478                        Helpers--Production Workers
# 332011  0.160194  0.839806                                Forest Firefighters
# 537021  0.157577  0.842423                          Crane and Tower Operators
# 472181  0.154538  0.845462                                            Roofers
# 499098  0.152706  0.847294  Helpers--Installation, Maintenance, and Repair...
# 499096  0.151532  0.848468                                            Riggers
# 474051  0.149369  0.850631                        Highway Maintenance Workers
# 472161  0.148622  0.851378                       Plasterers and Stucco Masons
# 537061  0.141339  0.858661                 Cleaners of Vehicles and Equipment
# 472071  0.138927  0.861073  Paving, Surfacing, and Tamping Equipment Opera...
# 472061  0.137323  0.862677                              Construction Laborers
# 537062  0.135811  0.864189  Laborers and Freight, Stock, and Material Move...
# 359021  0.122818  0.877182                                        Dishwashers
# 474061  0.120222  0.879778  Rail-Track Laying and Maintenance Equipment Op...
# 519197  0.116090  0.883910                                      Tire Builders
# 474031  0.112701  0.887299                                     Fence Erectors
# 472221  0.107922  0.892078                  Structural Iron and Steel Workers
# 537051  0.105337  0.894663             Industrial Truck and Tractor Operators
# 516021  0.103628  0.896372  Pressers, Textile, Garment, and Related Materials
#
#         FTE wage  count
# 172011    125841    859
# 152031     79976    548
# 433061     64098    115
# 433051     52410    510
# 434161     50559    150
# 439111     56719     56
# 291031     67565    208
# 132031     78859    176
# 131151     76150    307
# 131141     74696    161
# 131023     65736    892
# 113131     91069    148
# 113061     86722    709
# 434131     58089    313
# 212021     50039    171
# 232011     70925   1045
# 131131     86382    217
# 435011     49530     55
# 132041     88143     55
# 132081     68023    213
# 131081     71432    243
# 439081     63434     14
# 433021     46531   1038
# 273042     87898    233
# 433011     46322    275
# 172081    104367    118
# 193051    105440    100
# 413041     50775    178
# 434031     54320    240
# 434111     48222    205
# ...          ...    ...
# 472211     59059    229
# 517011     45347     71
# 536031     43264     62
# 516063     19424      3
# 519041     38640     31
# 517042     35904     14
# 517041     36204     32
# 499044     56932     65
# 514023     31235      6
# 519191     37260     10
# 514021     51066      9
# 519198     38841     56
# 332011     81696    577
# 537021     81537     99
# 472181     46086    196
# 499098     36474     29
# 499096     55772     16
# 474051     55635    139
# 472161     43497     89
# 537061     35637    408
# 472071     52950     15
# 472061     47487   2564
# 537062     45103   2737
# 359021     31126    176
# 474061     69375      8
# 519197     37200      6
# 474031     42903     36
# 472221     56387    117
# 537051     37942   1061
# 516021     28259     56
#
# [225 rows x 5 columns]

# %%
occupations.head()
# Out:
#              AGEP      FTE wage    log FTE  count  std log FTE    SOCP  \
# SOCP
# 113061  53.045134  86722.475716  11.255881    709     0.473258  113061
# 113131  51.560811  91069.762397  11.314990    148     0.485071  113131
# 119030  52.216567  83654.857017  11.210956   2849     0.490627  119030
# 119161  50.921053  83786.048845  11.282468     38     0.359862  119161
# 131023  52.773543  65736.095265  10.974031    892     0.453184  131023
#
#        SOCP_shave Occupation
# SOCP
# 113061     113061     113061
# 113131     113131     113131
# 119030     119030     119030
# 119161     119161     119161
# 131023     131023     131023

# %% [markdown]
# # SOLVE WITH BOOSTRAPPED LSA

# %%
Xy = pd.merge(workers[['SOCP','DEAR','DEYE','log FTE']],dall,right_index = True, left_on='SOCP')
X = (Xy.drop(['SOCP','DEAR','DEYE','log FTE'],axis = 1))
y = (Xy[['log FTE']])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

def lsa(Xy):
    X = (Xy.drop(['SOCP','DEAR','DEYE','log FTE'],axis = 1))
    y = (Xy[['log FTE']])
    xtx = X.T @ X
    xty = X.T @ y
    xtx_inv = pd.DataFrame(np.linalg.pinv(xtx.values), xtx.columns, xtx.index)
    k = xtx_inv @ xty
    return k

# %%
res = {}
for i in range(20):
    res[i] = pd.concat([lsa(Xy.sample(10000)) for i in range(100)],axis = 1)

# %%
fin = pd.concat(list(res.values()),axis = 1)
final = pd.concat([fin.T.mean(),fin.T.std()],axis = 1)
final.columns = ['mean','std']
final.sort_values('mean',ascending = False)

y_hat = dall @ final[['mean']]
y_test = Xy.groupby('SOCP').mean()[['log FTE']]

y_final = y_test.merge(y_hat,left_index = True, right_index = True)
y_final.columns = ['test','predict']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-253-a289f04abadc> in <module>()
# ----> 1 fin = pd.concat(list(res.values()),axis = 1)
#       2 final = pd.concat([fin.T.mean(),fin.T.std()],axis = 1)
#       3 final.columns = ['mean','std']
#       4 final.sort_values('mean',ascending = False)
#       5
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     284                        ' only pd.Series, pd.DataFrame, and pd.Panel'
#     285                        ' (deprecated) objs are valid'.format(type(obj)))
# --> 286                 raise TypeError(msg)
#     287
#     288             # consolidate
#
# TypeError: cannot concatenate object of type "<class 'numpy.ndarray'>"; only pd.Series, pd.DataFrame, and pd.Panel (deprecated) objs are valid

# %%
sns.scatterplot(x='predict',y='test',data = y_final)

# %%
def fnn(n):
    return fin[:n].std().max()

# %%
fin.mean().sort_values(ascending=False)
# Out:
# Stamina                              0.321967
# Control Precision                    0.233401
# Glare Sensitivity                    0.194829
# Physics                              0.179887
# Reading Comprehension                0.168712
# Judgment and Decision Making         0.139964
# Rate Control                         0.129095
# Monitoring                           0.127335
# Sales and Marketing                  0.114098
# Personnel and Human Resources        0.110120
# Visual Color Discrimination          0.093877
# Near Vision                          0.089998
# Management of Material Resources     0.087691
# Psychology                           0.085442
# Explosive Strength                   0.085409
# Auditory Attention                   0.083698
# Engineering and Technology           0.080883
# Therapy and Counseling               0.076646
# Problem Sensitivity                  0.075569
# Operations Analysis                  0.075191
# Written Comprehension                0.074406
# Law and Government                   0.074170
# Response Orientation                 0.073761
# Time Management                      0.072174
# Fluency of Ideas                     0.071426
# Inductive Reasoning                  0.071083
# Written Expression                   0.070144
# Installation                         0.067877
# Perceptual Speed                     0.065041
# Number Facility                      0.064075
#                                        ...
# Food Production                     -0.051781
# Information Ordering                -0.051975
# Learning Strategies                 -0.053584
# Dynamic Strength                    -0.058211
# Wrist-Finger Speed                  -0.060145
# Service Orientation                 -0.060881
# Time Sharing                        -0.061323
# Transportation                      -0.070595
# Administration and Management       -0.071593
# Night Vision                        -0.073406
# Oral Expression                     -0.074990
# Chemistry                           -0.076596
# Foreign Language                    -0.083594
# Management of Financial Resources   -0.086631
# English Language                    -0.092317
# Building and Construction           -0.093820
# Speaking                            -0.097763
# Negotiation                         -0.103982
# Visualization                       -0.107691
# Clerical                            -0.110201
# Mathematics                         -0.121625
# Philosophy and Theology             -0.143094
# Active Listening                    -0.152779
# Active Learning                     -0.156686
# Systems Evaluation                  -0.161290
# Finger Dexterity                    -0.173932
# Arm-Hand Steadiness                 -0.187307
# Reaction Time                       -0.221189
# Trunk Strength                      -0.221437
# Spatial Orientation                 -0.257586
# Length: 120, dtype: float64

# %%
plt.scatter(x=range(len(fin)),y=[fnn(n) for n in range(len(fin))])

# %%
dall
# Out:
#             Arm-Hand Steadiness  Auditory Attention  Category Flexibility  \
# SOCP_shave
# 111011                 0.000000            1.870000              3.870000
# 111021                 1.500000            2.000000              3.000000
# 112011                 0.500000            1.250000              3.880000
# 112021                 0.120000            1.620000              3.620000
# 112022                 0.500000            1.880000              3.620000
# 112031                 0.000000            1.500000              3.380000
# 113011                 2.000000            2.250000              3.120000
# 113021                 2.000000            1.750000              3.120000
# 113031                 0.125000            1.560000              3.560000
# 113051                 2.500000            2.875000              3.458333
# 113061                 0.000000            1.880000              3.750000
# 113071                 1.250000            2.040000              3.460000
# 113111                 0.500000            1.000000              3.000000
# 113121                 0.500000            1.620000              3.750000
# 113131                 0.880000            2.000000              3.620000
# 119013                 2.790000            2.420000              3.456667
# 119021                 0.620000            3.000000              3.500000
# 119031                 1.880000            2.000000              3.120000
# 119032                 0.500000            2.120000              4.000000
# 119033                 0.120000            1.380000              3.750000
# 119039                 1.560000            2.130000              3.380000
# 119041                 2.125000            2.375000              3.815000
# 119051                 2.880000            2.620000              3.120000
# 119061                 2.120000            1.750000              3.000000
# 119071                 0.620000            2.750000              3.250000
# 119081                 2.250000            2.000000              3.000000
# 119111                 0.880000            2.000000              3.250000
# 119121                 0.000000            1.916667              3.623333
# 119131                 0.380000            2.120000              3.000000
# 119141                 0.000000            1.380000              3.120000
# ...                         ...                 ...                   ...
# 534021                 2.630000            3.500000              2.630000
# 534031                 2.880000            3.880000              3.120000
# 534041                 2.750000            3.500000              2.630000
# 535011                 3.120000            3.880000              3.000000
# 535021                 3.123333            3.246667              3.126667
# 535022                 3.130000            3.380000              2.630000
# 535031                 3.250000            3.380000              3.250000
# 536011                 2.500000            2.750000              2.630000
# 536021                 2.120000            2.250000              2.620000
# 536031                 3.000000            2.750000              2.380000
# 536041                 2.500000            2.380000              3.250000
# 536051                 2.833333            2.790000              3.170000
# 536061                 2.120000            2.380000              2.880000
# 537011                 3.120000            3.000000              3.000000
# 537021                 3.120000            2.880000              2.500000
# 537031                 3.120000            3.380000              2.250000
# 537032                 3.120000            4.120000              2.880000
# 537033                 3.250000            2.750000              3.120000
# 537041                 2.630000            2.880000              2.630000
# 537051                 2.880000            3.000000              2.380000
# 537061                 2.500000            1.000000              2.120000
# 537062                 3.000000            2.250000              2.620000
# 537063                 3.250000            2.750000              2.880000
# 537064                 2.250000            1.500000              2.380000
# 537071                 3.120000            3.000000              3.000000
# 537072                 3.000000            3.500000              3.130000
# 537073                 2.500000            2.750000              3.130000
# 537081                 2.380000            2.120000              2.750000
# 537111                 2.000000            2.250000              1.500000
# 537121                 2.630000            3.380000              2.750000
#
#             Control Precision  Deductive Reasoning  Depth Perception  \
# SOCP_shave
# 111011               1.185000             4.750000          1.690000
# 111021               1.380000             3.750000          1.880000
# 112011               0.120000             4.500000          1.000000
# 112021               0.000000             4.380000          0.750000
# 112022               0.880000             4.380000          1.000000
# 112031               0.000000             4.120000          0.880000
# 113011               1.750000             3.880000          1.620000
# 113021               2.000000             4.000000          1.120000
# 113031               0.190000             4.440000          0.310000
# 113051               2.500000             3.981667          2.250000
# 113061               0.000000             4.000000          1.000000
# 113071               1.336667             3.956667          1.460000
# 113111               0.380000             3.380000          0.000000
# 113121               0.250000             4.120000          0.750000
# 113131               0.750000             4.250000          0.620000
# 119013               3.083333             3.833333          2.376667
# 119021               1.880000             4.000000          2.750000
# 119031               0.500000             4.120000          0.880000
# 119032               0.000000             4.500000          0.880000
# 119033               0.000000             4.000000          0.120000
# 119039               0.935000             4.190000          1.370000
# 119041               2.375000             4.380000          2.060000
# 119051               2.250000             3.500000          1.620000
# 119061               2.000000             3.120000          2.000000
# 119071               0.000000             4.000000          1.750000
# 119081               2.000000             3.880000          1.880000
# 119111               0.750000             4.000000          1.380000
# 119121               0.666667             4.293333          1.380000
# 119131               0.500000             3.250000          1.750000
# 119141               1.000000             3.880000          1.500000
# ...                       ...                  ...               ...
# 534021               3.630000             2.750000          2.880000
# 534031               3.120000             3.750000          3.000000
# 534041               3.750000             3.250000          3.000000
# 535011               3.750000             3.000000          3.880000
# 535021               3.916667             3.710000          3.583333
# 535022               4.130000             3.000000          3.380000
# 535031               3.880000             3.750000          2.250000
# 536011               3.380000             2.750000          3.000000
# 536021               2.880000             2.500000          2.750000
# 536031               3.000000             2.500000          2.250000
# 536041               2.620000             3.880000          2.000000
# 536051               2.916667             3.333333          2.793333
# 536061               2.120000             2.880000          1.880000
# 537011               3.500000             3.000000          3.120000
# 537021               4.120000             3.000000          4.120000
# 537031               4.000000             2.620000          3.620000
# 537032               4.000000             3.000000          3.880000
# 537033               3.750000             2.620000          3.500000
# 537041               3.880000             2.380000          3.500000
# 537051               4.000000             2.620000          4.000000
# 537061               3.000000             2.250000          2.500000
# 537062               3.250000             2.500000          2.750000
# 537063               3.750000             2.750000          2.620000
# 537064               2.380000             2.380000          2.000000
# 537071               3.120000             3.250000          2.620000
# 537072               3.380000             2.880000          3.000000
# 537073               4.000000             2.880000          2.250000
# 537081               3.120000             2.250000          2.750000
# 537111               4.000000             2.750000          3.380000
# 537121               3.880000             3.000000          3.750000
#
#             Dynamic Flexibility  Dynamic Strength  Explosive Strength  \
# SOCP_shave
# 111011                 0.000000          0.000000            0.000000
# 111021                 0.000000          0.750000            0.750000
# 112011                 0.000000          0.000000            0.000000
# 112021                 0.000000          0.250000            0.000000
# 112022                 0.000000          0.000000            0.000000
# 112031                 0.000000          0.000000            0.000000
# 113011                 0.000000          0.750000            0.750000
# 113021                 0.000000          0.500000            0.000000
# 113031                 0.000000          0.000000            0.000000
# 113051                 0.083333          0.853333            0.208333
# 113061                 0.000000          0.000000            0.000000
# 113071                 0.000000          0.666667            0.206667
# 113111                 0.000000          0.380000            0.000000
# 113121                 0.000000          0.380000            0.000000
# 113131                 0.000000          0.000000            0.000000
# 119013                 0.166667          1.626667            0.373333
# 119021                 0.000000          0.380000            0.000000
# 119031                 0.000000          1.120000            0.620000
# 119032                 0.000000          0.750000            0.620000
# 119033                 0.000000          0.250000            0.000000
# 119039                 1.000000          1.125000            1.190000
# 119041                 0.000000          0.500000            0.000000
# 119051                 0.000000          1.880000            0.880000
# 119061                 0.250000          1.000000            0.250000
# 119071                 0.000000          0.500000            1.000000
# 119081                 0.000000          1.380000            1.000000
# 119111                 0.000000          0.750000            0.000000
# 119121                 0.000000          0.000000            0.000000
# 119131                 0.000000          0.380000            0.750000
# 119141                 0.000000          0.000000            0.000000
# ...                         ...               ...                 ...
# 534021                 0.130000          2.380000            0.380000
# 534031                 0.000000          1.620000            0.000000
# 534041                 0.000000          1.750000            1.750000
# 535011                 0.250000          2.880000            1.380000
# 535021                 0.000000          1.706667            0.790000
# 535022                 0.000000          2.500000            0.380000
# 535031                 0.250000          2.000000            1.000000
# 536011                 0.000000          1.880000            0.130000
# 536021                 0.120000          1.750000            1.620000
# 536031                 0.000000          2.120000            0.880000
# 536041                 0.000000          0.880000            1.000000
# 536051                 0.000000          1.330000            0.083333
# 536061                 0.000000          1.750000            1.880000
# 537011                 0.250000          2.120000            1.380000
# 537021                 0.000000          2.000000            0.500000
# 537031                 0.250000          2.250000            0.380000
# 537032                 0.250000          2.750000            0.250000
# 537033                 0.250000          2.380000            0.380000
# 537041                 0.130000          2.000000            0.130000
# 537051                 0.500000          2.620000            0.620000
# 537061                 0.250000          2.000000            0.000000
# 537062                 1.000000          2.750000            0.880000
# 537063                 0.380000          2.120000            1.120000
# 537064                 0.500000          2.250000            0.500000
# 537071                 0.000000          1.880000            1.120000
# 537072                 0.250000          2.250000            0.000000
# 537073                 0.750000          2.500000            0.380000
# 537081                 0.250000          2.250000            0.500000
# 537111                 0.630000          1.500000            0.750000
# 537121                 0.380000          2.750000            0.130000
#
#             Extent Flexibility       ...        Philosophy and Theology  \
# SOCP_shave                           ...
# 111011                0.000000       ...                       2.120000
# 111021                0.500000       ...                       0.870000
# 112011                0.000000       ...                       2.110000
# 112021                0.000000       ...                       1.120000
# 112022                0.000000       ...                       1.220000
# 112031                0.000000       ...                       2.130000
# 113011                0.750000       ...                       1.310000
# 113021                0.000000       ...                       0.690000
# 113031                0.000000       ...                       0.715000
# 113051                1.166667       ...                       1.208333
# 113061                0.000000       ...                       0.900000
# 113071                0.626667       ...                       1.596667
# 113111                0.000000       ...                       0.950000
# 113121                0.000000       ...                       2.670000
# 113131                0.000000       ...                       2.040000
# 119013                2.166667       ...                       1.313333
# 119021                0.380000       ...                       0.640000
# 119031                1.120000       ...                       2.880000
# 119032                0.620000       ...                       3.670000
# 119033                0.000000       ...                       3.080000
# 119039                1.440000       ...                       1.735000
# 119041                0.560000       ...                       0.695000
# 119051                2.120000       ...                       1.540000
# 119061                0.880000       ...                       4.130000
# 119071                0.380000       ...                       1.360000
# 119081                1.380000       ...                       2.550000
# 119111                0.000000       ...                       1.150000
# 119121                0.000000       ...                       0.833333
# 119131                0.500000       ...                       1.310000
# 119141                0.000000       ...                       1.650000
# ...                        ...       ...                            ...
# 534021                3.630000       ...                       0.400000
# 534031                2.750000       ...                       1.130000
# 534041                1.380000       ...                       0.980000
# 535011                3.380000       ...                       0.590000
# 535021                2.540000       ...                       0.983333
# 535022                3.380000       ...                       1.150000
# 535031                3.500000       ...                       0.470000
# 536011                1.880000       ...                       0.790000
# 536021                2.620000       ...                       0.660000
# 536031                3.380000       ...                       0.690000
# 536041                1.120000       ...                       0.500000
# 536051                2.453333       ...                       0.550000
# 536061                2.120000       ...                       1.170000
# 537011                3.000000       ...                       0.030000
# 537021                2.620000       ...                       0.350000
# 537031                1.880000       ...                       0.260000
# 537032                2.880000       ...                       0.580000
# 537033                3.380000       ...                       1.140000
# 537041                3.500000       ...                       0.120000
# 537051                3.000000       ...                       0.400000
# 537061                3.120000       ...                       0.770000
# 537062                3.620000       ...                       0.460000
# 537063                2.750000       ...                       0.820000
# 537064                2.880000       ...                       1.090000
# 537071                2.250000       ...                       0.320000
# 537072                3.250000       ...                       2.030000
# 537073                3.250000       ...                       0.580000
# 537081                2.750000       ...                       0.290000
# 537111                3.130000       ...                       0.600000
# 537121                3.630000       ...                       0.080000
#
#              Physics  Production and Processing  Psychology  \
# SOCP_shave
# 111011      1.685000                   2.635000    3.590000
# 111021      1.410000                   4.340000    2.780000
# 112011      0.490000                   2.680000    2.740000
# 112021      0.370000                   2.920000    2.860000
# 112022      0.910000                   3.090000    2.950000
# 112031      0.260000                   0.770000    3.270000
# 113011      1.140000                   3.020000    1.990000
# 113021      1.200000                   1.420000    2.270000
# 113031      0.140000                   1.790000    2.930000
# 113051      3.603333                   4.813333    3.228333
# 113061      1.140000                   3.480000    2.000000
# 113071      1.193333                   4.190000    3.406667
# 113111      0.000000                   0.620000    3.100000
# 113121      0.170000                   2.330000    4.040000
# 113131      0.410000                   2.410000    3.740000
# 119013      2.960000                   4.683333    3.040000
# 119021      3.120000                   3.280000    2.790000
# 119031      1.120000                   2.670000    3.440000
# 119032      0.830000                   1.730000    4.710000
# 119033      0.820000                   1.600000    3.700000
# 119039      0.795000                   1.830000    3.510000
# 119041      4.000000                   3.890000    2.290000
# 119051      0.870000                   3.860000    2.850000
# 119061      0.530000                   1.810000    4.610000
# 119071      0.790000                   2.900000    3.720000
# 119081      0.710000                   2.250000    3.740000
# 119111      0.540000                   3.350000    2.730000
# 119121      2.543333                   1.893333    2.566667
# 119131      0.760000                   4.590000    3.410000
# 119141      0.770000                   1.120000    3.150000
# ...              ...                        ...         ...
# 534021      1.420000                   1.660000    2.400000
# 534031      2.250000                   1.840000    2.730000
# 534041      0.820000                   0.700000    2.700000
# 535011      2.560000                   2.010000    1.330000
# 535021      2.693333                   2.433333    3.223333
# 535022      2.230000                   2.080000    2.490000
# 535031      3.460000                   1.780000    2.560000
# 536011      1.210000                   0.860000    2.570000
# 536021      0.710000                   1.930000    1.490000
# 536031      2.400000                   2.460000    1.900000
# 536041      2.370000                   2.050000    1.470000
# 536051      2.660000                   3.450000    2.270000
# 536061      0.630000                   1.260000    2.630000
# 537011      0.680000                   2.940000    1.210000
# 537021      2.770000                   2.470000    1.540000
# 537031      2.220000                   3.260000    0.630000
# 537032      1.580000                   1.510000    1.540000
# 537033      1.870000                   3.070000    1.510000
# 537041      2.190000                   2.420000    0.290000
# 537051      0.950000                   2.860000    0.860000
# 537061      1.420000                   2.420000    1.460000
# 537062      0.720000                   2.200000    1.250000
# 537063      1.110000                   3.430000    1.130000
# 537064      0.880000                   2.330000    1.810000
# 537071      2.430000                   5.110000    1.020000
# 537072      2.770000                   3.840000    2.630000
# 537073      3.590000                   3.420000    1.090000
# 537081      1.570000                   2.430000    1.380000
# 537111      0.870000                   0.990000    1.770000
# 537121      2.460000                   4.750000    2.270000
#
#             Public Safety and Security  Sales and Marketing  \
# SOCP_shave
# 111011                        3.495000             4.370000
# 111021                        3.120000             4.050000
# 112011                        2.190000             5.580000
# 112021                        2.260000             6.050000
# 112022                        1.480000             6.130000
# 112031                        1.690000             5.470000
# 113011                        3.290000             2.000000
# 113021                        1.520000             1.770000
# 113031                        1.845000             2.805000
# 113051                        3.640000             1.811667
# 113061                        2.140000             3.380000
# 113071                        3.980000             3.456667
# 113111                        1.810000             2.240000
# 113121                        3.000000             2.670000
# 113131                        2.070000             3.590000
# 119013                        3.050000             3.756667
# 119021                        3.840000             3.160000
# 119031                        3.420000             3.420000
# 119032                        3.100000             2.500000
# 119033                        2.480000             3.260000
# 119039                        1.900000             3.985000
# 119041                        3.320000             2.685000
# 119051                        3.260000             3.630000
# 119061                        2.710000             2.790000
# 119071                        3.140000             3.540000
# 119081                        3.560000             4.830000
# 119111                        3.350000             1.920000
# 119121                        2.906667             2.273333
# 119131                        4.330000             3.040000
# 119141                        4.230000             3.770000
# ...                                ...                  ...
# 534021                        3.640000             0.920000
# 534031                        4.010000             1.280000
# 534041                        4.200000             0.470000
# 535011                        2.710000             0.700000
# 535021                        4.113333             1.270000
# 535022                        3.330000             2.500000
# 535031                        3.410000             1.090000
# 536011                        4.210000             0.620000
# 536021                        2.580000             1.970000
# 536031                        3.030000             3.490000
# 536041                        3.940000             0.780000
# 536051                        3.453333             1.616667
# 536061                        2.670000             1.440000
# 537011                        2.360000             0.070000
# 537021                        3.000000             0.970000
# 537031                        1.970000             1.070000
# 537032                        3.070000             0.890000
# 537033                        3.330000             1.470000
# 537041                        3.100000             0.330000
# 537051                        3.070000             1.700000
# 537061                        2.250000             1.700000
# 537062                        1.920000             0.850000
# 537063                        2.630000             1.090000
# 537064                        2.170000             1.860000
# 537071                        4.150000             1.150000
# 537072                        3.780000             0.930000
# 537073                        3.160000             0.830000
# 537081                        3.210000             2.540000
# 537111                        2.020000             0.110000
# 537121                        4.520000             1.060000
#
#             Sociology and Anthropology  Telecommunications  \
# SOCP_shave
# 111011                        3.175000            1.200000
# 111021                        1.300000            2.330000
# 112011                        2.770000            1.910000
# 112021                        2.440000            2.560000
# 112022                        1.680000            1.960000
# 112031                        3.250000            1.110000
# 113011                        1.450000            2.190000
# 113021                        1.690000            2.810000
# 113031                        1.870000            1.260000
# 113051                        1.551667            1.775000
# 113061                        1.190000            2.140000
# 113071                        2.150000            2.340000
# 113111                        2.760000            0.430000
# 113121                        3.780000            1.040000
# 113131                        3.890000            1.480000
# 119013                        1.476667            1.226667
# 119021                        1.080000            1.960000
# 119031                        2.790000            0.810000
# 119032                        3.570000            1.660000
# 119033                        2.770000            1.590000
# 119039                        2.915000            2.400000
# 119041                        1.080000            2.155000
# 119051                        1.510000            1.260000
# 119061                        2.920000            1.470000
# 119071                        2.100000            1.910000
# 119081                        2.630000            2.520000
# 119111                        1.920000            1.120000
# 119121                        1.840000            1.383333
# 119131                        1.540000            1.820000
# 119141                        2.150000            1.650000
# ...                                ...                 ...
# 534021                        0.750000            1.810000
# 534031                        1.260000            2.100000
# 534041                        1.530000            2.450000
# 535011                        0.940000            1.340000
# 535021                        1.273333            2.736667
# 535022                        1.810000            2.700000
# 535031                        0.140000            2.560000
# 536011                        0.900000            1.860000
# 536021                        0.840000            1.410000
# 536031                        1.120000            1.620000
# 536041                        0.670000            2.180000
# 536051                        0.850000            1.853333
# 536061                        1.210000            1.150000
# 537011                        0.050000            0.280000
# 537021                        0.620000            1.530000
# 537031                        0.240000            1.020000
# 537032                        0.570000            0.880000
# 537033                        0.800000            1.400000
# 537041                        0.290000            0.630000
# 537051                        0.460000            0.830000
# 537061                        0.890000            1.150000
# 537062                        0.520000            0.410000
# 537063                        0.860000            1.070000
# 537064                        0.900000            0.950000
# 537071                        0.200000            1.030000
# 537072                        1.590000            1.460000
# 537073                        0.640000            1.400000
# 537081                        0.590000            1.330000
# 537111                        0.200000            0.300000
# 537121                        0.170000            0.280000
#
#             Therapy and Counseling  Transportation
# SOCP_shave
# 111011                    1.520000        2.195000
# 111021                    1.480000        2.310000
# 112011                    1.420000        1.590000
# 112021                    1.100000        1.530000
# 112022                    1.040000        2.130000
# 112031                    1.540000        1.010000
# 113011                    1.390000        1.410000
# 113021                    0.780000        0.410000
# 113031                    0.980000        1.070000
# 113051                    1.688333        2.365000
# 113061                    0.760000        2.810000
# 113071                    2.206667        4.686667
# 113111                    1.810000        0.380000
# 113121                    3.710000        0.880000
# 113131                    2.070000        1.070000
# 119013                    1.233333        3.310000
# 119021                    0.840000        2.440000
# 119031                    2.830000        2.060000
# 119032                    3.680000        1.950000
# 119033                    3.460000        1.620000
# 119039                    2.010000        1.075000
# 119041                    0.985000        2.390000
# 119051                    2.270000        1.690000
# 119061                    2.880000        2.180000
# 119071                    1.790000        1.150000
# 119081                    2.030000        2.000000
# 119111                    1.760000        0.460000
# 119121                    1.096667        1.843333
# 119131                    2.020000        3.650000
# 119141                    1.230000        1.380000
# ...                            ...             ...
# 534021                    0.800000        4.260000
# 534031                    1.800000        4.130000
# 534041                    0.890000        4.450000
# 535011                    0.560000        2.930000
# 535021                    1.316667        4.770000
# 535022                    1.280000        3.480000
# 535031                    0.580000        3.950000
# 536011                    1.140000        2.430000
# 536021                    0.710000        2.440000
# 536031                    0.460000        1.410000
# 536041                    0.600000        4.230000
# 536051                    0.626667        3.820000
# 536061                    1.210000        3.750000
# 537011                    0.080000        2.200000
# 537021                    1.030000        3.420000
# 537031                    0.330000        1.830000
# 537032                    0.620000        2.130000
# 537033                    1.250000        2.730000
# 537041                    0.460000        2.570000
# 537051                    0.380000        2.690000
# 537061                    0.810000        2.780000
# 537062                    0.540000        2.460000
# 537063                    0.700000        1.910000
# 537064                    0.660000        0.820000
# 537071                    0.750000        1.640000
# 537072                    1.730000        2.570000
# 537073                    0.690000        2.500000
# 537081                    0.980000        4.190000
# 537111                    0.370000        2.490000
# 537121                    0.190000        3.980000
#
# [773 rows x 120 columns]

# %% [markdown]
# ## WITH TRAIN TEST SPLIT

# %%
Xy = pd.merge(workers[['SOCP','DEAR','DEYE','log FTE']],dall,right_index = True, left_on='SOCP')
X = (Xy.drop(['SOCP','DEAR','DEYE','log FTE'],axis = 1))
y = (Xy[['log FTE']])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

def sampler(X_train,y_train,n=10000):
    aaa = y_train.sample(10).index
    return (X_train.loc[aaa],y_train.loc[aaa])   

def lsa(X,y):
    xtx = X.T @ X
    xty = X.T @ y
    xtx_inv = pd.DataFrame(np.linalg.pinv(xtx.values), xtx.columns, xtx.index)
    k = xtx_inv @ xty
    return k

# %% [markdown]
# # CHECK CATEGORIES

# %%
datadic

# %%
1+1
# Out:
# 2
