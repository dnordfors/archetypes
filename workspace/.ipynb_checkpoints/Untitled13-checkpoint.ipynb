# %%
#%%

# IMPORT LIBRARIES

## OS
import os

# MANAGE
import pandas as pd
import numpy as np

## FIT
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
import xgboost as xgb

from sklearn.metrics import r2_score

## DECOMPOSITION
from sklearn.decomposition import NMF
from scipy.linalg import svd

## GRAPHICS
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})

## I/O
import zipfile
import requests
import pickle

## DOWNLOAD
import urllib.request
from tqdm import tqdm

## NLP
import nltk
lemmatizer = nltk.stem.WordNetLemmatizer()
from nltk.corpus import stopwords
set(stopwords.words('english'))
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')

class DownloadProgressBar(tqdm):
    def update_to(self, b=1, bsize=1, tsize=None):
        if tsize is not None:
            self.total = tsize
        self.update(b * bsize - self.n)

def download_url(url, output_path):
    with DownloadProgressBar(unit='B', unit_scale=True,
                             miniters=1, desc=url.split('/')[-1]) as t:
        urllib.request.urlretrieve(url, filename=output_path, reporthook=t.update_to)


## CREATE PATHS / DIRECTORIES 

# path to home directory (the location of this file)
path0 = !pwd
path = path0.n

os.chdir(path)

#Check if directories exist - creat directories if needed

paths = {}
paths['data'] = './data'
paths['census'] = paths['data'] + '/census'
paths['onet'] = paths['data'] + '/onet'

[os.makedirs(pth, exist_ok=True) for pth in paths.values()]


## GENERAL FUNCTIONS 
### NORMALIZATION
# Statistic normalization - subtract mean, scale by standard deviation
def norm_stat(vec, weights = False):
    '''
    Normalizes a vector v-v.mean())/v.std() 
    '''
    if weights:
        return  np.mean(abs(vec - vec.mean()))  
    return (vec-vec.mean())/vec.std()

# Algebraic normalization - dot product
def norm_dot(vec, weights = False):
    '''
    Normalizes the columns of a DataFrame (dot product)
    '''
    if weights:
        return  np.sqrt(vec @ vec)
    
    return vec / np.sqrt(vec @ vec)

# 
# Scaled Normalization 
def scale(vec, weights = False):
    stop_divide_by_zero = 0.00000001
    if weights:
        return (vec.max()-vec.min() + stop_divide_by_zero)
    return (vec-vec.min())/(vec.max()-vec.min() + stop_divide_by_zero)

### SELECTION 
def is_string(a):
    '''
    typically used for Boolean masking in Pandas, e.g.  
               df[df['column'].apply(is_string)] 
    returns all rows in df where df['column'] has a string value   
    '''
    return isinstance(a,str)


## CLASSES

### DATA DICTIONARY 

class    Datadic: 
    def __init__(self):
        # Set up FIPS CODES for states and regions
        fips_codes_exists = os.path.isfile('data/state-geocodes-v2016.xls')
        if not fips_codes_exists:
            print('*** FIPS State Geocodes is missing. Downloading from Census...')
            # !curl -o ./data/state-geocodes-v2016.xls -O https://www2.census.gov/programs-surveys/popest/geographies/2016/state-geocodes-v2016.xls
            download_url('https://www2.census.gov/programs-surveys/popest/geographies/2016/state-geocodes-v2016.xls','./data/state-geocodes-v2016.xls')
            print('*** Complete.')

        self.dfips = pd.read_excel('data/state-geocodes-v2016.xls')[5:] #five first rows are comment
        self.name_to_fips = self.dfips.set_index('Unnamed: 3')['Unnamed: 2'].to_dict()
        self.fips_to_name = self.dfips.set_index('Unnamed: 2')['Unnamed: 3'].to_dict()
        self.translate_fips = {**self.name_to_fips,**self.fips_to_name}
        
        self.state_to_abbrev = {'Alabama': 'AL','Alaska': 'AK','Arizona': 'AZ','Arkansas': 'AR','California': 'CA','Colorado': 'CO',
                'Connecticut': 'CT','Delaware': 'DE','District of Columbia': 'DC','Florida': 'FL','Georgia': 'GA','Hawaii': 'HI',
                'Idaho': 'ID','Illinois': 'IL','Indiana': 'IN','Iowa': 'IA','Kansas': 'KS','Kentucky': 'KY','Louisiana': 'LA',
                'Maine': 'ME','Maryland': 'MD','Massachusetts': 'MA','Michigan': 'MI','Minnesota': 'MN','Mississippi': 'MS','Missouri': 'MO',
                'Montana': 'MT','Nebraska': 'NE','Nevada': 'NV','New Hampshire': 'NH','New Jersey': 'NJ','New Mexico': 'NM',
                'New York': 'NY','North Carolina': 'NC','North Dakota': 'ND','Ohio': 'OH','Oklahoma': 'OK','Oregon': 'OR',
                'Pennsylvania': 'PA','Rhode Island': 'RI','South Carolina': 'SC','South Dakota': 'SD','Tennessee': 'TN','Texas': 'TX',
                'Utah': 'UT','Vermont': 'VT','Virginia': 'VA','Washington': 'WA','West Virginia': 'WV','Wisconsin': 'WI','Wyoming': 'WY'}
        self.abbrev_to_state = {v: k for k, v in self.state_to_abbrev.items()}
        self.translate_state_abbrev = {**self.state_to_abbrev,**self.abbrev_to_state}
        
        #Set up CENSUS/ACS PUMS DATA DICTIONARY
        pums_datadic_exists = os.path.isfile('./data/census/PUMS_Data_Dictionary.csv')
        if not pums_datadic_exists:
            print('*** Census ACS/PUMS Data Dictionary is missing. Downloading from Census...')
            # !curl -o ./data/census/PUMS_Data_Dictionary.csv -O https://www2.census.gov/programs-surveys/acs/tech_docs/pums/data_dict/PUMS_Data_Dictionary_2017.csv
            download_url('https://www2.census.gov/programs-surveys/acs/tech_docs/pums/data_dict/PUMS_Data_Dictionary_2017.csv','./data/census/PUMS_Data_Dictionary.csv')
            print('*** Complete.')
        self.census = pd.read_csv("data/census/PUMS_Data_Dictionary.csv").drop_duplicates()
        self.census_variable_definitions = self.census.groupby('RT').first()['Record Type'].to_dict()      
            
    def fips(self,name_or_fipsnr):
        nn = datadic.abbrev_to_state.get(name_or_fipsnr,name_or_fipsnr)
        return self.translate_fips.get(nn)
    
    def state_abbrev(self,name_or_abbrev):
        return self.translate_state_abbrev.get(name_or_abbrev)
    
    def census_def(self,variable_code):
        return self.census_variable_definitions.get(variable_code)

    # All definitions containing a select string
    def clk(self,census_col,search_string):
        return self.census[census_col].fillna('nan').apply(lambda x: search_string.lower() in x.lower())
    
    def census_about(self,search_string):
        return self.census[self.clk('Record Type',search_string) | self.clk('Unnamed: 6',search_string) ]
    
datadic = Datadic()


class Onet:
    '''
    Onet() is an object based on the Onet labor market database. 

    my_onet.source  - string: URL for importing the onet database from source
    my_onet.path    - string: local path to the directory where the onet database is stored. (set in 'paths' dictionary)
    my_onet.name    - string: the prefix of stored files, e.g. zipped DB:      path + '/'+ name +'.zip'
    my_onet.toc()   - function: returns table of contents for onet database

   # Data in Onet database
    my_onet.data()
                    - function: returns dataset named by label.
    my_onet.matrix() 
                    - function: returns onet dataset in matrix form
    my_onet.n_matrix() 
                    - function: normalized onet matrix
 
   
    '''
    def __init__(self,path = paths['onet'], name = 'onet', source = 'https://www.onetcenter.org/dl_files/database/db_23_3_excel.zip'):
        
        self.path = path
        self.name = name
        self.source = source
        self.dataset = {}
        self.matrix_dic = {}

        self.socp_titles = self.data('Alternate Titles',socp_shave = 8)[['SOCP_shave','Title']].drop_duplicates()
        
        zip_file = path + '/'+ name +'.zip'
        onet_exists = os.path.isfile(zip_file)
        if not onet_exists:
            print('*** Onet database does not exist. Downloading from Onet...')
            #shcmd = 'curl -o '+zip_file+' -O '+source
            #!$shcmd'
            download_url(source,zip_file)
            print('*** Complete.')
        
        self.zip = zipfile.ZipFile(zip_file)
        self.tocdf = self.make_toc()
    
    def make_toc(self,sep ='.'):
        '''
        Creates table of contents for Onet Database, returns as my_onet.tocdf (dataframe)
        '''
        nlst = np.array(self.zip.namelist())
        dr = nlst[0]
        nl = pd.DataFrame(nlst)
        self.tocdf = pd.DataFrame(nl[0].apply(lambda x: np.char.split(x.replace(dr,''),sep = '.'))[1:].to_dict(),
                                    index = ['name','extension']).T
        return self.tocdf
    
    def toc(self, name_contains= False, extension = False):
        '''
        Returns table of contents for Onet Database (dataframe) masked by string and/or extension
        '''
        selection = self.tocdf
        if extension:
            selection = selection[selection['extension'] == extension  ]['name']
        if name_contains:
            search_string = name_contains
            selection = selection[selection['name'].apply(lambda x: search_string.lower() in x.lower())]['name']
        return selection
         
    
    def data(self,label, socp_shave = 6):
        '''
        Returns onet dataset named 'label'
        '''
        # If dataframe in dictionary:  
        if label in self.dataset.keys():
            df = self.dataset[label]
            df['SOCP_shave'] = df['O*NET-SOC Code'].apply(lambda x: x.replace('.','').replace('-','')).apply(lambda x: x[:socp_shave])
            return self.dataset[label]

        # If dataframe NOT in dictionary: 
        # If pickled dataframe does not exist, create from zipped excel
        # Read pickled dataframe into dictionary
        pkl_name = self.path +'/'+ self.name +'_'+ label +'.pkl'
        pkl_exists = os.path.isfile(pkl_name)

        if not pkl_exists:
            print('*** '+label+'.pkl does not exist. Creating...')
            xlsx_name = self.zip.namelist()[0] + label +'.xlsx'
            pd.read_excel(self.zip.extract(xlsx_name)).to_pickle(pkl_name)
            print('*** Complete.')
        df = pd.read_pickle(pkl_name)
        df['SOCP_shave'] = df['O*NET-SOC Code'].apply(lambda x: x.replace('.','').replace('-','')).apply(lambda x: x[:socp_shave])
        self.dataset[label] = df                              
        return self.dataset[label]
    
    def grpby(self, label, columns = ['Scale Name','Element Name'], data_value = 'Data Value', scale_name = 'Level'):
        grp = pd.DataFrame(self.data(label).copy().groupby(columns).apply(lambda x: x[data_value].values))
        return grp

    def matrix(self,label, xx = 'Element Name',  yy = 'SOCP_shave',socp_shave = 6 , data_value = 'Data Value', scale_name = 'Level',
                show = 'mean', norm = False):
        '''
        Converts onet dataset into a matrix 
        xx          - matrix columns
        yy          - matrix index
        scale_name  - value category 
        data_value  - data values
        socp_shave  - number of digits in 'shaved' SOCP number
        show        - output matrix shows 'mean'(default), 'std' or 'count' (relevant for groupby socp_shave)
        '''
        if not (label,xx,yy,socp_shave,data_value,scale_name,norm) in self.matrix_dic.keys():
            print('*** Matrix not in dictionary. Constructing....')
            columns = ['Scale Name',yy,xx] # Default columns
            grpb = self.data(label,socp_shave = socp_shave).groupby(columns)
            mat_mean   = grpb.mean().loc[scale_name][data_value].unstack()
            mat_std    = grpb.std().loc[scale_name][data_value].unstack()
            mat_count = grpb.count().loc[scale_name][data_value].unstack().T.iloc[[0]].T
            if norm:
                w = mat_mean.apply(lambda col: norm(col,weights = True) )
                mat_mean = mat_mean.apply(norm)
                mat_std = mat_std/w
            self.matrix_dic[label,xx,yy,socp_shave,data_value,scale_name,norm] = {
                'mean':mat_mean,'std':mat_std,'count':mat_count}
            print('*** Complete')
        return self.matrix_dic[label,xx,yy,socp_shave,data_value,scale_name,norm][show]
    
       
# Instantiate Onet() as 'onet'
onet = Onet()            

#%%    

class   Census:
    '''
    Census() is an object containing census ACS/PUMS data 
    my_census.source    - string: URL for importing the census data from US Census online
    my_census.path      - string: local path to the directory where the census data is stored. (set in 'paths' dictionary)
    my_census.name      - string: the prefix of stored files, e.g. pickle:      path + '/'+ name +'.pkl'

    my_census.data(self,state, socp_shave = n)
                        - function: returns the acs/pums for 'state', with an SOCP number of 'n' digits (default n=6)
    my_census.dataset   - dataframe: acs/pums data for a state (state abbreviation used for naming)
    my_census.import_from_source(self,state)
                        - function: imports data for 'state' from my_census.source and converts to pickled dataframe 


    # my_census.state    – String: name of state, e.g. 'California', or abbreviation, e.g. 'CA'
    # my_census.data     – DataFrame: imported census ACS/PUMS data (from pickle)
    # my_census.workers  – DataFrame: people fulfilling 'workers' criteria (see below)
    # my_census.occupations         – DataFrame: Occupations of the workers (groupby SOCP-number)
    
    # my_census.workers_occupations(age_low = 40, age_high = 65, std_max = 0.5, socp_granularity = 5):
    #      - Function: populates my_census.workers / .occupations according to criteria
    #          – Workers: age_low (default 40)  and age_high (default 65)
    #          – Occupations: socp_granularity (default 5) ; the length of the SOCP number, default 5 digits.
    
    '''

    def __init__(self,path = paths['census'], name = 'census', 
                 source = 'https://www2.census.gov/programs-surveys/acs/data/pums/2017/5-Year/'):
        self.path = path
        self.name = name
        self.source = source
        self.dataset = {}
        
    
    def data(self,state, socp_shave = 6):
        '''
        READ CENSUS/ACS PUMS DATABASE. Search order: Dictionary, Pickle; Create dictionary/pickle if non-existent.
        socp_shave  : number of digits in 'shaved' SOCP number
        '''
        state_abbr = datadic.state_to_abbrev.get(state,state)
        pkl_name = self.path +'/'+ self.name +'_'+ state_abbr +'.pkl'
        pkl_exists = os.path.isfile(pkl_name)
        if not pkl_exists:
            self.import_from_source(state)
        df = pd.read_pickle(pkl_name)
        df['SOCP_shave'] = df['SOCP'].apply(lambda x: x[:socp_shave].replace('X','0') if type(x)==str else x)
        self.dataset[state_abbr] = df
        return self.dataset[state_abbr]


    # Create and execute shell command fetching state census zip-file 
    def import_from_source(self,state):
        print('*** Downloading '+state+' ACS/PUMS dataset from US Census...')
        state_abbr = datadic.state_to_abbrev.get(state,state)
 #       shcmd = "curl -o "+self.path+'/'+self.name+"_tmp.zip -O "+ self.source +self.state_zipfile_name(state_abbr)
 #       ! $shcmd
        download_url(self.source +self.state_zipfile_name(state_abbr),self.path+'/'+self.name+"_tmp.zip")
        print('*** Reformatting...')
        with zipfile.ZipFile(self.path+'/'+self.name+"_tmp.zip", 'r') as zipObj:
            zipObj.extractall(self.path)
        csv_filename = self.path+'/psam_p'+datadic.fips(state)+'.csv'
        pkl_filename = self.path+'/'+self.name+'_'+state_abbr+'.pkl'
        pd.read_csv(csv_filename).to_pickle(pkl_filename)
        ! rm $csv_filename 
        print('*** Complete.')
        return 

    def state_zipfile_name(self,state_abbr):
        return 'csv_p'+state_abbr.lower()+'.zip'



# Instantiate Census() as 'census'
census = Census()


#%%

# # MATRIX-FACTORIZATION: DIMENSIONALITY REDUCTION & ARCHETYPING

# ## CLUSTER FEATURES INTO OCCUPATION CATEGORIES
# ## Use non-zero matrix factorization for clustering
# ## Use singular value decomposition first state for determining overall similarity

class Archetypes:
    '''
    Archetypes: Performs NMF of order n on X and stores the result as attributes. 
    Archetypes are normalized: cosine similarity a(i) @ a(i) = 1. 
    Atributes:
        my_archetypes.n         - order / number of archetypes
        my_archetypes.X         - input matrix
        
        my_archetypes.model     - NMF model 
        my_archetypes.w         - NMF w-matrix 
        my_archetypes.h         - NMF h-matrix
        
        my_archetypes.o         - occupations x archetypes matrix (from w-matrix)
        my_archetypes.on        - occupations x normalized archetypes matrix (from w-matrix) - SOCP number as index. 
        my_archetypes.occ       - occupations x normalized archetypes matrix - Occupation names as index
        
        my_archetypes.f         - features x archetypes matrix (from h-matrix)
        my_archetypes.fn        - features x normalized archetypes matrix
        
    '''
    def __init__(self,X,n):
        self.n = n
        self.X = X
        self.model = NMF(n_components=n, init='random', random_state=0, max_iter = 1000, tol = 0.0000001)
        self.w = self.model.fit_transform(self.X)
        self.o = pd.DataFrame(self.w,index=self.X.index)
        self.on = self.o.T.apply(norm_dot).T
        self.occ = self.on.copy()
        self.occ['Occupations'] = self.occ.index
#        self.occ['Occupations'] = self.occ['Occupations'].apply(onet_socp_name)
        self.occ = self.occ.set_index('Occupations')
        self.h = self.model.components_
        self.f = pd.DataFrame(self.h,columns=X.columns)
        self.fn =self.f.T.apply(norm_dot).T
        self.plot_occupations_dic ={}
        self.plot_features_dic ={}
        
    def plot_features(self,fig_scale = (1,3.5),metric='cosine', method = 'single',vertical = True): 
        '''
        Plot Archetypes as x and features as y. 
        Utilizes Seaborn Clustermap, with hierarchical clustering along both axes. 
        This clusters features and archetypes in a way that visualizes similarities and diffferences
        between the archetypes. 
        
        Archetypes are normalized (cosine-similarity): dot product archetype[i] @ archetype[i] = 1.
        The plot shows intensities (= squared feature coefficients) so that the sum of intensities = 1.  

        fig_scale: default values (x/1, y/3.5) scales the axes so that all feature labels are included in the plot.
        
        For other hyperparameters, see seaborn.clustermap
     
        '''
        param = (fig_scale,metric,method,vertical)
        if param in self.plot_features_dic.keys():
            fig = self.plot_features_dic[param]
            return fig.fig

        df = np.square(self.fn)

        if vertical:
            fig = sns.clustermap(df.T,robust = True, z_score=1,figsize=(
                self.n/fig_scale[0],self.X.shape[1]/fig_scale[1]),method = method,metric = metric)        
        else: # horizontal
            fig = sns.clustermap(df,robust = True, z_score=0,figsize=(
                self.X.shape[1]/fig_scale[1],self.n/fig_scale[0]),method = method,metric = metric)        
        self.features_plot = fig
        return fig


    def plot_occupations(self,fig_scale = (1,3.5),metric='cosine', method = 'single',vertical = True):
        '''
        Plot Archetypes as x and occupations as y. 
        Utilizes Seaborn Clustermap, with hierarchical clustering along both axes. 
        This clusters occupations and archetypes in a way that visualizes similarities and diffferences
        between the archetypes. 
        
        Occupations are normalized (cosine-similarity): dot product occupation[i] @ occupation[i] = 1.
        The plot shows intensities (= squared feature coefficients) so that the sum of intensities = 1.  

        fig_scale: default values (x/1, y/3.5) scales the axes so that all feature labels are included in the plot.
        
        For other hyperparameters, see seaborn.clustermap
     
        '''
        param = (fig_scale,metric,method,vertical)
        if param in self.plot_occupations_dic.keys():
            fig = self.plot_occupations_dic[param]
            return fig.fig

        df = np.square(self.occ)
        if vertical:
            fig = sns.clustermap(df, figsize=(
                self.n/fig_scale[0],self.X.shape[0]/fig_scale[1]),method = method,metric = metric)
        else: # horizontal
            fig = sns.clustermap(df.T, figsize=(
                self.X.shape[0]/fig_scale[1],self.n/fig_scale[0]),method = method,metric = metric)
        self.plot_occupations_dic[param] = fig
        return fig.fig

        
class Xfit:
    '''
    Xfit is a 'fit-as-an-object' solution:
        my_fit = Xfit(X,y,Xsamples=False, my_regressor, itr, xval) 
            does the following:
            0. SAMPLES X - unless Xsamples is 'False' [default value], X is replaced by n random samples of itself  
            1. SPLITS X and y into test and training sets. 
            2. FITS a cross-validation, slicing the training data into 'xval' slices : cross_validate(regressor,X_train.values, y_train.values, cv=xval) 
            3. BOOTSTRAPS: Repeats (1-2) 'itr' number of times
            4. RETURNS RESULTS as attributes:
                my_fit.X          – List: The original X input data
                my_fit.itr        – Number of iterations / fits
                my_fit.y          – List: The original y input data
                my_fit.xval       – Number of slices in the cross validation
                my_fit.fit        – Dictionary: the 'itr' number of cross-validated fits, including estimators
                my_fit.y_test     – Dictionary: the y_test (list) for each fit
                my_fit.y_predict  – Dictionary: the predicted y for each fit
                my_fit.scores     – Pandas.DataFrame: validation scores for all fits 
                my_fit.score      – Dictionary: the mean score and standard deviation. 
                my_fit.features_importances        – Dictionary: feature_importances for all fits (for estimators with '.feature_importance_' as an attribute )
                my_fit.feature_importance          – Pandas.DataFrame: the average feature importances and standard deviations.           
    '''
    from sklearn.model_selection import train_test_split
    from sklearn.model_selection import cross_validate
    from sklearn.model_selection import cross_val_score
    from sklearn import linear_model
    from sklearn.ensemble import RandomForestRegressor
    from sklearn.ensemble import GradientBoostingRegressor
    import xgboost as xgb  

    def __init__(self,X,y,Xsamples=False,regressor = xgb.XGBRegressor(),itr = 10, xval = 3):      
        # FITTING
        n = xval  
        feature_names = X.columns
        res = {}
        ypred = {}
        ytest = {}
        scor = {}
        feat_imp = {}       
        for i in range(itr):
            if Xsamples:
                X_train, X_test, y_train, y_test = train_test_split(X.sample(Xsamples,axis=1), y, test_size=0.2)
            else:
                X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
            res_xboo = cross_validate(regressor,X_train.values, y_train.values, cv=n, return_estimator=True)
            ytest[i] = y_test
            res[i] = res_xboo
            ypred[i] = [res_xboo['estimator'][j].predict(X_test.values) for j in range(n)]
            scor[i] = [res_xboo['estimator'][j].score(X_test.values,y_test.values) for j in range(n)]
            feat_imp[i] = [res_xboo['estimator'][j].feature_importances_ for j in range(n)]
        scor_tot = np.concatenate(np.array(list(scor.values())))
        feat_tot = pd.concat([pd.DataFrame(feat_imp[i]) for i in range(itr)])
#       # feat_tot.columns = X.columns
        feat_tot.reset_index(inplace=True,drop = True)
        feat_mean = pd.concat([feat_tot.mean(),feat_tot.std()],axis=1)
        feat_mean.columns = ['mean','std']
        feat_mean['ratio'] = feat_mean['std']/feat_mean['mean']      
        # STORING RESULTS AS ATTRIBUTES
        self.X = X
        self.y = y
        self.fit = res
        self.y_predict = ypred
        self.y_test = ytest
        self.scores = pd.DataFrame(scor).T
        self.score = {'mean':scor_tot.mean(), 'std':scor_tot.std()}
        self.feature_importances = feat_imp
        self.feature_importance = feat_mean.sort_values('mean',ascending=False)
        self.itr =itr
        self.xv = xval



class Svd:
    ''''
    Singular value decomposition-as-an-object
        my_svd = Svd(X) returns
        my_svd.u/.s/.vt – U S and VT from the Singular Value Decomposition (see manual)
        my_svd.f        – Pandas.DataFrame: f=original features x svd_features
        my_svd.o        - Pandas.DataFrame: o=occupations x svd_features
    '''
    def __init__(self,X):
        self.u,self.s,self.vt = svd(np.array(X))
        self.f = pd.DataFrame(self.vt,columns=X.columns)
        self.o = pd.DataFrame(self.u,columns=X.index)
        




#%%

# %%
title_vec = onet.socp_titles['Title'].apply(nlp_prep)
onet.socp_titles['title_vec'] = title_vec

# %%
onet.socp_titles['title_vec']
# Out:
# 0                                       [chief, executive]
# 149                       [chief, sustainability, officer]
# 175                          [general, operation, manager]
# 272                                           [legislator]
# 295                      [advertising, promotion, manager]
# 329                                      [green, marketer]
# 336                                   [marketing, manager]
# 389                                        [sale, manager]
# 449               [public, relation, fundraising, manager]
# 484                     [administrative, service, manager]
# 528               [computer, information, system, manager]
# 593                                   [financial, manager]
# 604                                [treasurer, controller]
# 642               [financial, manager, branch, department]
# 717                      [industrial, production, manager]
# 766                    [quality, control, system, manager]
# 785                      [geothermal, production, manager]
# 799                        [biofuels, production, manager]
# 818                       [biomass, power, plant, manager]
# 834      [methane, landfill, gas, collection, system, o...
# 848                   [hydroelectric, production, manager]
# 867                                  [purchasing, manager]
# 904       [transportation, storage, distribution, manager]
# 914                              [transportation, manager]
# 998                       [storage, distribution, manager]
# 1049                                  [logistics, manager]
# 1072                      [compensation, benefit, manager]
# 1094                            [human, resource, manager]
# 1130                      [training, development, manager]
# 1166                        [nursery, greenhouse, manager]
#                                ...
# 57380     [laborer, freight, stock, material, mover, hand]
# 57866                        [machine, feeder, offbearers]
# 58353                            [packer, packagers, hand]
# 58563    [gas, compressor, gas, pumping, station, opera...
# 58589          [pump, operator, except, wellhead, pumpers]
# 58655                                  [wellhead, pumpers]
# 58676            [refuse, recyclable, material, collector]
# 58742                       [mine, shuttle, car, operator]
# 58756                     [tank, car, truck, ship, loader]
# 58787                           [material, moving, worker]
# 58961                                 [air, crew, officer]
# 58973                [aircraft, launch, recovery, officer]
# 58977                 [armored, assault, vehicle, officer]
# 58983                        [artillery, missile, officer]
# 59014                  [command, control, center, officer]
# 59087                                  [infantry, officer]
# 59090                            [special, force, officer]
# 59104    [military, officer, special, tactical, operati...
# 59218         [first, line, supervisor, air, crew, member]
# 59225    [first, line, supervisor, weapon, specialist, ...
# 59233    [first, line, supervisor, tactical, operation,...
# 59268                                  [air, crew, member]
# 59321             [aircraft, launch, recovery, specialist]
# 59328            [armored, assault, vehicle, crew, member]
# 59344                   [artillery, missile, crew, member]
# 59404               [command, control, center, specialist]
# 59453                                           [infantry]
# 59468                           [radar, sonar, technician]
# 59533                                     [special, force]
# 59559    [military, enlisted, tactical, operation, air,...
# Name: title_vec, Length: 1109, dtype: object

# %%
def drop_stopwords(wordvec,language='English'):
    wv = np.array(wordvec)
    stw = np.array(stopwords.words(language))
    without_stopwords = wv[[not word in stw for word in wv]]
    return without_stopwords

def lemmatize(wordvec):
    return [lemmatizer.lemmatize(word) for word in wordvec ]

def nlp_prep(string):
    wordvec = tokenizer.tokenize(string.lower())
    return np.array(lemmatize(drop_stopwords(wordvec)))

# %%
tt.apply(nlp_prep).iloc[2]
# Out:
# array(['general', 'operation', 'manager'], dtype='<U9')

# %%
set([5,1,3,2,77]) & set([2,2,77,4,5])
# Out:
# {2, 5, 77}

# %%
np.roll([1,2,3,4],1)
# Out:
# array([4, 1, 2, 3])

# %%
tt = onet.socp_titles.set_index('SOCP_shave')
tts = tt['title_vec'].apply(set)
ix = tt.index.values
ix_x = np.concatenate([ix for step in range(len(ix)-1)])
ix_y = np.concatenate([np.roll(ix,step) for step in range(len(ix)-1)])
sim_mat = pd.DataFrame(df.loc[ix_y].values & df.loc[ix_y].values, index = [ix_x,ix_y]).unstack()

# %%
sim_mat
# Out:
#                            0                                    \
#                     11101100                          11101103
# 11101100  {chief, executive}                               NaN
# 11101103  {chief, executive}  {sustainability, chief, officer}
# 11102100  {chief, executive}  {sustainability, chief, officer}
# 11103100  {chief, executive}  {sustainability, chief, officer}
# 11201100  {chief, executive}  {sustainability, chief, officer}
# 11201101  {chief, executive}  {sustainability, chief, officer}
# 11202100  {chief, executive}  {sustainability, chief, officer}
# 11202200  {chief, executive}  {sustainability, chief, officer}
# 11203100  {chief, executive}  {sustainability, chief, officer}
# 11301100  {chief, executive}  {sustainability, chief, officer}
# 11302100  {chief, executive}  {sustainability, chief, officer}
# 11303100  {chief, executive}  {sustainability, chief, officer}
# 11303101  {chief, executive}  {sustainability, chief, officer}
# 11303102  {chief, executive}  {sustainability, chief, officer}
# 11305100  {chief, executive}  {sustainability, chief, officer}
# 11305101  {chief, executive}  {sustainability, chief, officer}
# 11305102  {chief, executive}  {sustainability, chief, officer}
# 11305103  {chief, executive}  {sustainability, chief, officer}
# 11305104  {chief, executive}  {sustainability, chief, officer}
# 11305105  {chief, executive}  {sustainability, chief, officer}
# 11305106  {chief, executive}  {sustainability, chief, officer}
# 11306100  {chief, executive}  {sustainability, chief, officer}
# 11307100  {chief, executive}  {sustainability, chief, officer}
# 11307101  {chief, executive}  {sustainability, chief, officer}
# 11307102  {chief, executive}  {sustainability, chief, officer}
# 11307103  {chief, executive}  {sustainability, chief, officer}
# 11311100  {chief, executive}  {sustainability, chief, officer}
# 11312100  {chief, executive}  {sustainability, chief, officer}
# 11313100  {chief, executive}  {sustainability, chief, officer}
# 11901301  {chief, executive}  {sustainability, chief, officer}
# ...                      ...                               ...
# 53706200  {chief, executive}  {sustainability, chief, officer}
# 53706300  {chief, executive}  {sustainability, chief, officer}
# 53706400  {chief, executive}  {sustainability, chief, officer}
# 53707100  {chief, executive}  {sustainability, chief, officer}
# 53707200  {chief, executive}  {sustainability, chief, officer}
# 53707300  {chief, executive}  {sustainability, chief, officer}
# 53708100  {chief, executive}  {sustainability, chief, officer}
# 53711100  {chief, executive}  {sustainability, chief, officer}
# 53712100  {chief, executive}  {sustainability, chief, officer}
# 53719900  {chief, executive}  {sustainability, chief, officer}
# 55101100  {chief, executive}  {sustainability, chief, officer}
# 55101200  {chief, executive}  {sustainability, chief, officer}
# 55101300  {chief, executive}  {sustainability, chief, officer}
# 55101400  {chief, executive}  {sustainability, chief, officer}
# 55101500  {chief, executive}  {sustainability, chief, officer}
# 55101600  {chief, executive}  {sustainability, chief, officer}
# 55101700  {chief, executive}  {sustainability, chief, officer}
# 55101900  {chief, executive}  {sustainability, chief, officer}
# 55201100  {chief, executive}  {sustainability, chief, officer}
# 55201200  {chief, executive}  {sustainability, chief, officer}
# 55201300  {chief, executive}  {sustainability, chief, officer}
# 55301100  {chief, executive}  {sustainability, chief, officer}
# 55301200  {chief, executive}  {sustainability, chief, officer}
# 55301300  {chief, executive}  {sustainability, chief, officer}
# 55301400  {chief, executive}  {sustainability, chief, officer}
# 55301500  {chief, executive}  {sustainability, chief, officer}
# 55301600  {chief, executive}  {sustainability, chief, officer}
# 55301700  {chief, executive}  {sustainability, chief, officer}
# 55301800  {chief, executive}  {sustainability, chief, officer}
# 55301900                 NaN  {sustainability, chief, officer}
#
#                                                        \
#                                11102100      11103100
# 11101100  {operation, manager, general}  {legislator}
# 11101103                            NaN  {legislator}
# 11102100  {operation, manager, general}           NaN
# 11103100  {operation, manager, general}  {legislator}
# 11201100  {operation, manager, general}  {legislator}
# 11201101  {operation, manager, general}  {legislator}
# 11202100  {operation, manager, general}  {legislator}
# 11202200  {operation, manager, general}  {legislator}
# 11203100  {operation, manager, general}  {legislator}
# 11301100  {operation, manager, general}  {legislator}
# 11302100  {operation, manager, general}  {legislator}
# 11303100  {operation, manager, general}  {legislator}
# 11303101  {operation, manager, general}  {legislator}
# 11303102  {operation, manager, general}  {legislator}
# 11305100  {operation, manager, general}  {legislator}
# 11305101  {operation, manager, general}  {legislator}
# 11305102  {operation, manager, general}  {legislator}
# 11305103  {operation, manager, general}  {legislator}
# 11305104  {operation, manager, general}  {legislator}
# 11305105  {operation, manager, general}  {legislator}
# 11305106  {operation, manager, general}  {legislator}
# 11306100  {operation, manager, general}  {legislator}
# 11307100  {operation, manager, general}  {legislator}
# 11307101  {operation, manager, general}  {legislator}
# 11307102  {operation, manager, general}  {legislator}
# 11307103  {operation, manager, general}  {legislator}
# 11311100  {operation, manager, general}  {legislator}
# 11312100  {operation, manager, general}  {legislator}
# 11313100  {operation, manager, general}  {legislator}
# 11901301  {operation, manager, general}  {legislator}
# ...                                 ...           ...
# 53706200  {operation, manager, general}  {legislator}
# 53706300  {operation, manager, general}  {legislator}
# 53706400  {operation, manager, general}  {legislator}
# 53707100  {operation, manager, general}  {legislator}
# 53707200  {operation, manager, general}  {legislator}
# 53707300  {operation, manager, general}  {legislator}
# 53708100  {operation, manager, general}  {legislator}
# 53711100  {operation, manager, general}  {legislator}
# 53712100  {operation, manager, general}  {legislator}
# 53719900  {operation, manager, general}  {legislator}
# 55101100  {operation, manager, general}  {legislator}
# 55101200  {operation, manager, general}  {legislator}
# 55101300  {operation, manager, general}  {legislator}
# 55101400  {operation, manager, general}  {legislator}
# 55101500  {operation, manager, general}  {legislator}
# 55101600  {operation, manager, general}  {legislator}
# 55101700  {operation, manager, general}  {legislator}
# 55101900  {operation, manager, general}  {legislator}
# 55201100  {operation, manager, general}  {legislator}
# 55201200  {operation, manager, general}  {legislator}
# 55201300  {operation, manager, general}  {legislator}
# 55301100  {operation, manager, general}  {legislator}
# 55301200  {operation, manager, general}  {legislator}
# 55301300  {operation, manager, general}  {legislator}
# 55301400  {operation, manager, general}  {legislator}
# 55301500  {operation, manager, general}  {legislator}
# 55301600  {operation, manager, general}  {legislator}
# 55301700  {operation, manager, general}  {legislator}
# 55301800  {operation, manager, general}  {legislator}
# 55301900  {operation, manager, general}  {legislator}
#
#                                                                 \
#                                    11201100           11201101
# 11101100  {advertising, manager, promotion}  {green, marketer}
# 11101103  {advertising, manager, promotion}  {green, marketer}
# 11102100  {advertising, manager, promotion}  {green, marketer}
# 11103100                                NaN  {green, marketer}
# 11201100  {advertising, manager, promotion}                NaN
# 11201101  {advertising, manager, promotion}  {green, marketer}
# 11202100  {advertising, manager, promotion}  {green, marketer}
# 11202200  {advertising, manager, promotion}  {green, marketer}
# 11203100  {advertising, manager, promotion}  {green, marketer}
# 11301100  {advertising, manager, promotion}  {green, marketer}
# 11302100  {advertising, manager, promotion}  {green, marketer}
# 11303100  {advertising, manager, promotion}  {green, marketer}
# 11303101  {advertising, manager, promotion}  {green, marketer}
# 11303102  {advertising, manager, promotion}  {green, marketer}
# 11305100  {advertising, manager, promotion}  {green, marketer}
# 11305101  {advertising, manager, promotion}  {green, marketer}
# 11305102  {advertising, manager, promotion}  {green, marketer}
# 11305103  {advertising, manager, promotion}  {green, marketer}
# 11305104  {advertising, manager, promotion}  {green, marketer}
# 11305105  {advertising, manager, promotion}  {green, marketer}
# 11305106  {advertising, manager, promotion}  {green, marketer}
# 11306100  {advertising, manager, promotion}  {green, marketer}
# 11307100  {advertising, manager, promotion}  {green, marketer}
# 11307101  {advertising, manager, promotion}  {green, marketer}
# 11307102  {advertising, manager, promotion}  {green, marketer}
# 11307103  {advertising, manager, promotion}  {green, marketer}
# 11311100  {advertising, manager, promotion}  {green, marketer}
# 11312100  {advertising, manager, promotion}  {green, marketer}
# 11313100  {advertising, manager, promotion}  {green, marketer}
# 11901301  {advertising, manager, promotion}  {green, marketer}
# ...                                     ...                ...
# 53706200  {advertising, manager, promotion}  {green, marketer}
# 53706300  {advertising, manager, promotion}  {green, marketer}
# 53706400  {advertising, manager, promotion}  {green, marketer}
# 53707100  {advertising, manager, promotion}  {green, marketer}
# 53707200  {advertising, manager, promotion}  {green, marketer}
# 53707300  {advertising, manager, promotion}  {green, marketer}
# 53708100  {advertising, manager, promotion}  {green, marketer}
# 53711100  {advertising, manager, promotion}  {green, marketer}
# 53712100  {advertising, manager, promotion}  {green, marketer}
# 53719900  {advertising, manager, promotion}  {green, marketer}
# 55101100  {advertising, manager, promotion}  {green, marketer}
# 55101200  {advertising, manager, promotion}  {green, marketer}
# 55101300  {advertising, manager, promotion}  {green, marketer}
# 55101400  {advertising, manager, promotion}  {green, marketer}
# 55101500  {advertising, manager, promotion}  {green, marketer}
# 55101600  {advertising, manager, promotion}  {green, marketer}
# 55101700  {advertising, manager, promotion}  {green, marketer}
# 55101900  {advertising, manager, promotion}  {green, marketer}
# 55201100  {advertising, manager, promotion}  {green, marketer}
# 55201200  {advertising, manager, promotion}  {green, marketer}
# 55201300  {advertising, manager, promotion}  {green, marketer}
# 55301100  {advertising, manager, promotion}  {green, marketer}
# 55301200  {advertising, manager, promotion}  {green, marketer}
# 55301300  {advertising, manager, promotion}  {green, marketer}
# 55301400  {advertising, manager, promotion}  {green, marketer}
# 55301500  {advertising, manager, promotion}  {green, marketer}
# 55301600  {advertising, manager, promotion}  {green, marketer}
# 55301700  {advertising, manager, promotion}  {green, marketer}
# 55301800  {advertising, manager, promotion}  {green, marketer}
# 55301900  {advertising, manager, promotion}  {green, marketer}
#
#                                                  \
#                       11202100         11202200
# 11101100  {manager, marketing}  {manager, sale}
# 11101103  {manager, marketing}  {manager, sale}
# 11102100  {manager, marketing}  {manager, sale}
# 11103100  {manager, marketing}  {manager, sale}
# 11201100  {manager, marketing}  {manager, sale}
# 11201101                   NaN  {manager, sale}
# 11202100  {manager, marketing}              NaN
# 11202200  {manager, marketing}  {manager, sale}
# 11203100  {manager, marketing}  {manager, sale}
# 11301100  {manager, marketing}  {manager, sale}
# 11302100  {manager, marketing}  {manager, sale}
# 11303100  {manager, marketing}  {manager, sale}
# 11303101  {manager, marketing}  {manager, sale}
# 11303102  {manager, marketing}  {manager, sale}
# 11305100  {manager, marketing}  {manager, sale}
# 11305101  {manager, marketing}  {manager, sale}
# 11305102  {manager, marketing}  {manager, sale}
# 11305103  {manager, marketing}  {manager, sale}
# 11305104  {manager, marketing}  {manager, sale}
# 11305105  {manager, marketing}  {manager, sale}
# 11305106  {manager, marketing}  {manager, sale}
# 11306100  {manager, marketing}  {manager, sale}
# 11307100  {manager, marketing}  {manager, sale}
# 11307101  {manager, marketing}  {manager, sale}
# 11307102  {manager, marketing}  {manager, sale}
# 11307103  {manager, marketing}  {manager, sale}
# 11311100  {manager, marketing}  {manager, sale}
# 11312100  {manager, marketing}  {manager, sale}
# 11313100  {manager, marketing}  {manager, sale}
# 11901301  {manager, marketing}  {manager, sale}
# ...                        ...              ...
# 53706200  {manager, marketing}  {manager, sale}
# 53706300  {manager, marketing}  {manager, sale}
# 53706400  {manager, marketing}  {manager, sale}
# 53707100  {manager, marketing}  {manager, sale}
# 53707200  {manager, marketing}  {manager, sale}
# 53707300  {manager, marketing}  {manager, sale}
# 53708100  {manager, marketing}  {manager, sale}
# 53711100  {manager, marketing}  {manager, sale}
# 53712100  {manager, marketing}  {manager, sale}
# 53719900  {manager, marketing}  {manager, sale}
# 55101100  {manager, marketing}  {manager, sale}
# 55101200  {manager, marketing}  {manager, sale}
# 55101300  {manager, marketing}  {manager, sale}
# 55101400  {manager, marketing}  {manager, sale}
# 55101500  {manager, marketing}  {manager, sale}
# 55101600  {manager, marketing}  {manager, sale}
# 55101700  {manager, marketing}  {manager, sale}
# 55101900  {manager, marketing}  {manager, sale}
# 55201100  {manager, marketing}  {manager, sale}
# 55201200  {manager, marketing}  {manager, sale}
# 55201300  {manager, marketing}  {manager, sale}
# 55301100  {manager, marketing}  {manager, sale}
# 55301200  {manager, marketing}  {manager, sale}
# 55301300  {manager, marketing}  {manager, sale}
# 55301400  {manager, marketing}  {manager, sale}
# 55301500  {manager, marketing}  {manager, sale}
# 55301600  {manager, marketing}  {manager, sale}
# 55301700  {manager, marketing}  {manager, sale}
# 55301800  {manager, marketing}  {manager, sale}
# 55301900  {manager, marketing}  {manager, sale}
#
#                                                     \
#                                           11203100
# 11101100  {fundraising, manager, public, relation}
# 11101103  {fundraising, manager, public, relation}
# 11102100  {fundraising, manager, public, relation}
# 11103100  {fundraising, manager, public, relation}
# 11201100  {fundraising, manager, public, relation}
# 11201101  {fundraising, manager, public, relation}
# 11202100  {fundraising, manager, public, relation}
# 11202200                                       NaN
# 11203100  {fundraising, manager, public, relation}
# 11301100  {fundraising, manager, public, relation}
# 11302100  {fundraising, manager, public, relation}
# 11303100  {fundraising, manager, public, relation}
# 11303101  {fundraising, manager, public, relation}
# 11303102  {fundraising, manager, public, relation}
# 11305100  {fundraising, manager, public, relation}
# 11305101  {fundraising, manager, public, relation}
# 11305102  {fundraising, manager, public, relation}
# 11305103  {fundraising, manager, public, relation}
# 11305104  {fundraising, manager, public, relation}
# 11305105  {fundraising, manager, public, relation}
# 11305106  {fundraising, manager, public, relation}
# 11306100  {fundraising, manager, public, relation}
# 11307100  {fundraising, manager, public, relation}
# 11307101  {fundraising, manager, public, relation}
# 11307102  {fundraising, manager, public, relation}
# 11307103  {fundraising, manager, public, relation}
# 11311100  {fundraising, manager, public, relation}
# 11312100  {fundraising, manager, public, relation}
# 11313100  {fundraising, manager, public, relation}
# 11901301  {fundraising, manager, public, relation}
# ...                                            ...
# 53706200  {fundraising, manager, public, relation}
# 53706300  {fundraising, manager, public, relation}
# 53706400  {fundraising, manager, public, relation}
# 53707100  {fundraising, manager, public, relation}
# 53707200  {fundraising, manager, public, relation}
# 53707300  {fundraising, manager, public, relation}
# 53708100  {fundraising, manager, public, relation}
# 53711100  {fundraising, manager, public, relation}
# 53712100  {fundraising, manager, public, relation}
# 53719900  {fundraising, manager, public, relation}
# 55101100  {fundraising, manager, public, relation}
# 55101200  {fundraising, manager, public, relation}
# 55101300  {fundraising, manager, public, relation}
# 55101400  {fundraising, manager, public, relation}
# 55101500  {fundraising, manager, public, relation}
# 55101600  {fundraising, manager, public, relation}
# 55101700  {fundraising, manager, public, relation}
# 55101900  {fundraising, manager, public, relation}
# 55201100  {fundraising, manager, public, relation}
# 55201200  {fundraising, manager, public, relation}
# 55201300  {fundraising, manager, public, relation}
# 55301100  {fundraising, manager, public, relation}
# 55301200  {fundraising, manager, public, relation}
# 55301300  {fundraising, manager, public, relation}
# 55301400  {fundraising, manager, public, relation}
# 55301500  {fundraising, manager, public, relation}
# 55301600  {fundraising, manager, public, relation}
# 55301700  {fundraising, manager, public, relation}
# 55301800  {fundraising, manager, public, relation}
# 55301900  {fundraising, manager, public, relation}
#
#                                               \
#                                     11301100
# 11101100  {manager, service, administrative}
# 11101103  {manager, service, administrative}
# 11102100  {manager, service, administrative}
# 11103100  {manager, service, administrative}
# 11201100  {manager, service, administrative}
# 11201101  {manager, service, administrative}
# 11202100  {manager, service, administrative}
# 11202200  {manager, service, administrative}
# 11203100                                 NaN
# 11301100  {manager, service, administrative}
# 11302100  {manager, service, administrative}
# 11303100  {manager, service, administrative}
# 11303101  {manager, service, administrative}
# 11303102  {manager, service, administrative}
# 11305100  {manager, service, administrative}
# 11305101  {manager, service, administrative}
# 11305102  {manager, service, administrative}
# 11305103  {manager, service, administrative}
# 11305104  {manager, service, administrative}
# 11305105  {manager, service, administrative}
# 11305106  {manager, service, administrative}
# 11306100  {manager, service, administrative}
# 11307100  {manager, service, administrative}
# 11307101  {manager, service, administrative}
# 11307102  {manager, service, administrative}
# 11307103  {manager, service, administrative}
# 11311100  {manager, service, administrative}
# 11312100  {manager, service, administrative}
# 11313100  {manager, service, administrative}
# 11901301  {manager, service, administrative}
# ...                                      ...
# 53706200  {manager, service, administrative}
# 53706300  {manager, service, administrative}
# 53706400  {manager, service, administrative}
# 53707100  {manager, service, administrative}
# 53707200  {manager, service, administrative}
# 53707300  {manager, service, administrative}
# 53708100  {manager, service, administrative}
# 53711100  {manager, service, administrative}
# 53712100  {manager, service, administrative}
# 53719900  {manager, service, administrative}
# 55101100  {manager, service, administrative}
# 55101200  {manager, service, administrative}
# 55101300  {manager, service, administrative}
# 55101400  {manager, service, administrative}
# 55101500  {manager, service, administrative}
# 55101600  {manager, service, administrative}
# 55101700  {manager, service, administrative}
# 55101900  {manager, service, administrative}
# 55201100  {manager, service, administrative}
# 55201200  {manager, service, administrative}
# 55201300  {manager, service, administrative}
# 55301100  {manager, service, administrative}
# 55301200  {manager, service, administrative}
# 55301300  {manager, service, administrative}
# 55301400  {manager, service, administrative}
# 55301500  {manager, service, administrative}
# 55301600  {manager, service, administrative}
# 55301700  {manager, service, administrative}
# 55301800  {manager, service, administrative}
# 55301900  {manager, service, administrative}
#
#                                 ...                          \
#                                 ...
# 11101100                        ...
# 11101103                        ...
# 11102100                        ...
# 11103100                        ...
# 11201100                        ...
# 11201101                        ...
# 11202100                        ...
# 11202200                        ...
# 11203100                        ...
# 11301100                        ...
# 11302100                        ...
# 11303100                        ...
# 11303101                        ...
# 11303102                        ...
# 11305100                        ...
# 11305101                        ...
# 11305102                        ...
# 11305103                        ...
# 11305104                        ...
# 11305105                        ...
# 11305106                        ...
# 11306100                        ...
# 11307100                        ...
# 11307101                        ...
# 11307102                        ...
# 11307103                        ...
# 11311100                        ...
# 11312100                        ...
# 11313100                        ...
# 11901301                        ...
# ...                             ...
# 53706200                        ...
# 53706300                        ...
# 53706400                        ...
# 53707100                        ...
# 53707200                        ...
# 53707300                        ...
# 53708100                        ...
# 53711100                        ...
# 53712100                        ...
# 53719900                        ...
# 55101100                        ...
# 55101200                        ...
# 55101300                        ...
# 55101400                        ...
# 55101500                        ...
# 55101600                        ...
# 55101700                        ...
# 55101900                        ...
# 55201100                        ...
# 55201200                        ...
# 55201300                        ...
# 55301100                        ...
# 55301200                        ...
# 55301300                        ...
# 55301400                        ...
# 55301500                        ...
# 55301600                        ...
# 55301700                        ...
# 55301800                        ...
# 55301900                        ...
#
#                                                              \
#                                                    55201300
# 11101100  {tactical, specialist, line, supervisor, opera...
# 11101103  {tactical, specialist, line, supervisor, opera...
# 11102100  {tactical, specialist, line, supervisor, opera...
# 11103100  {tactical, specialist, line, supervisor, opera...
# 11201100  {tactical, specialist, line, supervisor, opera...
# 11201101  {tactical, specialist, line, supervisor, opera...
# 11202100  {tactical, specialist, line, supervisor, opera...
# 11202200  {tactical, specialist, line, supervisor, opera...
# 11203100  {tactical, specialist, line, supervisor, opera...
# 11301100  {tactical, specialist, line, supervisor, opera...
# 11302100  {tactical, specialist, line, supervisor, opera...
# 11303100  {tactical, specialist, line, supervisor, opera...
# 11303101  {tactical, specialist, line, supervisor, opera...
# 11303102  {tactical, specialist, line, supervisor, opera...
# 11305100  {tactical, specialist, line, supervisor, opera...
# 11305101  {tactical, specialist, line, supervisor, opera...
# 11305102  {tactical, specialist, line, supervisor, opera...
# 11305103  {tactical, specialist, line, supervisor, opera...
# 11305104  {tactical, specialist, line, supervisor, opera...
# 11305105  {tactical, specialist, line, supervisor, opera...
# 11305106  {tactical, specialist, line, supervisor, opera...
# 11306100  {tactical, specialist, line, supervisor, opera...
# 11307100  {tactical, specialist, line, supervisor, opera...
# 11307101  {tactical, specialist, line, supervisor, opera...
# 11307102  {tactical, specialist, line, supervisor, opera...
# 11307103  {tactical, specialist, line, supervisor, opera...
# 11311100  {tactical, specialist, line, supervisor, opera...
# 11312100  {tactical, specialist, line, supervisor, opera...
# 11313100  {tactical, specialist, line, supervisor, opera...
# 11901301  {tactical, specialist, line, supervisor, opera...
# ...                                                     ...
# 53706200  {tactical, specialist, line, supervisor, opera...
# 53706300  {tactical, specialist, line, supervisor, opera...
# 53706400  {tactical, specialist, line, supervisor, opera...
# 53707100  {tactical, specialist, line, supervisor, opera...
# 53707200  {tactical, specialist, line, supervisor, opera...
# 53707300  {tactical, specialist, line, supervisor, opera...
# 53708100  {tactical, specialist, line, supervisor, opera...
# 53711100  {tactical, specialist, line, supervisor, opera...
# 53712100  {tactical, specialist, line, supervisor, opera...
# 53719900  {tactical, specialist, line, supervisor, opera...
# 55101100  {tactical, specialist, line, supervisor, opera...
# 55101200  {tactical, specialist, line, supervisor, opera...
# 55101300  {tactical, specialist, line, supervisor, opera...
# 55101400  {tactical, specialist, line, supervisor, opera...
# 55101500  {tactical, specialist, line, supervisor, opera...
# 55101600  {tactical, specialist, line, supervisor, opera...
# 55101700  {tactical, specialist, line, supervisor, opera...
# 55101900  {tactical, specialist, line, supervisor, opera...
# 55201100  {tactical, specialist, line, supervisor, opera...
# 55201200                                                NaN
# 55201300  {tactical, specialist, line, supervisor, opera...
# 55301100  {tactical, specialist, line, supervisor, opera...
# 55301200  {tactical, specialist, line, supervisor, opera...
# 55301300  {tactical, specialist, line, supervisor, opera...
# 55301400  {tactical, specialist, line, supervisor, opera...
# 55301500  {tactical, specialist, line, supervisor, opera...
# 55301600  {tactical, specialist, line, supervisor, opera...
# 55301700  {tactical, specialist, line, supervisor, opera...
# 55301800  {tactical, specialist, line, supervisor, opera...
# 55301900  {tactical, specialist, line, supervisor, opera...
#
#                                                                          \
#                      55301100                                  55301200
# 11101100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11101103  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11102100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11103100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11201100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11201101  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11202100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11202200  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11203100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11301100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11302100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11303100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11303101  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11303102  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11305100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11305101  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11305102  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11305103  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11305104  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11305105  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11305106  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11306100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11307100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11307101  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11307102  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11307103  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11311100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11312100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11313100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11901301  {member, crew, air}  {aircraft, launch, specialist, recovery}
# ...                       ...                                       ...
# 53706200  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 53706300  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 53706400  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 53707100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 53707200  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 53707300  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 53708100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 53711100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 53712100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 53719900  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55101100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55101200  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55101300  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55101400  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55101500  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55101600  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55101700  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55101900  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55201100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55201200  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55201300                  NaN  {aircraft, launch, specialist, recovery}
# 55301100  {member, crew, air}                                       NaN
# 55301200  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55301300  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55301400  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55301500  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55301600  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55301700  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55301800  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55301900  {member, crew, air}  {aircraft, launch, specialist, recovery}
#
#                                                      \
#                                            55301300
# 11101100  {armored, assault, crew, member, vehicle}
# 11101103  {armored, assault, crew, member, vehicle}
# 11102100  {armored, assault, crew, member, vehicle}
# 11103100  {armored, assault, crew, member, vehicle}
# 11201100  {armored, assault, crew, member, vehicle}
# 11201101  {armored, assault, crew, member, vehicle}
# 11202100  {armored, assault, crew, member, vehicle}
# 11202200  {armored, assault, crew, member, vehicle}
# 11203100  {armored, assault, crew, member, vehicle}
# 11301100  {armored, assault, crew, member, vehicle}
# 11302100  {armored, assault, crew, member, vehicle}
# 11303100  {armored, assault, crew, member, vehicle}
# 11303101  {armored, assault, crew, member, vehicle}
# 11303102  {armored, assault, crew, member, vehicle}
# 11305100  {armored, assault, crew, member, vehicle}
# 11305101  {armored, assault, crew, member, vehicle}
# 11305102  {armored, assault, crew, member, vehicle}
# 11305103  {armored, assault, crew, member, vehicle}
# 11305104  {armored, assault, crew, member, vehicle}
# 11305105  {armored, assault, crew, member, vehicle}
# 11305106  {armored, assault, crew, member, vehicle}
# 11306100  {armored, assault, crew, member, vehicle}
# 11307100  {armored, assault, crew, member, vehicle}
# 11307101  {armored, assault, crew, member, vehicle}
# 11307102  {armored, assault, crew, member, vehicle}
# 11307103  {armored, assault, crew, member, vehicle}
# 11311100  {armored, assault, crew, member, vehicle}
# 11312100  {armored, assault, crew, member, vehicle}
# 11313100  {armored, assault, crew, member, vehicle}
# 11901301  {armored, assault, crew, member, vehicle}
# ...                                             ...
# 53706200  {armored, assault, crew, member, vehicle}
# 53706300  {armored, assault, crew, member, vehicle}
# 53706400  {armored, assault, crew, member, vehicle}
# 53707100  {armored, assault, crew, member, vehicle}
# 53707200  {armored, assault, crew, member, vehicle}
# 53707300  {armored, assault, crew, member, vehicle}
# 53708100  {armored, assault, crew, member, vehicle}
# 53711100  {armored, assault, crew, member, vehicle}
# 53712100  {armored, assault, crew, member, vehicle}
# 53719900  {armored, assault, crew, member, vehicle}
# 55101100  {armored, assault, crew, member, vehicle}
# 55101200  {armored, assault, crew, member, vehicle}
# 55101300  {armored, assault, crew, member, vehicle}
# 55101400  {armored, assault, crew, member, vehicle}
# 55101500  {armored, assault, crew, member, vehicle}
# 55101600  {armored, assault, crew, member, vehicle}
# 55101700  {armored, assault, crew, member, vehicle}
# 55101900  {armored, assault, crew, member, vehicle}
# 55201100  {armored, assault, crew, member, vehicle}
# 55201200  {armored, assault, crew, member, vehicle}
# 55201300  {armored, assault, crew, member, vehicle}
# 55301100  {armored, assault, crew, member, vehicle}
# 55301200                                        NaN
# 55301300  {armored, assault, crew, member, vehicle}
# 55301400  {armored, assault, crew, member, vehicle}
# 55301500  {armored, assault, crew, member, vehicle}
# 55301600  {armored, assault, crew, member, vehicle}
# 55301700  {armored, assault, crew, member, vehicle}
# 55301800  {armored, assault, crew, member, vehicle}
# 55301900  {armored, assault, crew, member, vehicle}
#
#                                               \
#                                     55301400
# 11101100  {member, artillery, crew, missile}
# 11101103  {member, artillery, crew, missile}
# 11102100  {member, artillery, crew, missile}
# 11103100  {member, artillery, crew, missile}
# 11201100  {member, artillery, crew, missile}
# 11201101  {member, artillery, crew, missile}
# 11202100  {member, artillery, crew, missile}
# 11202200  {member, artillery, crew, missile}
# 11203100  {member, artillery, crew, missile}
# 11301100  {member, artillery, crew, missile}
# 11302100  {member, artillery, crew, missile}
# 11303100  {member, artillery, crew, missile}
# 11303101  {member, artillery, crew, missile}
# 11303102  {member, artillery, crew, missile}
# 11305100  {member, artillery, crew, missile}
# 11305101  {member, artillery, crew, missile}
# 11305102  {member, artillery, crew, missile}
# 11305103  {member, artillery, crew, missile}
# 11305104  {member, artillery, crew, missile}
# 11305105  {member, artillery, crew, missile}
# 11305106  {member, artillery, crew, missile}
# 11306100  {member, artillery, crew, missile}
# 11307100  {member, artillery, crew, missile}
# 11307101  {member, artillery, crew, missile}
# 11307102  {member, artillery, crew, missile}
# 11307103  {member, artillery, crew, missile}
# 11311100  {member, artillery, crew, missile}
# 11312100  {member, artillery, crew, missile}
# 11313100  {member, artillery, crew, missile}
# 11901301  {member, artillery, crew, missile}
# ...                                      ...
# 53706200  {member, artillery, crew, missile}
# 53706300  {member, artillery, crew, missile}
# 53706400  {member, artillery, crew, missile}
# 53707100  {member, artillery, crew, missile}
# 53707200  {member, artillery, crew, missile}
# 53707300  {member, artillery, crew, missile}
# 53708100  {member, artillery, crew, missile}
# 53711100  {member, artillery, crew, missile}
# 53712100  {member, artillery, crew, missile}
# 53719900  {member, artillery, crew, missile}
# 55101100  {member, artillery, crew, missile}
# 55101200  {member, artillery, crew, missile}
# 55101300  {member, artillery, crew, missile}
# 55101400  {member, artillery, crew, missile}
# 55101500  {member, artillery, crew, missile}
# 55101600  {member, artillery, crew, missile}
# 55101700  {member, artillery, crew, missile}
# 55101900  {member, artillery, crew, missile}
# 55201100  {member, artillery, crew, missile}
# 55201200  {member, artillery, crew, missile}
# 55201300  {member, artillery, crew, missile}
# 55301100  {member, artillery, crew, missile}
# 55301200  {member, artillery, crew, missile}
# 55301300                                 NaN
# 55301400  {member, artillery, crew, missile}
# 55301500  {member, artillery, crew, missile}
# 55301600  {member, artillery, crew, missile}
# 55301700  {member, artillery, crew, missile}
# 55301800  {member, artillery, crew, missile}
# 55301900  {member, artillery, crew, missile}
#
#                                                               \
#                                         55301500    55301600
# 11101100  {control, center, specialist, command}  {infantry}
# 11101103  {control, center, specialist, command}  {infantry}
# 11102100  {control, center, specialist, command}  {infantry}
# 11103100  {control, center, specialist, command}  {infantry}
# 11201100  {control, center, specialist, command}  {infantry}
# 11201101  {control, center, specialist, command}  {infantry}
# 11202100  {control, center, specialist, command}  {infantry}
# 11202200  {control, center, specialist, command}  {infantry}
# 11203100  {control, center, specialist, command}  {infantry}
# 11301100  {control, center, specialist, command}  {infantry}
# 11302100  {control, center, specialist, command}  {infantry}
# 11303100  {control, center, specialist, command}  {infantry}
# 11303101  {control, center, specialist, command}  {infantry}
# 11303102  {control, center, specialist, command}  {infantry}
# 11305100  {control, center, specialist, command}  {infantry}
# 11305101  {control, center, specialist, command}  {infantry}
# 11305102  {control, center, specialist, command}  {infantry}
# 11305103  {control, center, specialist, command}  {infantry}
# 11305104  {control, center, specialist, command}  {infantry}
# 11305105  {control, center, specialist, command}  {infantry}
# 11305106  {control, center, specialist, command}  {infantry}
# 11306100  {control, center, specialist, command}  {infantry}
# 11307100  {control, center, specialist, command}  {infantry}
# 11307101  {control, center, specialist, command}  {infantry}
# 11307102  {control, center, specialist, command}  {infantry}
# 11307103  {control, center, specialist, command}  {infantry}
# 11311100  {control, center, specialist, command}  {infantry}
# 11312100  {control, center, specialist, command}  {infantry}
# 11313100  {control, center, specialist, command}  {infantry}
# 11901301  {control, center, specialist, command}  {infantry}
# ...                                          ...         ...
# 53706200  {control, center, specialist, command}  {infantry}
# 53706300  {control, center, specialist, command}  {infantry}
# 53706400  {control, center, specialist, command}  {infantry}
# 53707100  {control, center, specialist, command}  {infantry}
# 53707200  {control, center, specialist, command}  {infantry}
# 53707300  {control, center, specialist, command}  {infantry}
# 53708100  {control, center, specialist, command}  {infantry}
# 53711100  {control, center, specialist, command}  {infantry}
# 53712100  {control, center, specialist, command}  {infantry}
# 53719900  {control, center, specialist, command}  {infantry}
# 55101100  {control, center, specialist, command}  {infantry}
# 55101200  {control, center, specialist, command}  {infantry}
# 55101300  {control, center, specialist, command}  {infantry}
# 55101400  {control, center, specialist, command}  {infantry}
# 55101500  {control, center, specialist, command}  {infantry}
# 55101600  {control, center, specialist, command}  {infantry}
# 55101700  {control, center, specialist, command}  {infantry}
# 55101900  {control, center, specialist, command}  {infantry}
# 55201100  {control, center, specialist, command}  {infantry}
# 55201200  {control, center, specialist, command}  {infantry}
# 55201300  {control, center, specialist, command}  {infantry}
# 55301100  {control, center, specialist, command}  {infantry}
# 55301200  {control, center, specialist, command}  {infantry}
# 55301300  {control, center, specialist, command}  {infantry}
# 55301400                                     NaN  {infantry}
# 55301500  {control, center, specialist, command}         NaN
# 55301600  {control, center, specialist, command}  {infantry}
# 55301700  {control, center, specialist, command}  {infantry}
# 55301800  {control, center, specialist, command}  {infantry}
# 55301900  {control, center, specialist, command}  {infantry}
#
#                                                         \
#                             55301700          55301800
# 11101100  {technician, radar, sonar}  {special, force}
# 11101103  {technician, radar, sonar}  {special, force}
# 11102100  {technician, radar, sonar}  {special, force}
# 11103100  {technician, radar, sonar}  {special, force}
# 11201100  {technician, radar, sonar}  {special, force}
# 11201101  {technician, radar, sonar}  {special, force}
# 11202100  {technician, radar, sonar}  {special, force}
# 11202200  {technician, radar, sonar}  {special, force}
# 11203100  {technician, radar, sonar}  {special, force}
# 11301100  {technician, radar, sonar}  {special, force}
# 11302100  {technician, radar, sonar}  {special, force}
# 11303100  {technician, radar, sonar}  {special, force}
# 11303101  {technician, radar, sonar}  {special, force}
# 11303102  {technician, radar, sonar}  {special, force}
# 11305100  {technician, radar, sonar}  {special, force}
# 11305101  {technician, radar, sonar}  {special, force}
# 11305102  {technician, radar, sonar}  {special, force}
# 11305103  {technician, radar, sonar}  {special, force}
# 11305104  {technician, radar, sonar}  {special, force}
# 11305105  {technician, radar, sonar}  {special, force}
# 11305106  {technician, radar, sonar}  {special, force}
# 11306100  {technician, radar, sonar}  {special, force}
# 11307100  {technician, radar, sonar}  {special, force}
# 11307101  {technician, radar, sonar}  {special, force}
# 11307102  {technician, radar, sonar}  {special, force}
# 11307103  {technician, radar, sonar}  {special, force}
# 11311100  {technician, radar, sonar}  {special, force}
# 11312100  {technician, radar, sonar}  {special, force}
# 11313100  {technician, radar, sonar}  {special, force}
# 11901301  {technician, radar, sonar}  {special, force}
# ...                              ...               ...
# 53706200  {technician, radar, sonar}  {special, force}
# 53706300  {technician, radar, sonar}  {special, force}
# 53706400  {technician, radar, sonar}  {special, force}
# 53707100  {technician, radar, sonar}  {special, force}
# 53707200  {technician, radar, sonar}  {special, force}
# 53707300  {technician, radar, sonar}  {special, force}
# 53708100  {technician, radar, sonar}  {special, force}
# 53711100  {technician, radar, sonar}  {special, force}
# 53712100  {technician, radar, sonar}  {special, force}
# 53719900  {technician, radar, sonar}  {special, force}
# 55101100  {technician, radar, sonar}  {special, force}
# 55101200  {technician, radar, sonar}  {special, force}
# 55101300  {technician, radar, sonar}  {special, force}
# 55101400  {technician, radar, sonar}  {special, force}
# 55101500  {technician, radar, sonar}  {special, force}
# 55101600  {technician, radar, sonar}  {special, force}
# 55101700  {technician, radar, sonar}  {special, force}
# 55101900  {technician, radar, sonar}  {special, force}
# 55201100  {technician, radar, sonar}  {special, force}
# 55201200  {technician, radar, sonar}  {special, force}
# 55201300  {technician, radar, sonar}  {special, force}
# 55301100  {technician, radar, sonar}  {special, force}
# 55301200  {technician, radar, sonar}  {special, force}
# 55301300  {technician, radar, sonar}  {special, force}
# 55301400  {technician, radar, sonar}  {special, force}
# 55301500  {technician, radar, sonar}  {special, force}
# 55301600                         NaN  {special, force}
# 55301700  {technician, radar, sonar}               NaN
# 55301800  {technician, radar, sonar}  {special, force}
# 55301900  {technician, radar, sonar}  {special, force}
#
#
#                                                    55301900
# 11101100  {tactical, operation, crew, member, enlisted, ...
# 11101103  {tactical, operation, crew, member, enlisted, ...
# 11102100  {tactical, operation, crew, member, enlisted, ...
# 11103100  {tactical, operation, crew, member, enlisted, ...
# 11201100  {tactical, operation, crew, member, enlisted, ...
# 11201101  {tactical, operation, crew, member, enlisted, ...
# 11202100  {tactical, operation, crew, member, enlisted, ...
# 11202200  {tactical, operation, crew, member, enlisted, ...
# 11203100  {tactical, operation, crew, member, enlisted, ...
# 11301100  {tactical, operation, crew, member, enlisted, ...
# 11302100  {tactical, operation, crew, member, enlisted, ...
# 11303100  {tactical, operation, crew, member, enlisted, ...
# 11303101  {tactical, operation, crew, member, enlisted, ...
# 11303102  {tactical, operation, crew, member, enlisted, ...
# 11305100  {tactical, operation, crew, member, enlisted, ...
# 11305101  {tactical, operation, crew, member, enlisted, ...
# 11305102  {tactical, operation, crew, member, enlisted, ...
# 11305103  {tactical, operation, crew, member, enlisted, ...
# 11305104  {tactical, operation, crew, member, enlisted, ...
# 11305105  {tactical, operation, crew, member, enlisted, ...
# 11305106  {tactical, operation, crew, member, enlisted, ...
# 11306100  {tactical, operation, crew, member, enlisted, ...
# 11307100  {tactical, operation, crew, member, enlisted, ...
# 11307101  {tactical, operation, crew, member, enlisted, ...
# 11307102  {tactical, operation, crew, member, enlisted, ...
# 11307103  {tactical, operation, crew, member, enlisted, ...
# 11311100  {tactical, operation, crew, member, enlisted, ...
# 11312100  {tactical, operation, crew, member, enlisted, ...
# 11313100  {tactical, operation, crew, member, enlisted, ...
# 11901301  {tactical, operation, crew, member, enlisted, ...
# ...                                                     ...
# 53706200  {tactical, operation, crew, member, enlisted, ...
# 53706300  {tactical, operation, crew, member, enlisted, ...
# 53706400  {tactical, operation, crew, member, enlisted, ...
# 53707100  {tactical, operation, crew, member, enlisted, ...
# 53707200  {tactical, operation, crew, member, enlisted, ...
# 53707300  {tactical, operation, crew, member, enlisted, ...
# 53708100  {tactical, operation, crew, member, enlisted, ...
# 53711100  {tactical, operation, crew, member, enlisted, ...
# 53712100  {tactical, operation, crew, member, enlisted, ...
# 53719900  {tactical, operation, crew, member, enlisted, ...
# 55101100  {tactical, operation, crew, member, enlisted, ...
# 55101200  {tactical, operation, crew, member, enlisted, ...
# 55101300  {tactical, operation, crew, member, enlisted, ...
# 55101400  {tactical, operation, crew, member, enlisted, ...
# 55101500  {tactical, operation, crew, member, enlisted, ...
# 55101600  {tactical, operation, crew, member, enlisted, ...
# 55101700  {tactical, operation, crew, member, enlisted, ...
# 55101900  {tactical, operation, crew, member, enlisted, ...
# 55201100  {tactical, operation, crew, member, enlisted, ...
# 55201200  {tactical, operation, crew, member, enlisted, ...
# 55201300  {tactical, operation, crew, member, enlisted, ...
# 55301100  {tactical, operation, crew, member, enlisted, ...
# 55301200  {tactical, operation, crew, member, enlisted, ...
# 55301300  {tactical, operation, crew, member, enlisted, ...
# 55301400  {tactical, operation, crew, member, enlisted, ...
# 55301500  {tactical, operation, crew, member, enlisted, ...
# 55301600  {tactical, operation, crew, member, enlisted, ...
# 55301700  {tactical, operation, crew, member, enlisted, ...
# 55301800                                                NaN
# 55301900  {tactical, operation, crew, member, enlisted, ...
#
# [1109 rows x 1109 columns]

# %%
aaa = [in_common(step) for step in range(len(tt)-1)]

# %%
ix
# Out:
# array(['11101100', '11101103', '11102100', ..., '55301700', '55301800',
#        '55301900'], dtype=object)

# %%
len(tt)
# Out:
# 1109

# %%
np.outer([1, 2, 3], [4, 5, 6])
# Out:
# array([[ 4,  5,  6],
#        [ 8, 10, 12],
#        [12, 15, 18]])

# %%
df = tt['title_vec'].apply(set)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-126-123d87a010a0> in <module>()
#       2 df2 = pd.DataFrame(df.loc[ix_x])
#       3 df2['y']= ix_y
# ----> 4 df2['title_vec_y'] = df.loc[ix_y]
#       5 df2
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3114         else:
#    3115             # set column
# -> 3116             self._set_item(key, value)
#    3117
#    3118     def _setitem_slice(self, key, value):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3189
#    3190         self._ensure_valid_index(value)
# -> 3191         value = self._sanitize_column(key, value)
#    3192         NDFrame._set_item(self, key, value)
#    3193
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3361
#    3362         if isinstance(value, Series):
# -> 3363             value = reindexer(value)
#    3364
#    3365         elif isinstance(value, DataFrame):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in reindexer(value)
#    3348                 # GH 4107
#    3349                 try:
# -> 3350                     value = value.reindex(self.index)._values
#    3351                 except Exception as e:
#    3352
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py in reindex(self, index, **kwargs)
#    3320     @Appender(generic._shared_docs['reindex'] % _shared_doc_kwargs)
#    3321     def reindex(self, index=None, **kwargs):
# -> 3322         return super(Series, self).reindex(index=index, **kwargs)
#    3323
#    3324     def drop(self, labels=None, axis=0, index=None, columns=None,
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    3683         # perform the reindex on the axes
#    3684         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 3685                                   fill_value, copy).__finalize__(self)
#    3686
#    3687     def _reindex_axes(self, axes, level, limit, tolerance, method, fill_value,
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3696             ax = self._get_axis(a)
#    3697             new_index, indexer = ax.reindex(labels, level=level, limit=limit,
# -> 3698                                             tolerance=tolerance, method=method)
#    3699
#    3700             axis = self._get_axis_number(a)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in reindex(self, target, method, level, limit, tolerance)
#    3608                         raise ValueError("cannot reindex a non-unique index "
#    3609                                          "with a method or limit")
# -> 3610                     indexer, missing = self.get_indexer_non_unique(target)
#    3611
#    3612         if preserve_names and target.nlevels == 1 and target.name != self.name:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_indexer_non_unique(self, target)
#    3357             tgt_values = target._ndarray_values
#    3358
# -> 3359         indexer, missing = self._engine.get_indexer_non_unique(tgt_values)
#    3360         return _ensure_platform_int(indexer), missing
#    3361
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_indexer_non_unique()
#
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in resize(a, new_shape)
#    1318         extra = Na - extra
#    1319
# -> 1320     a = concatenate((a,) * n_copies)
#    1321     if extra > 0:
#    1322         a = a[:-extra]
#
# KeyboardInterrupt:

# %%
df2.unstack()
# Out:
#                            0                                    \
#                     11101100                          11101103
# 11101100  {chief, executive}                               NaN
# 11101103  {chief, executive}  {sustainability, chief, officer}
# 11102100  {chief, executive}  {sustainability, chief, officer}
# 11103100  {chief, executive}  {sustainability, chief, officer}
# 11201100  {chief, executive}  {sustainability, chief, officer}
# 11201101  {chief, executive}  {sustainability, chief, officer}
# 11202100  {chief, executive}  {sustainability, chief, officer}
# 11202200  {chief, executive}  {sustainability, chief, officer}
# 11203100  {chief, executive}  {sustainability, chief, officer}
# 11301100  {chief, executive}  {sustainability, chief, officer}
# 11302100  {chief, executive}  {sustainability, chief, officer}
# 11303100  {chief, executive}  {sustainability, chief, officer}
# 11303101  {chief, executive}  {sustainability, chief, officer}
# 11303102  {chief, executive}  {sustainability, chief, officer}
# 11305100  {chief, executive}  {sustainability, chief, officer}
# 11305101  {chief, executive}  {sustainability, chief, officer}
# 11305102  {chief, executive}  {sustainability, chief, officer}
# 11305103  {chief, executive}  {sustainability, chief, officer}
# 11305104  {chief, executive}  {sustainability, chief, officer}
# 11305105  {chief, executive}  {sustainability, chief, officer}
# 11305106  {chief, executive}  {sustainability, chief, officer}
# 11306100  {chief, executive}  {sustainability, chief, officer}
# 11307100  {chief, executive}  {sustainability, chief, officer}
# 11307101  {chief, executive}  {sustainability, chief, officer}
# 11307102  {chief, executive}  {sustainability, chief, officer}
# 11307103  {chief, executive}  {sustainability, chief, officer}
# 11311100  {chief, executive}  {sustainability, chief, officer}
# 11312100  {chief, executive}  {sustainability, chief, officer}
# 11313100  {chief, executive}  {sustainability, chief, officer}
# 11901301  {chief, executive}  {sustainability, chief, officer}
# ...                      ...                               ...
# 53706200  {chief, executive}  {sustainability, chief, officer}
# 53706300  {chief, executive}  {sustainability, chief, officer}
# 53706400  {chief, executive}  {sustainability, chief, officer}
# 53707100  {chief, executive}  {sustainability, chief, officer}
# 53707200  {chief, executive}  {sustainability, chief, officer}
# 53707300  {chief, executive}  {sustainability, chief, officer}
# 53708100  {chief, executive}  {sustainability, chief, officer}
# 53711100  {chief, executive}  {sustainability, chief, officer}
# 53712100  {chief, executive}  {sustainability, chief, officer}
# 53719900  {chief, executive}  {sustainability, chief, officer}
# 55101100  {chief, executive}  {sustainability, chief, officer}
# 55101200  {chief, executive}  {sustainability, chief, officer}
# 55101300  {chief, executive}  {sustainability, chief, officer}
# 55101400  {chief, executive}  {sustainability, chief, officer}
# 55101500  {chief, executive}  {sustainability, chief, officer}
# 55101600  {chief, executive}  {sustainability, chief, officer}
# 55101700  {chief, executive}  {sustainability, chief, officer}
# 55101900  {chief, executive}  {sustainability, chief, officer}
# 55201100  {chief, executive}  {sustainability, chief, officer}
# 55201200  {chief, executive}  {sustainability, chief, officer}
# 55201300  {chief, executive}  {sustainability, chief, officer}
# 55301100  {chief, executive}  {sustainability, chief, officer}
# 55301200  {chief, executive}  {sustainability, chief, officer}
# 55301300  {chief, executive}  {sustainability, chief, officer}
# 55301400  {chief, executive}  {sustainability, chief, officer}
# 55301500  {chief, executive}  {sustainability, chief, officer}
# 55301600  {chief, executive}  {sustainability, chief, officer}
# 55301700  {chief, executive}  {sustainability, chief, officer}
# 55301800  {chief, executive}  {sustainability, chief, officer}
# 55301900                 NaN  {sustainability, chief, officer}
#
#                                                        \
#                                11102100      11103100
# 11101100  {operation, manager, general}  {legislator}
# 11101103                            NaN  {legislator}
# 11102100  {operation, manager, general}           NaN
# 11103100  {operation, manager, general}  {legislator}
# 11201100  {operation, manager, general}  {legislator}
# 11201101  {operation, manager, general}  {legislator}
# 11202100  {operation, manager, general}  {legislator}
# 11202200  {operation, manager, general}  {legislator}
# 11203100  {operation, manager, general}  {legislator}
# 11301100  {operation, manager, general}  {legislator}
# 11302100  {operation, manager, general}  {legislator}
# 11303100  {operation, manager, general}  {legislator}
# 11303101  {operation, manager, general}  {legislator}
# 11303102  {operation, manager, general}  {legislator}
# 11305100  {operation, manager, general}  {legislator}
# 11305101  {operation, manager, general}  {legislator}
# 11305102  {operation, manager, general}  {legislator}
# 11305103  {operation, manager, general}  {legislator}
# 11305104  {operation, manager, general}  {legislator}
# 11305105  {operation, manager, general}  {legislator}
# 11305106  {operation, manager, general}  {legislator}
# 11306100  {operation, manager, general}  {legislator}
# 11307100  {operation, manager, general}  {legislator}
# 11307101  {operation, manager, general}  {legislator}
# 11307102  {operation, manager, general}  {legislator}
# 11307103  {operation, manager, general}  {legislator}
# 11311100  {operation, manager, general}  {legislator}
# 11312100  {operation, manager, general}  {legislator}
# 11313100  {operation, manager, general}  {legislator}
# 11901301  {operation, manager, general}  {legislator}
# ...                                 ...           ...
# 53706200  {operation, manager, general}  {legislator}
# 53706300  {operation, manager, general}  {legislator}
# 53706400  {operation, manager, general}  {legislator}
# 53707100  {operation, manager, general}  {legislator}
# 53707200  {operation, manager, general}  {legislator}
# 53707300  {operation, manager, general}  {legislator}
# 53708100  {operation, manager, general}  {legislator}
# 53711100  {operation, manager, general}  {legislator}
# 53712100  {operation, manager, general}  {legislator}
# 53719900  {operation, manager, general}  {legislator}
# 55101100  {operation, manager, general}  {legislator}
# 55101200  {operation, manager, general}  {legislator}
# 55101300  {operation, manager, general}  {legislator}
# 55101400  {operation, manager, general}  {legislator}
# 55101500  {operation, manager, general}  {legislator}
# 55101600  {operation, manager, general}  {legislator}
# 55101700  {operation, manager, general}  {legislator}
# 55101900  {operation, manager, general}  {legislator}
# 55201100  {operation, manager, general}  {legislator}
# 55201200  {operation, manager, general}  {legislator}
# 55201300  {operation, manager, general}  {legislator}
# 55301100  {operation, manager, general}  {legislator}
# 55301200  {operation, manager, general}  {legislator}
# 55301300  {operation, manager, general}  {legislator}
# 55301400  {operation, manager, general}  {legislator}
# 55301500  {operation, manager, general}  {legislator}
# 55301600  {operation, manager, general}  {legislator}
# 55301700  {operation, manager, general}  {legislator}
# 55301800  {operation, manager, general}  {legislator}
# 55301900  {operation, manager, general}  {legislator}
#
#                                                                 \
#                                    11201100           11201101
# 11101100  {advertising, manager, promotion}  {green, marketer}
# 11101103  {advertising, manager, promotion}  {green, marketer}
# 11102100  {advertising, manager, promotion}  {green, marketer}
# 11103100                                NaN  {green, marketer}
# 11201100  {advertising, manager, promotion}                NaN
# 11201101  {advertising, manager, promotion}  {green, marketer}
# 11202100  {advertising, manager, promotion}  {green, marketer}
# 11202200  {advertising, manager, promotion}  {green, marketer}
# 11203100  {advertising, manager, promotion}  {green, marketer}
# 11301100  {advertising, manager, promotion}  {green, marketer}
# 11302100  {advertising, manager, promotion}  {green, marketer}
# 11303100  {advertising, manager, promotion}  {green, marketer}
# 11303101  {advertising, manager, promotion}  {green, marketer}
# 11303102  {advertising, manager, promotion}  {green, marketer}
# 11305100  {advertising, manager, promotion}  {green, marketer}
# 11305101  {advertising, manager, promotion}  {green, marketer}
# 11305102  {advertising, manager, promotion}  {green, marketer}
# 11305103  {advertising, manager, promotion}  {green, marketer}
# 11305104  {advertising, manager, promotion}  {green, marketer}
# 11305105  {advertising, manager, promotion}  {green, marketer}
# 11305106  {advertising, manager, promotion}  {green, marketer}
# 11306100  {advertising, manager, promotion}  {green, marketer}
# 11307100  {advertising, manager, promotion}  {green, marketer}
# 11307101  {advertising, manager, promotion}  {green, marketer}
# 11307102  {advertising, manager, promotion}  {green, marketer}
# 11307103  {advertising, manager, promotion}  {green, marketer}
# 11311100  {advertising, manager, promotion}  {green, marketer}
# 11312100  {advertising, manager, promotion}  {green, marketer}
# 11313100  {advertising, manager, promotion}  {green, marketer}
# 11901301  {advertising, manager, promotion}  {green, marketer}
# ...                                     ...                ...
# 53706200  {advertising, manager, promotion}  {green, marketer}
# 53706300  {advertising, manager, promotion}  {green, marketer}
# 53706400  {advertising, manager, promotion}  {green, marketer}
# 53707100  {advertising, manager, promotion}  {green, marketer}
# 53707200  {advertising, manager, promotion}  {green, marketer}
# 53707300  {advertising, manager, promotion}  {green, marketer}
# 53708100  {advertising, manager, promotion}  {green, marketer}
# 53711100  {advertising, manager, promotion}  {green, marketer}
# 53712100  {advertising, manager, promotion}  {green, marketer}
# 53719900  {advertising, manager, promotion}  {green, marketer}
# 55101100  {advertising, manager, promotion}  {green, marketer}
# 55101200  {advertising, manager, promotion}  {green, marketer}
# 55101300  {advertising, manager, promotion}  {green, marketer}
# 55101400  {advertising, manager, promotion}  {green, marketer}
# 55101500  {advertising, manager, promotion}  {green, marketer}
# 55101600  {advertising, manager, promotion}  {green, marketer}
# 55101700  {advertising, manager, promotion}  {green, marketer}
# 55101900  {advertising, manager, promotion}  {green, marketer}
# 55201100  {advertising, manager, promotion}  {green, marketer}
# 55201200  {advertising, manager, promotion}  {green, marketer}
# 55201300  {advertising, manager, promotion}  {green, marketer}
# 55301100  {advertising, manager, promotion}  {green, marketer}
# 55301200  {advertising, manager, promotion}  {green, marketer}
# 55301300  {advertising, manager, promotion}  {green, marketer}
# 55301400  {advertising, manager, promotion}  {green, marketer}
# 55301500  {advertising, manager, promotion}  {green, marketer}
# 55301600  {advertising, manager, promotion}  {green, marketer}
# 55301700  {advertising, manager, promotion}  {green, marketer}
# 55301800  {advertising, manager, promotion}  {green, marketer}
# 55301900  {advertising, manager, promotion}  {green, marketer}
#
#                                                  \
#                       11202100         11202200
# 11101100  {manager, marketing}  {manager, sale}
# 11101103  {manager, marketing}  {manager, sale}
# 11102100  {manager, marketing}  {manager, sale}
# 11103100  {manager, marketing}  {manager, sale}
# 11201100  {manager, marketing}  {manager, sale}
# 11201101                   NaN  {manager, sale}
# 11202100  {manager, marketing}              NaN
# 11202200  {manager, marketing}  {manager, sale}
# 11203100  {manager, marketing}  {manager, sale}
# 11301100  {manager, marketing}  {manager, sale}
# 11302100  {manager, marketing}  {manager, sale}
# 11303100  {manager, marketing}  {manager, sale}
# 11303101  {manager, marketing}  {manager, sale}
# 11303102  {manager, marketing}  {manager, sale}
# 11305100  {manager, marketing}  {manager, sale}
# 11305101  {manager, marketing}  {manager, sale}
# 11305102  {manager, marketing}  {manager, sale}
# 11305103  {manager, marketing}  {manager, sale}
# 11305104  {manager, marketing}  {manager, sale}
# 11305105  {manager, marketing}  {manager, sale}
# 11305106  {manager, marketing}  {manager, sale}
# 11306100  {manager, marketing}  {manager, sale}
# 11307100  {manager, marketing}  {manager, sale}
# 11307101  {manager, marketing}  {manager, sale}
# 11307102  {manager, marketing}  {manager, sale}
# 11307103  {manager, marketing}  {manager, sale}
# 11311100  {manager, marketing}  {manager, sale}
# 11312100  {manager, marketing}  {manager, sale}
# 11313100  {manager, marketing}  {manager, sale}
# 11901301  {manager, marketing}  {manager, sale}
# ...                        ...              ...
# 53706200  {manager, marketing}  {manager, sale}
# 53706300  {manager, marketing}  {manager, sale}
# 53706400  {manager, marketing}  {manager, sale}
# 53707100  {manager, marketing}  {manager, sale}
# 53707200  {manager, marketing}  {manager, sale}
# 53707300  {manager, marketing}  {manager, sale}
# 53708100  {manager, marketing}  {manager, sale}
# 53711100  {manager, marketing}  {manager, sale}
# 53712100  {manager, marketing}  {manager, sale}
# 53719900  {manager, marketing}  {manager, sale}
# 55101100  {manager, marketing}  {manager, sale}
# 55101200  {manager, marketing}  {manager, sale}
# 55101300  {manager, marketing}  {manager, sale}
# 55101400  {manager, marketing}  {manager, sale}
# 55101500  {manager, marketing}  {manager, sale}
# 55101600  {manager, marketing}  {manager, sale}
# 55101700  {manager, marketing}  {manager, sale}
# 55101900  {manager, marketing}  {manager, sale}
# 55201100  {manager, marketing}  {manager, sale}
# 55201200  {manager, marketing}  {manager, sale}
# 55201300  {manager, marketing}  {manager, sale}
# 55301100  {manager, marketing}  {manager, sale}
# 55301200  {manager, marketing}  {manager, sale}
# 55301300  {manager, marketing}  {manager, sale}
# 55301400  {manager, marketing}  {manager, sale}
# 55301500  {manager, marketing}  {manager, sale}
# 55301600  {manager, marketing}  {manager, sale}
# 55301700  {manager, marketing}  {manager, sale}
# 55301800  {manager, marketing}  {manager, sale}
# 55301900  {manager, marketing}  {manager, sale}
#
#                                                     \
#                                           11203100
# 11101100  {fundraising, manager, public, relation}
# 11101103  {fundraising, manager, public, relation}
# 11102100  {fundraising, manager, public, relation}
# 11103100  {fundraising, manager, public, relation}
# 11201100  {fundraising, manager, public, relation}
# 11201101  {fundraising, manager, public, relation}
# 11202100  {fundraising, manager, public, relation}
# 11202200                                       NaN
# 11203100  {fundraising, manager, public, relation}
# 11301100  {fundraising, manager, public, relation}
# 11302100  {fundraising, manager, public, relation}
# 11303100  {fundraising, manager, public, relation}
# 11303101  {fundraising, manager, public, relation}
# 11303102  {fundraising, manager, public, relation}
# 11305100  {fundraising, manager, public, relation}
# 11305101  {fundraising, manager, public, relation}
# 11305102  {fundraising, manager, public, relation}
# 11305103  {fundraising, manager, public, relation}
# 11305104  {fundraising, manager, public, relation}
# 11305105  {fundraising, manager, public, relation}
# 11305106  {fundraising, manager, public, relation}
# 11306100  {fundraising, manager, public, relation}
# 11307100  {fundraising, manager, public, relation}
# 11307101  {fundraising, manager, public, relation}
# 11307102  {fundraising, manager, public, relation}
# 11307103  {fundraising, manager, public, relation}
# 11311100  {fundraising, manager, public, relation}
# 11312100  {fundraising, manager, public, relation}
# 11313100  {fundraising, manager, public, relation}
# 11901301  {fundraising, manager, public, relation}
# ...                                            ...
# 53706200  {fundraising, manager, public, relation}
# 53706300  {fundraising, manager, public, relation}
# 53706400  {fundraising, manager, public, relation}
# 53707100  {fundraising, manager, public, relation}
# 53707200  {fundraising, manager, public, relation}
# 53707300  {fundraising, manager, public, relation}
# 53708100  {fundraising, manager, public, relation}
# 53711100  {fundraising, manager, public, relation}
# 53712100  {fundraising, manager, public, relation}
# 53719900  {fundraising, manager, public, relation}
# 55101100  {fundraising, manager, public, relation}
# 55101200  {fundraising, manager, public, relation}
# 55101300  {fundraising, manager, public, relation}
# 55101400  {fundraising, manager, public, relation}
# 55101500  {fundraising, manager, public, relation}
# 55101600  {fundraising, manager, public, relation}
# 55101700  {fundraising, manager, public, relation}
# 55101900  {fundraising, manager, public, relation}
# 55201100  {fundraising, manager, public, relation}
# 55201200  {fundraising, manager, public, relation}
# 55201300  {fundraising, manager, public, relation}
# 55301100  {fundraising, manager, public, relation}
# 55301200  {fundraising, manager, public, relation}
# 55301300  {fundraising, manager, public, relation}
# 55301400  {fundraising, manager, public, relation}
# 55301500  {fundraising, manager, public, relation}
# 55301600  {fundraising, manager, public, relation}
# 55301700  {fundraising, manager, public, relation}
# 55301800  {fundraising, manager, public, relation}
# 55301900  {fundraising, manager, public, relation}
#
#                                               \
#                                     11301100
# 11101100  {manager, service, administrative}
# 11101103  {manager, service, administrative}
# 11102100  {manager, service, administrative}
# 11103100  {manager, service, administrative}
# 11201100  {manager, service, administrative}
# 11201101  {manager, service, administrative}
# 11202100  {manager, service, administrative}
# 11202200  {manager, service, administrative}
# 11203100                                 NaN
# 11301100  {manager, service, administrative}
# 11302100  {manager, service, administrative}
# 11303100  {manager, service, administrative}
# 11303101  {manager, service, administrative}
# 11303102  {manager, service, administrative}
# 11305100  {manager, service, administrative}
# 11305101  {manager, service, administrative}
# 11305102  {manager, service, administrative}
# 11305103  {manager, service, administrative}
# 11305104  {manager, service, administrative}
# 11305105  {manager, service, administrative}
# 11305106  {manager, service, administrative}
# 11306100  {manager, service, administrative}
# 11307100  {manager, service, administrative}
# 11307101  {manager, service, administrative}
# 11307102  {manager, service, administrative}
# 11307103  {manager, service, administrative}
# 11311100  {manager, service, administrative}
# 11312100  {manager, service, administrative}
# 11313100  {manager, service, administrative}
# 11901301  {manager, service, administrative}
# ...                                      ...
# 53706200  {manager, service, administrative}
# 53706300  {manager, service, administrative}
# 53706400  {manager, service, administrative}
# 53707100  {manager, service, administrative}
# 53707200  {manager, service, administrative}
# 53707300  {manager, service, administrative}
# 53708100  {manager, service, administrative}
# 53711100  {manager, service, administrative}
# 53712100  {manager, service, administrative}
# 53719900  {manager, service, administrative}
# 55101100  {manager, service, administrative}
# 55101200  {manager, service, administrative}
# 55101300  {manager, service, administrative}
# 55101400  {manager, service, administrative}
# 55101500  {manager, service, administrative}
# 55101600  {manager, service, administrative}
# 55101700  {manager, service, administrative}
# 55101900  {manager, service, administrative}
# 55201100  {manager, service, administrative}
# 55201200  {manager, service, administrative}
# 55201300  {manager, service, administrative}
# 55301100  {manager, service, administrative}
# 55301200  {manager, service, administrative}
# 55301300  {manager, service, administrative}
# 55301400  {manager, service, administrative}
# 55301500  {manager, service, administrative}
# 55301600  {manager, service, administrative}
# 55301700  {manager, service, administrative}
# 55301800  {manager, service, administrative}
# 55301900  {manager, service, administrative}
#
#                                 ...                          \
#                                 ...
# 11101100                        ...
# 11101103                        ...
# 11102100                        ...
# 11103100                        ...
# 11201100                        ...
# 11201101                        ...
# 11202100                        ...
# 11202200                        ...
# 11203100                        ...
# 11301100                        ...
# 11302100                        ...
# 11303100                        ...
# 11303101                        ...
# 11303102                        ...
# 11305100                        ...
# 11305101                        ...
# 11305102                        ...
# 11305103                        ...
# 11305104                        ...
# 11305105                        ...
# 11305106                        ...
# 11306100                        ...
# 11307100                        ...
# 11307101                        ...
# 11307102                        ...
# 11307103                        ...
# 11311100                        ...
# 11312100                        ...
# 11313100                        ...
# 11901301                        ...
# ...                             ...
# 53706200                        ...
# 53706300                        ...
# 53706400                        ...
# 53707100                        ...
# 53707200                        ...
# 53707300                        ...
# 53708100                        ...
# 53711100                        ...
# 53712100                        ...
# 53719900                        ...
# 55101100                        ...
# 55101200                        ...
# 55101300                        ...
# 55101400                        ...
# 55101500                        ...
# 55101600                        ...
# 55101700                        ...
# 55101900                        ...
# 55201100                        ...
# 55201200                        ...
# 55201300                        ...
# 55301100                        ...
# 55301200                        ...
# 55301300                        ...
# 55301400                        ...
# 55301500                        ...
# 55301600                        ...
# 55301700                        ...
# 55301800                        ...
# 55301900                        ...
#
#                                                              \
#                                                    55201300
# 11101100  {tactical, specialist, line, supervisor, opera...
# 11101103  {tactical, specialist, line, supervisor, opera...
# 11102100  {tactical, specialist, line, supervisor, opera...
# 11103100  {tactical, specialist, line, supervisor, opera...
# 11201100  {tactical, specialist, line, supervisor, opera...
# 11201101  {tactical, specialist, line, supervisor, opera...
# 11202100  {tactical, specialist, line, supervisor, opera...
# 11202200  {tactical, specialist, line, supervisor, opera...
# 11203100  {tactical, specialist, line, supervisor, opera...
# 11301100  {tactical, specialist, line, supervisor, opera...
# 11302100  {tactical, specialist, line, supervisor, opera...
# 11303100  {tactical, specialist, line, supervisor, opera...
# 11303101  {tactical, specialist, line, supervisor, opera...
# 11303102  {tactical, specialist, line, supervisor, opera...
# 11305100  {tactical, specialist, line, supervisor, opera...
# 11305101  {tactical, specialist, line, supervisor, opera...
# 11305102  {tactical, specialist, line, supervisor, opera...
# 11305103  {tactical, specialist, line, supervisor, opera...
# 11305104  {tactical, specialist, line, supervisor, opera...
# 11305105  {tactical, specialist, line, supervisor, opera...
# 11305106  {tactical, specialist, line, supervisor, opera...
# 11306100  {tactical, specialist, line, supervisor, opera...
# 11307100  {tactical, specialist, line, supervisor, opera...
# 11307101  {tactical, specialist, line, supervisor, opera...
# 11307102  {tactical, specialist, line, supervisor, opera...
# 11307103  {tactical, specialist, line, supervisor, opera...
# 11311100  {tactical, specialist, line, supervisor, opera...
# 11312100  {tactical, specialist, line, supervisor, opera...
# 11313100  {tactical, specialist, line, supervisor, opera...
# 11901301  {tactical, specialist, line, supervisor, opera...
# ...                                                     ...
# 53706200  {tactical, specialist, line, supervisor, opera...
# 53706300  {tactical, specialist, line, supervisor, opera...
# 53706400  {tactical, specialist, line, supervisor, opera...
# 53707100  {tactical, specialist, line, supervisor, opera...
# 53707200  {tactical, specialist, line, supervisor, opera...
# 53707300  {tactical, specialist, line, supervisor, opera...
# 53708100  {tactical, specialist, line, supervisor, opera...
# 53711100  {tactical, specialist, line, supervisor, opera...
# 53712100  {tactical, specialist, line, supervisor, opera...
# 53719900  {tactical, specialist, line, supervisor, opera...
# 55101100  {tactical, specialist, line, supervisor, opera...
# 55101200  {tactical, specialist, line, supervisor, opera...
# 55101300  {tactical, specialist, line, supervisor, opera...
# 55101400  {tactical, specialist, line, supervisor, opera...
# 55101500  {tactical, specialist, line, supervisor, opera...
# 55101600  {tactical, specialist, line, supervisor, opera...
# 55101700  {tactical, specialist, line, supervisor, opera...
# 55101900  {tactical, specialist, line, supervisor, opera...
# 55201100  {tactical, specialist, line, supervisor, opera...
# 55201200                                                NaN
# 55201300  {tactical, specialist, line, supervisor, opera...
# 55301100  {tactical, specialist, line, supervisor, opera...
# 55301200  {tactical, specialist, line, supervisor, opera...
# 55301300  {tactical, specialist, line, supervisor, opera...
# 55301400  {tactical, specialist, line, supervisor, opera...
# 55301500  {tactical, specialist, line, supervisor, opera...
# 55301600  {tactical, specialist, line, supervisor, opera...
# 55301700  {tactical, specialist, line, supervisor, opera...
# 55301800  {tactical, specialist, line, supervisor, opera...
# 55301900  {tactical, specialist, line, supervisor, opera...
#
#                                                                          \
#                      55301100                                  55301200
# 11101100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11101103  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11102100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11103100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11201100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11201101  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11202100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11202200  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11203100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11301100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11302100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11303100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11303101  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11303102  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11305100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11305101  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11305102  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11305103  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11305104  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11305105  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11305106  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11306100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11307100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11307101  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11307102  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11307103  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11311100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11312100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11313100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 11901301  {member, crew, air}  {aircraft, launch, specialist, recovery}
# ...                       ...                                       ...
# 53706200  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 53706300  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 53706400  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 53707100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 53707200  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 53707300  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 53708100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 53711100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 53712100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 53719900  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55101100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55101200  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55101300  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55101400  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55101500  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55101600  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55101700  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55101900  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55201100  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55201200  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55201300                  NaN  {aircraft, launch, specialist, recovery}
# 55301100  {member, crew, air}                                       NaN
# 55301200  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55301300  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55301400  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55301500  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55301600  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55301700  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55301800  {member, crew, air}  {aircraft, launch, specialist, recovery}
# 55301900  {member, crew, air}  {aircraft, launch, specialist, recovery}
#
#                                                      \
#                                            55301300
# 11101100  {armored, assault, crew, member, vehicle}
# 11101103  {armored, assault, crew, member, vehicle}
# 11102100  {armored, assault, crew, member, vehicle}
# 11103100  {armored, assault, crew, member, vehicle}
# 11201100  {armored, assault, crew, member, vehicle}
# 11201101  {armored, assault, crew, member, vehicle}
# 11202100  {armored, assault, crew, member, vehicle}
# 11202200  {armored, assault, crew, member, vehicle}
# 11203100  {armored, assault, crew, member, vehicle}
# 11301100  {armored, assault, crew, member, vehicle}
# 11302100  {armored, assault, crew, member, vehicle}
# 11303100  {armored, assault, crew, member, vehicle}
# 11303101  {armored, assault, crew, member, vehicle}
# 11303102  {armored, assault, crew, member, vehicle}
# 11305100  {armored, assault, crew, member, vehicle}
# 11305101  {armored, assault, crew, member, vehicle}
# 11305102  {armored, assault, crew, member, vehicle}
# 11305103  {armored, assault, crew, member, vehicle}
# 11305104  {armored, assault, crew, member, vehicle}
# 11305105  {armored, assault, crew, member, vehicle}
# 11305106  {armored, assault, crew, member, vehicle}
# 11306100  {armored, assault, crew, member, vehicle}
# 11307100  {armored, assault, crew, member, vehicle}
# 11307101  {armored, assault, crew, member, vehicle}
# 11307102  {armored, assault, crew, member, vehicle}
# 11307103  {armored, assault, crew, member, vehicle}
# 11311100  {armored, assault, crew, member, vehicle}
# 11312100  {armored, assault, crew, member, vehicle}
# 11313100  {armored, assault, crew, member, vehicle}
# 11901301  {armored, assault, crew, member, vehicle}
# ...                                             ...
# 53706200  {armored, assault, crew, member, vehicle}
# 53706300  {armored, assault, crew, member, vehicle}
# 53706400  {armored, assault, crew, member, vehicle}
# 53707100  {armored, assault, crew, member, vehicle}
# 53707200  {armored, assault, crew, member, vehicle}
# 53707300  {armored, assault, crew, member, vehicle}
# 53708100  {armored, assault, crew, member, vehicle}
# 53711100  {armored, assault, crew, member, vehicle}
# 53712100  {armored, assault, crew, member, vehicle}
# 53719900  {armored, assault, crew, member, vehicle}
# 55101100  {armored, assault, crew, member, vehicle}
# 55101200  {armored, assault, crew, member, vehicle}
# 55101300  {armored, assault, crew, member, vehicle}
# 55101400  {armored, assault, crew, member, vehicle}
# 55101500  {armored, assault, crew, member, vehicle}
# 55101600  {armored, assault, crew, member, vehicle}
# 55101700  {armored, assault, crew, member, vehicle}
# 55101900  {armored, assault, crew, member, vehicle}
# 55201100  {armored, assault, crew, member, vehicle}
# 55201200  {armored, assault, crew, member, vehicle}
# 55201300  {armored, assault, crew, member, vehicle}
# 55301100  {armored, assault, crew, member, vehicle}
# 55301200                                        NaN
# 55301300  {armored, assault, crew, member, vehicle}
# 55301400  {armored, assault, crew, member, vehicle}
# 55301500  {armored, assault, crew, member, vehicle}
# 55301600  {armored, assault, crew, member, vehicle}
# 55301700  {armored, assault, crew, member, vehicle}
# 55301800  {armored, assault, crew, member, vehicle}
# 55301900  {armored, assault, crew, member, vehicle}
#
#                                               \
#                                     55301400
# 11101100  {member, artillery, crew, missile}
# 11101103  {member, artillery, crew, missile}
# 11102100  {member, artillery, crew, missile}
# 11103100  {member, artillery, crew, missile}
# 11201100  {member, artillery, crew, missile}
# 11201101  {member, artillery, crew, missile}
# 11202100  {member, artillery, crew, missile}
# 11202200  {member, artillery, crew, missile}
# 11203100  {member, artillery, crew, missile}
# 11301100  {member, artillery, crew, missile}
# 11302100  {member, artillery, crew, missile}
# 11303100  {member, artillery, crew, missile}
# 11303101  {member, artillery, crew, missile}
# 11303102  {member, artillery, crew, missile}
# 11305100  {member, artillery, crew, missile}
# 11305101  {member, artillery, crew, missile}
# 11305102  {member, artillery, crew, missile}
# 11305103  {member, artillery, crew, missile}
# 11305104  {member, artillery, crew, missile}
# 11305105  {member, artillery, crew, missile}
# 11305106  {member, artillery, crew, missile}
# 11306100  {member, artillery, crew, missile}
# 11307100  {member, artillery, crew, missile}
# 11307101  {member, artillery, crew, missile}
# 11307102  {member, artillery, crew, missile}
# 11307103  {member, artillery, crew, missile}
# 11311100  {member, artillery, crew, missile}
# 11312100  {member, artillery, crew, missile}
# 11313100  {member, artillery, crew, missile}
# 11901301  {member, artillery, crew, missile}
# ...                                      ...
# 53706200  {member, artillery, crew, missile}
# 53706300  {member, artillery, crew, missile}
# 53706400  {member, artillery, crew, missile}
# 53707100  {member, artillery, crew, missile}
# 53707200  {member, artillery, crew, missile}
# 53707300  {member, artillery, crew, missile}
# 53708100  {member, artillery, crew, missile}
# 53711100  {member, artillery, crew, missile}
# 53712100  {member, artillery, crew, missile}
# 53719900  {member, artillery, crew, missile}
# 55101100  {member, artillery, crew, missile}
# 55101200  {member, artillery, crew, missile}
# 55101300  {member, artillery, crew, missile}
# 55101400  {member, artillery, crew, missile}
# 55101500  {member, artillery, crew, missile}
# 55101600  {member, artillery, crew, missile}
# 55101700  {member, artillery, crew, missile}
# 55101900  {member, artillery, crew, missile}
# 55201100  {member, artillery, crew, missile}
# 55201200  {member, artillery, crew, missile}
# 55201300  {member, artillery, crew, missile}
# 55301100  {member, artillery, crew, missile}
# 55301200  {member, artillery, crew, missile}
# 55301300                                 NaN
# 55301400  {member, artillery, crew, missile}
# 55301500  {member, artillery, crew, missile}
# 55301600  {member, artillery, crew, missile}
# 55301700  {member, artillery, crew, missile}
# 55301800  {member, artillery, crew, missile}
# 55301900  {member, artillery, crew, missile}
#
#                                                               \
#                                         55301500    55301600
# 11101100  {control, center, specialist, command}  {infantry}
# 11101103  {control, center, specialist, command}  {infantry}
# 11102100  {control, center, specialist, command}  {infantry}
# 11103100  {control, center, specialist, command}  {infantry}
# 11201100  {control, center, specialist, command}  {infantry}
# 11201101  {control, center, specialist, command}  {infantry}
# 11202100  {control, center, specialist, command}  {infantry}
# 11202200  {control, center, specialist, command}  {infantry}
# 11203100  {control, center, specialist, command}  {infantry}
# 11301100  {control, center, specialist, command}  {infantry}
# 11302100  {control, center, specialist, command}  {infantry}
# 11303100  {control, center, specialist, command}  {infantry}
# 11303101  {control, center, specialist, command}  {infantry}
# 11303102  {control, center, specialist, command}  {infantry}
# 11305100  {control, center, specialist, command}  {infantry}
# 11305101  {control, center, specialist, command}  {infantry}
# 11305102  {control, center, specialist, command}  {infantry}
# 11305103  {control, center, specialist, command}  {infantry}
# 11305104  {control, center, specialist, command}  {infantry}
# 11305105  {control, center, specialist, command}  {infantry}
# 11305106  {control, center, specialist, command}  {infantry}
# 11306100  {control, center, specialist, command}  {infantry}
# 11307100  {control, center, specialist, command}  {infantry}
# 11307101  {control, center, specialist, command}  {infantry}
# 11307102  {control, center, specialist, command}  {infantry}
# 11307103  {control, center, specialist, command}  {infantry}
# 11311100  {control, center, specialist, command}  {infantry}
# 11312100  {control, center, specialist, command}  {infantry}
# 11313100  {control, center, specialist, command}  {infantry}
# 11901301  {control, center, specialist, command}  {infantry}
# ...                                          ...         ...
# 53706200  {control, center, specialist, command}  {infantry}
# 53706300  {control, center, specialist, command}  {infantry}
# 53706400  {control, center, specialist, command}  {infantry}
# 53707100  {control, center, specialist, command}  {infantry}
# 53707200  {control, center, specialist, command}  {infantry}
# 53707300  {control, center, specialist, command}  {infantry}
# 53708100  {control, center, specialist, command}  {infantry}
# 53711100  {control, center, specialist, command}  {infantry}
# 53712100  {control, center, specialist, command}  {infantry}
# 53719900  {control, center, specialist, command}  {infantry}
# 55101100  {control, center, specialist, command}  {infantry}
# 55101200  {control, center, specialist, command}  {infantry}
# 55101300  {control, center, specialist, command}  {infantry}
# 55101400  {control, center, specialist, command}  {infantry}
# 55101500  {control, center, specialist, command}  {infantry}
# 55101600  {control, center, specialist, command}  {infantry}
# 55101700  {control, center, specialist, command}  {infantry}
# 55101900  {control, center, specialist, command}  {infantry}
# 55201100  {control, center, specialist, command}  {infantry}
# 55201200  {control, center, specialist, command}  {infantry}
# 55201300  {control, center, specialist, command}  {infantry}
# 55301100  {control, center, specialist, command}  {infantry}
# 55301200  {control, center, specialist, command}  {infantry}
# 55301300  {control, center, specialist, command}  {infantry}
# 55301400                                     NaN  {infantry}
# 55301500  {control, center, specialist, command}         NaN
# 55301600  {control, center, specialist, command}  {infantry}
# 55301700  {control, center, specialist, command}  {infantry}
# 55301800  {control, center, specialist, command}  {infantry}
# 55301900  {control, center, specialist, command}  {infantry}
#
#                                                         \
#                             55301700          55301800
# 11101100  {technician, radar, sonar}  {special, force}
# 11101103  {technician, radar, sonar}  {special, force}
# 11102100  {technician, radar, sonar}  {special, force}
# 11103100  {technician, radar, sonar}  {special, force}
# 11201100  {technician, radar, sonar}  {special, force}
# 11201101  {technician, radar, sonar}  {special, force}
# 11202100  {technician, radar, sonar}  {special, force}
# 11202200  {technician, radar, sonar}  {special, force}
# 11203100  {technician, radar, sonar}  {special, force}
# 11301100  {technician, radar, sonar}  {special, force}
# 11302100  {technician, radar, sonar}  {special, force}
# 11303100  {technician, radar, sonar}  {special, force}
# 11303101  {technician, radar, sonar}  {special, force}
# 11303102  {technician, radar, sonar}  {special, force}
# 11305100  {technician, radar, sonar}  {special, force}
# 11305101  {technician, radar, sonar}  {special, force}
# 11305102  {technician, radar, sonar}  {special, force}
# 11305103  {technician, radar, sonar}  {special, force}
# 11305104  {technician, radar, sonar}  {special, force}
# 11305105  {technician, radar, sonar}  {special, force}
# 11305106  {technician, radar, sonar}  {special, force}
# 11306100  {technician, radar, sonar}  {special, force}
# 11307100  {technician, radar, sonar}  {special, force}
# 11307101  {technician, radar, sonar}  {special, force}
# 11307102  {technician, radar, sonar}  {special, force}
# 11307103  {technician, radar, sonar}  {special, force}
# 11311100  {technician, radar, sonar}  {special, force}
# 11312100  {technician, radar, sonar}  {special, force}
# 11313100  {technician, radar, sonar}  {special, force}
# 11901301  {technician, radar, sonar}  {special, force}
# ...                              ...               ...
# 53706200  {technician, radar, sonar}  {special, force}
# 53706300  {technician, radar, sonar}  {special, force}
# 53706400  {technician, radar, sonar}  {special, force}
# 53707100  {technician, radar, sonar}  {special, force}
# 53707200  {technician, radar, sonar}  {special, force}
# 53707300  {technician, radar, sonar}  {special, force}
# 53708100  {technician, radar, sonar}  {special, force}
# 53711100  {technician, radar, sonar}  {special, force}
# 53712100  {technician, radar, sonar}  {special, force}
# 53719900  {technician, radar, sonar}  {special, force}
# 55101100  {technician, radar, sonar}  {special, force}
# 55101200  {technician, radar, sonar}  {special, force}
# 55101300  {technician, radar, sonar}  {special, force}
# 55101400  {technician, radar, sonar}  {special, force}
# 55101500  {technician, radar, sonar}  {special, force}
# 55101600  {technician, radar, sonar}  {special, force}
# 55101700  {technician, radar, sonar}  {special, force}
# 55101900  {technician, radar, sonar}  {special, force}
# 55201100  {technician, radar, sonar}  {special, force}
# 55201200  {technician, radar, sonar}  {special, force}
# 55201300  {technician, radar, sonar}  {special, force}
# 55301100  {technician, radar, sonar}  {special, force}
# 55301200  {technician, radar, sonar}  {special, force}
# 55301300  {technician, radar, sonar}  {special, force}
# 55301400  {technician, radar, sonar}  {special, force}
# 55301500  {technician, radar, sonar}  {special, force}
# 55301600                         NaN  {special, force}
# 55301700  {technician, radar, sonar}               NaN
# 55301800  {technician, radar, sonar}  {special, force}
# 55301900  {technician, radar, sonar}  {special, force}
#
#
#                                                    55301900
# 11101100  {tactical, operation, crew, member, enlisted, ...
# 11101103  {tactical, operation, crew, member, enlisted, ...
# 11102100  {tactical, operation, crew, member, enlisted, ...
# 11103100  {tactical, operation, crew, member, enlisted, ...
# 11201100  {tactical, operation, crew, member, enlisted, ...
# 11201101  {tactical, operation, crew, member, enlisted, ...
# 11202100  {tactical, operation, crew, member, enlisted, ...
# 11202200  {tactical, operation, crew, member, enlisted, ...
# 11203100  {tactical, operation, crew, member, enlisted, ...
# 11301100  {tactical, operation, crew, member, enlisted, ...
# 11302100  {tactical, operation, crew, member, enlisted, ...
# 11303100  {tactical, operation, crew, member, enlisted, ...
# 11303101  {tactical, operation, crew, member, enlisted, ...
# 11303102  {tactical, operation, crew, member, enlisted, ...
# 11305100  {tactical, operation, crew, member, enlisted, ...
# 11305101  {tactical, operation, crew, member, enlisted, ...
# 11305102  {tactical, operation, crew, member, enlisted, ...
# 11305103  {tactical, operation, crew, member, enlisted, ...
# 11305104  {tactical, operation, crew, member, enlisted, ...
# 11305105  {tactical, operation, crew, member, enlisted, ...
# 11305106  {tactical, operation, crew, member, enlisted, ...
# 11306100  {tactical, operation, crew, member, enlisted, ...
# 11307100  {tactical, operation, crew, member, enlisted, ...
# 11307101  {tactical, operation, crew, member, enlisted, ...
# 11307102  {tactical, operation, crew, member, enlisted, ...
# 11307103  {tactical, operation, crew, member, enlisted, ...
# 11311100  {tactical, operation, crew, member, enlisted, ...
# 11312100  {tactical, operation, crew, member, enlisted, ...
# 11313100  {tactical, operation, crew, member, enlisted, ...
# 11901301  {tactical, operation, crew, member, enlisted, ...
# ...                                                     ...
# 53706200  {tactical, operation, crew, member, enlisted, ...
# 53706300  {tactical, operation, crew, member, enlisted, ...
# 53706400  {tactical, operation, crew, member, enlisted, ...
# 53707100  {tactical, operation, crew, member, enlisted, ...
# 53707200  {tactical, operation, crew, member, enlisted, ...
# 53707300  {tactical, operation, crew, member, enlisted, ...
# 53708100  {tactical, operation, crew, member, enlisted, ...
# 53711100  {tactical, operation, crew, member, enlisted, ...
# 53712100  {tactical, operation, crew, member, enlisted, ...
# 53719900  {tactical, operation, crew, member, enlisted, ...
# 55101100  {tactical, operation, crew, member, enlisted, ...
# 55101200  {tactical, operation, crew, member, enlisted, ...
# 55101300  {tactical, operation, crew, member, enlisted, ...
# 55101400  {tactical, operation, crew, member, enlisted, ...
# 55101500  {tactical, operation, crew, member, enlisted, ...
# 55101600  {tactical, operation, crew, member, enlisted, ...
# 55101700  {tactical, operation, crew, member, enlisted, ...
# 55101900  {tactical, operation, crew, member, enlisted, ...
# 55201100  {tactical, operation, crew, member, enlisted, ...
# 55201200  {tactical, operation, crew, member, enlisted, ...
# 55201300  {tactical, operation, crew, member, enlisted, ...
# 55301100  {tactical, operation, crew, member, enlisted, ...
# 55301200  {tactical, operation, crew, member, enlisted, ...
# 55301300  {tactical, operation, crew, member, enlisted, ...
# 55301400  {tactical, operation, crew, member, enlisted, ...
# 55301500  {tactical, operation, crew, member, enlisted, ...
# 55301600  {tactical, operation, crew, member, enlisted, ...
# 55301700  {tactical, operation, crew, member, enlisted, ...
# 55301800                                                NaN
# 55301900  {tactical, operation, crew, member, enlisted, ...
#
# [1109 rows x 1109 columns]

# %%
aaa.head()
# Out:
# SOCP_shave
# 11101100                   {chief, executive}
# 11101103     {sustainability, chief, officer}
# 11102100        {operation, manager, general}
# 11103100                         {legislator}
# 11201100    {advertising, manager, promotion}
# Name: title_vec, dtype: object
